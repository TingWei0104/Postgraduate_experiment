# %%
import pandas as pd
import openpyxl
# 變數設定，目的在於其他的project只要修改這部分就好了
Project = 'math'
Project2 = 'Math'
project_bugid_num = 106
Excel_name = 'math_整理結果'
Excel_save_path = 'math_result'

# 這是要放要拿來使用的絕對路徑
# unsort_data_path = 'Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old'
unsort_data_path = '懷疑值source/' + Project2 + '/old'

SBFL_all = ["Ochiai"]

# %%
# 取得project的每一個bug-id有多少行的方法。
SBFL_fault_statement_number = []
project_statement_file = 'project_line/' + Project +'_line.txt'

# 使用 with 語句打開文件，確保文件在使用後自動關閉
with open(project_statement_file, 'r', encoding='utf-8') as file:
    project_lines = file.readlines()  # 讀取所有行

# 去掉每行末尾的換行符
project_lines = [int(line.strip()) for line in project_lines] # 順便將str轉為數字
print(project_lines)

max_line = max(project_lines) # 找出最大行數，用於後續輸出使用
print(max_line)
# Out:
# [2539, 2069, 503, 3149, 231, 9146, 2921, 973, 2161, 2285, 7036, 2391, 7555, 6616, 2863, 2850, 1206, 7205, 2814, 7172, 5390, 2310, 2353, 2347, 548, 2356, 1945, 5934, 3407, 2708, 3033, 3930, 5756, 188, 517, 643, 1745, 5094, 2460, 2014, 1875, 5779, 2301, 2894, 1546, 2678, 2677, 3169, 3245, 3152, 2754, 2948, 789, 2897, 2051, 2514, 2603, 2841, 2881, 2087, 2321, 2247, 1773, 656, 3680, 1781, 682, 620, 3360, 181, 1108, 227, 306, 4661, 131, 5117, 4643, 476, 491, 4447, 4446, 2019, 2018, 251, 467, 1492, 2010, 2010, 108, 106, 471, 227, 222, 221, 451, 128, 218, 919, 325, 631, 140, 929, 238, 169, 68, 187]
# 9146

# %%
# get_fault_statement
#動態產生二微陣列的方法
Project_bugid_faultStatement = []

for i in range(0,project_bugid_num):
    fault_statement_file_path = '錯誤位置/'+ Project + '/' + Project2 +'_v' + str(i+1) + '_FaultStatement.txt'
    print(fault_statement_file_path)

    # 使用 with 語句打開文件，確保文件在使用後自動關閉
    with open(fault_statement_file_path, 'r', encoding='utf-8') as file:
        lines2 = file.readlines()  # 讀取所有行

    # 去掉每行末尾的換行符
    lines2 = [line.strip() for line in lines2]
    print(lines2)

    lines2 = lines2[0].split()
    print(len(lines2))

    Project_bugid_faultStatement.append([])
    for j in range(0,len(lines2)):
        Project_bugid_faultStatement[i].append(int(lines2[j])) # 順便將str轉為數字

print(Project_bugid_faultStatement)
# Out:
# 錯誤位置/math/Math_v1_FaultStatement.txt
# ['313 314 69 70']
# 4
# 錯誤位置/math/Math_v2_FaultStatement.txt
# ['1563']
# 1
# 錯誤位置/math/Math_v3_FaultStatement.txt
# ['286 288']
# 2
# 錯誤位置/math/Math_v4_FaultStatement.txt
# ['2114 2115 2885 2886']
# 4
# 錯誤位置/math/Math_v5_FaultStatement.txt
# ['63']
# 1
# 錯誤位置/math/Math_v6_FaultStatement.txt
# ['1379 1381 1410 1504 1506 1511 1538 1631 1632 1654 1712 1721 195 1979 1980 325 327 425']
# 18
# 錯誤位置/math/Math_v7_FaultStatement.txt
# ['1803 1804 1810 1811 1812 1814 1819 1820 1821']
# 9
# 錯誤位置/math/Math_v8_FaultStatement.txt
# ['533']
# 1
# 錯誤位置/math/Math_v9_FaultStatement.txt
# ['15']
# 1
# 錯誤位置/math/Math_v10_FaultStatement.txt
# ['1929 1935']
# 2
# 錯誤位置/math/Math_v11_FaultStatement.txt
# ['100']
# 1
# 錯誤位置/math/Math_v12_FaultStatement.txt
# ['0']
# 1
# 錯誤位置/math/Math_v13_FaultStatement.txt
# ['6258 6259']
# 2
# 錯誤位置/math/Math_v14_FaultStatement.txt
# ['2064 2065 2066 2120 2121']
# 5
# 錯誤位置/math/Math_v15_FaultStatement.txt
# ['558']
# 1
# 錯誤位置/math/Math_v16_FaultStatement.txt
# ['1256 1257 1258 1259 1287 1288 1289 1290']
# 8
# 錯誤位置/math/Math_v17_FaultStatement.txt
# ['759']
# 1
# 錯誤位置/math/Math_v18_FaultStatement.txt
# ['4549 4557 4568 4570']
# 4
# 錯誤位置/math/Math_v19_FaultStatement.txt
# ['300 302']
# 2
# 錯誤位置/math/Math_v20_FaultStatement.txt
# ['597']
# 1
# 錯誤位置/math/Math_v21_FaultStatement.txt
# ['3494 3500 3503 3504 3505 3506 3507 3508 3509 3522 3526']
# 11
# 錯誤位置/math/Math_v22_FaultStatement.txt
# ['1938 2040']
# 2
# 錯誤位置/math/Math_v23_FaultStatement.txt
# ['2312 2313 2315 2338']
# 4
# 錯誤位置/math/Math_v24_FaultStatement.txt
# ['114 91']
# 2
# 錯誤位置/math/Math_v25_FaultStatement.txt
# ['70']
# 1
# 錯誤位置/math/Math_v26_FaultStatement.txt
# ['113 132']
# 2
# 錯誤位置/math/Math_v27_FaultStatement.txt
# ['168']
# 1
# 錯誤位置/math/Math_v28_FaultStatement.txt
# ['5625 5626 5632 5633']
# 4
# 錯誤位置/math/Math_v29_FaultStatement.txt
# ['2462 2463 2464 2465 2470 2473']
# 6
# 錯誤位置/math/Math_v30_FaultStatement.txt
# ['2446']
# 1
# 錯誤位置/math/Math_v31_FaultStatement.txt
# ['613 614 620 621 622 623 624 625 626 627 628 629 630 631 632 633 634 635 636 637 638 639 640 641 648 649 650 651 652 657']
# 30
# 錯誤位置/math/Math_v32_FaultStatement.txt
# ['2218']
# 1
# 錯誤位置/math/Math_v33_FaultStatement.txt
# ['119']
# 1
# 錯誤位置/math/Math_v34_FaultStatement.txt
# ['55']
# 1
# 錯誤位置/math/Math_v35_FaultStatement.txt
# ['50 53']
# 2
# 錯誤位置/math/Math_v36_FaultStatement.txt
# ['220 221 230 231']
# 4
# 錯誤位置/math/Math_v37_FaultStatement.txt
# ['1676 1678 1679 1680 1681 1682 1684 1685 1686 1687']
# 10
# 錯誤位置/math/Math_v38_FaultStatement.txt
# ['816 817 818 873']
# 4
# 錯誤位置/math/Math_v39_FaultStatement.txt
# ['2296 2297']
# 2
# 錯誤位置/math/Math_v40_FaultStatement.txt
# ['1817 1819']
# 2
# 錯誤位置/math/Math_v41_FaultStatement.txt
# ['1769']
# 1
# 錯誤位置/math/Math_v42_FaultStatement.txt
# ['4041 4042']
# 2
# 錯誤位置/math/Math_v43_FaultStatement.txt
# ['1666 1668 1670']
# 3
# 錯誤位置/math/Math_v44_FaultStatement.txt
# ['167 194 195 199 200']
# 5
# 錯誤位置/math/Math_v45_FaultStatement.txt
# ['1105 1106 1107 1108']
# 4
# 錯誤位置/math/Math_v46_FaultStatement.txt
# ['42 57']
# 2
# 錯誤位置/math/Math_v47_FaultStatement.txt
# ['2507 2539 2540 2555']
# 4
# 錯誤位置/math/Math_v48_FaultStatement.txt
# ['3003']
# 1
# 錯誤位置/math/Math_v49_FaultStatement.txt
# ['2666 2673 2680 2687']
# 4
# 錯誤位置/math/Math_v50_FaultStatement.txt
# ['96 97 98']
# 3
# 錯誤位置/math/Math_v51_FaultStatement.txt
# ['2 40 45']
# 3
# 錯誤位置/math/Math_v52_FaultStatement.txt
# ['2572 2578 2581']
# 3
# 錯誤位置/math/Math_v53_FaultStatement.txt
# ['25 26']
# 2
# 錯誤位置/math/Math_v54_FaultStatement.txt
# ['1773 2681']
# 2
# 錯誤位置/math/Math_v55_FaultStatement.txt
# ['1967']
# 1
# 錯誤位置/math/Math_v56_FaultStatement.txt
# ['767 768 769 770 771 772']
# 6
# 錯誤位置/math/Math_v57_FaultStatement.txt
# ['2510']
# 1
# 錯誤位置/math/Math_v58_FaultStatement.txt
# ['80']
# 1
# 錯誤位置/math/Math_v59_FaultStatement.txt
# ['2880']
# 1
# 錯誤位置/math/Math_v60_FaultStatement.txt
# ['100 101 102 103 104 105 99']
# 7
# 錯誤位置/math/Math_v61_FaultStatement.txt
# ['2073']
# 1
# 錯誤位置/math/Math_v62_FaultStatement.txt
# ['2059 2063 2064 2065']
# 4
# 錯誤位置/math/Math_v63_FaultStatement.txt
# ['122']
# 1
# 錯誤位置/math/Math_v64_FaultStatement.txt
# ['230 237 241 264 266 267 277 278 290 325 330 331 332 336 337']
# 15
# 錯誤位置/math/Math_v65_FaultStatement.txt
# ['546 547 548 549 550 554']
# 6
# 錯誤位置/math/Math_v66_FaultStatement.txt
# ['128 129 153 155 157 59 61 62 65 66 68 83 84 88 89']
# 15
# 錯誤位置/math/Math_v67_FaultStatement.txt
# ['332 333']
# 2
# 錯誤位置/math/Math_v68_FaultStatement.txt
# ['193 194 225 253 318 319']
# 6
# 錯誤位置/math/Math_v69_FaultStatement.txt
# ['40']
# 1
# 錯誤位置/math/Math_v70_FaultStatement.txt
# ['165']
# 1
# 錯誤位置/math/Math_v71_FaultStatement.txt
# ['358 359 748 749']
# 4
# 錯誤位置/math/Math_v72_FaultStatement.txt
# ['140 146']
# 2
# 錯誤位置/math/Math_v73_FaultStatement.txt
# ['198']
# 1
# 錯誤位置/math/Math_v74_FaultStatement.txt
# ['4468 4469 4470']
# 3
# 錯誤位置/math/Math_v75_FaultStatement.txt
# ['69']
# 1
# 錯誤位置/math/Math_v76_FaultStatement.txt
# ['1638 1639 1640 1641 1642 1647 1672 1673 1674 1675 1676 1681 1682']
# 13
# 錯誤位置/math/Math_v77_FaultStatement.txt
# ['3843 3844 3845 3846 3847 3848 4385']
# 7
# 錯誤位置/math/Math_v78_FaultStatement.txt
# ['81']
# 1
# 錯誤位置/math/Math_v79_FaultStatement.txt
# ['381 383']
# 2
# 錯誤位置/math/Math_v80_FaultStatement.txt
# ['1741']
# 1
# 錯誤位置/math/Math_v81_FaultStatement.txt
# ['2637 2638 2790 2791 3137']
# 5
# 錯誤位置/math/Math_v82_FaultStatement.txt
# ['1948']
# 1
# 錯誤位置/math/Math_v83_FaultStatement.txt
# ['1862 1884 1888']
# 3
# 錯誤位置/math/Math_v84_FaultStatement.txt
# ['201 202']
# 2
# 錯誤位置/math/Math_v85_FaultStatement.txt
# ['461']
# 1
# 錯誤位置/math/Math_v86_FaultStatement.txt
# ['1369 1370 1371 1372']
# 4
# 錯誤位置/math/Math_v87_FaultStatement.txt
# ['1789 1790 1792']
# 3
# 錯誤位置/math/Math_v88_FaultStatement.txt
# ['1523 1524 1525 1526 1527 1528 1529']
# 7
# 錯誤位置/math/Math_v89_FaultStatement.txt
# ['25 26']
# 2
# 錯誤位置/math/Math_v90_FaultStatement.txt
# ['23 24']
# 2
# 錯誤位置/math/Math_v91_FaultStatement.txt
# ['394 395']
# 2
# 錯誤位置/math/Math_v92_FaultStatement.txt
# ['29 30 31 32 33 40 42 43']
# 8
# 錯誤位置/math/Math_v93_FaultStatement.txt
# ['58 59 64 67 68']
# 5
# 錯誤位置/math/Math_v94_FaultStatement.txt
# ['70']
# 1
# 錯誤位置/math/Math_v95_FaultStatement.txt
# ['347 348']
# 2
# 錯誤位置/math/Math_v96_FaultStatement.txt
# ['53']
# 1
# 錯誤位置/math/Math_v97_FaultStatement.txt
# ['100 101 102 103']
# 4
# 錯誤位置/math/Math_v98_FaultStatement.txt
# ['314 761']
# 2
# 錯誤位置/math/Math_v99_FaultStatement.txt
# ['171 172 207 208']
# 4
# 錯誤位置/math/Math_v100_FaultStatement.txt
# ['503 517 520']
# 3
# 錯誤位置/math/Math_v101_FaultStatement.txt
# ['86']
# 1
# 錯誤位置/math/Math_v102_FaultStatement.txt
# ['416 419 420']
# 3
# 錯誤位置/math/Math_v103_FaultStatement.txt
# ['111']
# 1
# 錯誤位置/math/Math_v104_FaultStatement.txt
# ['0']
# 1
# 錯誤位置/math/Math_v105_FaultStatement.txt
# ['44']
# 1
# 錯誤位置/math/Math_v106_FaultStatement.txt
# ['164 167 177 182']
# 4
# [[313, 314, 69, 70], [1563], [286, 288], [2114, 2115, 2885, 2886], [63], [1379, 1381, 1410, 1504, 1506, 1511, 1538, 1631, 1632, 1654, 1712, 1721, 195, 1979, 1980, 325, 327, 425], [1803, 1804, 1810, 1811, 1812, 1814, 1819, 1820, 1821], [533], [15], [1929, 1935], [100], [0], [6258, 6259], [2064, 2065, 2066, 2120, 2121], [558], [1256, 1257, 1258, 1259, 1287, 1288, 1289, 1290], [759], [4549, 4557, 4568, 4570], [300, 302], [597], [3494, 3500, 3503, 3504, 3505, 3506, 3507, 3508, 3509, 3522, 3526], [1938, 2040], [2312, 2313, 2315, 2338], [114, 91], [70], [113, 132], [168], [5625, 5626, 5632, 5633], [2462, 2463, 2464, 2465, 2470, 2473], [2446], [613, 614, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 648, 649, 650, 651, 652, 657], [2218], [119], [55], [50, 53], [220, 221, 230, 231], [1676, 1678, 1679, 1680, 1681, 1682, 1684, 1685, 1686, 1687], [816, 817, 818, 873], [2296, 2297], [1817, 1819], [1769], [4041, 4042], [1666, 1668, 1670], [167, 194, 195, 199, 200], [1105, 1106, 1107, 1108], [42, 57], [2507, 2539, 2540, 2555], [3003], [2666, 2673, 2680, 2687], [96, 97, 98], [2, 40, 45], [2572, 2578, 2581], [25, 26], [1773, 2681], [1967], [767, 768, 769, 770, 771, 772], [2510], [80], [2880], [100, 101, 102, 103, 104, 105, 99], [2073], [2059, 2063, 2064, 2065], [122], [230, 237, 241, 264, 266, 267, 277, 278, 290, 325, 330, 331, 332, 336, 337], [546, 547, 548, 549, 550, 554], [128, 129, 153, 155, 157, 59, 61, 62, 65, 66, 68, 83, 84, 88, 89], [332, 333], [193, 194, 225, 253, 318, 319], [40], [165], [358, 359, 748, 749], [140, 146], [198], [4468, 4469, 4470], [69], [1638, 1639, 1640, 1641, 1642, 1647, 1672, 1673, 1674, 1675, 1676, 1681, 1682], [3843, 3844, 3845, 3846, 3847, 3848, 4385], [81], [381, 383], [1741], [2637, 2638, 2790, 2791, 3137], [1948], [1862, 1884, 1888], [201, 202], [461], [1369, 1370, 1371, 1372], [1789, 1790, 1792], [1523, 1524, 1525, 1526, 1527, 1528, 1529], [25, 26], [23, 24], [394, 395], [29, 30, 31, 32, 33, 40, 42, 43], [58, 59, 64, 67, 68], [70], [347, 348], [53], [100, 101, 102, 103], [314, 761], [171, 172, 207, 208], [503, 517, 520], [86], [416, 419, 420], [111], [0], [44], [164, 167, 177, 182]]

# %%
# #要存成的excel index有甚麼
# data = {
#     'SBFL_Tool': [],
#     'Top': [],
#     'Spectra_file_index': [],
#     'Suspicious_Value': []
# }

# %%
#動態產生二微陣列的方法
bug_id_rank = []

for SBFL_index, SBFL_a in enumerate(SBFL_all):
    
    
    for i in range(0,project_bugid_num):   

        # 要存成的excel index有甚麼
        # 因為每次一個for迴圈就會要新的df，所以每次都要重新定義，保證能清空前一個錯誤版本的資料
        data = {
        'SBFL_Tool': [],
        'bug_id': [],
        'Top': [],
        'Spectra_file_index': [],
        'Suspicious_Value': [],
        '錯誤': []
        }

        # 後續記錄用
        # 紀錄不同錯誤版本用於SBFL後，錯誤在哪個排名
        bug_id_rank.append([])

        file_path = unsort_data_path + '/' + SBFL_a + '_v' + str(i+1) + '_sus.txt' #使用絕對路徑
        print("懷疑值檔案", file_path)

        # 使用 with 語句打開文件，確保文件在使用後自動關閉
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()  # 讀取所有行

        # 去掉每行末尾的換行符
        lines = [line.strip() for line in lines]

        # 轉換為float，以及處理例外的問題。
        numbers = []
        for line in lines:
            try:
                number = float(line.strip())
            except ValueError:  # 捕獲轉換錯誤
                print("抓到非數字!")
                number = 0  # 將無法轉換的值設為0
            numbers.append(number)


        # 將列表中的元素和其索引配對，用於表示的幾個statement
        indexed_list = list(enumerate(numbers))

        # 取出最大的數字
        max_prob = max(indexed_list)
        count = numbers.count(max_prob)

        # 將列表中的元素和其索引配對,索引從1開始
        indexed_list = [(i+1, numbers) for i, numbers in enumerate(numbers)]

        # 找出前 XX 名（若列表長度小於 XX，則返回所有元素）
        # top_test = sorted(indexed_list, key=lambda x: x[1], reverse=True)[:max_line]

        # 找出前 200 名（若列表長度小於 200，則返回所有元素），因為全部都存起來，excel會爆炸，所以改成200名就好了。
        #top_test = sorted(indexed_list, key=lambda x: x[1], reverse=True)[:200]

        # 因為不需要前200名，所以取全部。
        top_test = sorted(indexed_list, key=lambda x: x[1], reverse=True)

        Now_top = 0 # 用於紀錄top用的
        previous_rank_sus = '' #表示與前一個rank的懷疑質做比較做比較
        count_top = 0

        for index, value in top_test:

            #用於處理計算Top使用----
            count_top += 1
            if value != previous_rank_sus:
                #Now_top = Now_top
                #Now_top += 1
                Now_top = count_top
            else:
                Now_top = Now_top
            #----------------------
            
            # 標示錯誤位置用
            flag = 0
            for faultStatement_index in range(0,len(Project_bugid_faultStatement[i])): # 檢查這一行有沒有存在正確的錯誤位置(Project_bugid_faultStatement)裡面。
                if index == Project_bugid_faultStatement[i][faultStatement_index]:
                    bug_id_rank[i].append("錯誤index: " + str(index) + ", Top位置: " + str(Now_top)) # 順便將str轉為數字
                    flag = 1
                    break

            previous_rank_sus = value
            data['SBFL_Tool'].append(SBFL_a)
            data['bug_id'].append(i+1)
            data['Top'].append(Now_top)
            data['Spectra_file_index'].append(index)
            data['Suspicious_Value'].append(value)
            if  flag == 1:
                data['錯誤'].append("錯誤找到")
            elif flag == 0:
                data['錯誤'].append(" ")

        # 創建 DataFrame
        df = pd.DataFrame(data)
        print(df)

        save_excel_file_name = Excel_name + SBFL_a + '_' + Project + '_v' + str(i+1)
        print(save_excel_file_name)
        wb = openpyxl.Workbook() #建立空的excel
        #wb = openpyxl.load_workbook('oxxo.xlsx') #開啟excel
        wb.save( Excel_save_path + '/' + save_excel_file_name + '.xlsx')

        # # 將資料寫入 Excel 檔案
        file_name = Excel_save_path + '/' + save_excel_file_name + '.xlsx'
        df.to_excel(Excel_save_path + '/' + save_excel_file_name + '.xlsx', index=False)

        print(f"資料已寫入 {save_excel_file_name} 文件中")


print(bug_id_rank)
# Out:
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v1_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai       1    1                 271               1.0
# 1       Ochiai       1    1                 272               1.0
# 2       Ochiai       1    1                2533               1.0
# 3       Ochiai       1    1                2534               1.0
# 4       Ochiai       1    1                2538               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2534    Ochiai       1  535                2214               0.0
# 2535    Ochiai       1  535                2532               0.0
# 2536    Ochiai       1  535                2535               0.0
# 2537    Ochiai       1  535                2536               0.0
# 2538    Ochiai       1  535                2537               0.0
#
# [2539 rows x 6 columns]
# math_整理結果Ochiai_math_v1
# 資料已寫入 math_整理結果Ochiai_math_v1 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v2_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai       2    1                1623               1.0
# 1       Ochiai       2    1                1749               1.0
# 2       Ochiai       2    1                1750               1.0
# 3       Ochiai       2    1                1751               1.0
# 4       Ochiai       2    1                1752               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2064    Ochiai       2  139                2065               0.0
# 2065    Ochiai       2  139                2066               0.0
# 2066    Ochiai       2  139                2067               0.0
# 2067    Ochiai       2  139                2068               0.0
# 2068    Ochiai       2  139                2069               0.0
#
# [2069 rows x 6 columns]
# math_整理結果Ochiai_math_v2
# 資料已寫入 math_整理結果Ochiai_math_v2 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v3_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai       3    1                 285               1.0
# 1      Ochiai       3    1                 286               1.0  錯誤找到
# 2      Ochiai       3    1                 288               1.0  錯誤找到
# 3      Ochiai       3    1                 289               1.0
# 4      Ochiai       3    1                 290               1.0
# ..        ...     ...  ...                 ...               ...   ...
# 498    Ochiai       3   19                 499               0.0
# 499    Ochiai       3   19                 500               0.0
# 500    Ochiai       3   19                 501               0.0
# 501    Ochiai       3   19                 502               0.0
# 502    Ochiai       3   19                 503               0.0
#
# [503 rows x 6 columns]
# math_整理結果Ochiai_math_v3
# 資料已寫入 math_整理結果Ochiai_math_v3 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v4_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai       4    1                2112               1.0
# 1       Ochiai       4    1                2113               1.0
# 2       Ochiai       4    1                2114               1.0  錯誤找到
# 3       Ochiai       4    1                2115               1.0  錯誤找到
# 4       Ochiai       4    1                2873               1.0
# ...        ...     ...  ...                 ...               ...   ...
# 3144    Ochiai       4  315                3145               0.0
# 3145    Ochiai       4  315                3146               0.0
# 3146    Ochiai       4  315                3147               0.0
# 3147    Ochiai       4  315                3148               0.0
# 3148    Ochiai       4  315                3149               0.0
#
# [3149 rows x 6 columns]
# math_整理結果Ochiai_math_v4
# 資料已寫入 math_整理結果Ochiai_math_v4 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v5_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai       5    1                  63          1.000000  錯誤找到
# 1      Ochiai       5    1                 203          1.000000
# 2      Ochiai       5    3                  62          0.447214
# 3      Ochiai       5    4                  60          0.408248
# 4      Ochiai       5    5                  79          0.154303
# ..        ...     ...  ...                 ...               ...   ...
# 226    Ochiai       5   21                 227          0.000000
# 227    Ochiai       5   21                 228          0.000000
# 228    Ochiai       5   21                 229          0.000000
# 229    Ochiai       5   21                 230          0.000000
# 230    Ochiai       5   21                 231          0.000000
#
# [231 rows x 6 columns]
# math_整理結果Ochiai_math_v5
# 資料已寫入 math_整理結果Ochiai_math_v5 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v6_sus.txt
#      SBFL_Tool  bug_id   Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai       6     1                 200          1.000000
# 1       Ochiai       6     2                2018          0.755929
# 2       Ochiai       6     3                2250          0.731925
# 3       Ochiai       6     3                2251          0.731925
# 4       Ochiai       6     3                2252          0.731925
# ...        ...     ...   ...                 ...               ... ..
# 9141    Ochiai       6  2785                9142          0.000000
# 9142    Ochiai       6  2785                9143          0.000000
# 9143    Ochiai       6  2785                9144          0.000000
# 9144    Ochiai       6  2785                9145          0.000000
# 9145    Ochiai       6  2785                9146          0.000000
#
# [9146 rows x 6 columns]
# math_整理結果Ochiai_math_v6
# 資料已寫入 math_整理結果Ochiai_math_v6 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v7_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai       7    1                1369               1.0
# 1       Ochiai       7    1                1370               1.0
# 2       Ochiai       7    1                1372               1.0
# 3       Ochiai       7    1                1806               1.0
# 4       Ochiai       7    1                1807               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2916    Ochiai       7  987                2917               0.0
# 2917    Ochiai       7  987                2918               0.0
# 2918    Ochiai       7  987                2919               0.0
# 2919    Ochiai       7  987                2920               0.0
# 2920    Ochiai       7  987                2921               0.0
#
# [2921 rows x 6 columns]
# math_整理結果Ochiai_math_v7
# 資料已寫入 math_整理結果Ochiai_math_v7 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v8_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai       8    1                 499               1.0
# 1      Ochiai       8    1                 500               1.0
# 2      Ochiai       8    1                 531               1.0
# 3      Ochiai       8    1                 533               1.0  錯誤找到
# 4      Ochiai       8    1                 534               1.0
# ..        ...     ...  ...                 ...               ...   ...
# 968    Ochiai       8  126                 969               0.0
# 969    Ochiai       8  126                 970               0.0
# 970    Ochiai       8  126                 971               0.0
# 971    Ochiai       8  126                 972               0.0
# 972    Ochiai       8  126                 973               0.0
#
# [973 rows x 6 columns]
# math_整理結果Ochiai_math_v8
# 資料已寫入 math_整理結果Ochiai_math_v8 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v9_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai       9    1                  15          1.000000  錯誤找到
# 1       Ochiai       9    1                  16          1.000000
# 2       Ochiai       9    1                 105          1.000000
# 3       Ochiai       9    1                 146          1.000000
# 4       Ochiai       9    5                  17          0.316228
# ...        ...     ...  ...                 ...               ...   ...
# 2156    Ochiai       9  114                2157          0.000000
# 2157    Ochiai       9  114                2158          0.000000
# 2158    Ochiai       9  114                2159          0.000000
# 2159    Ochiai       9  114                2160          0.000000
# 2160    Ochiai       9  114                2161          0.000000
#
# [2161 rows x 6 columns]
# math_整理結果Ochiai_math_v9
# 資料已寫入 math_整理結果Ochiai_math_v9 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v10_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      10    1                1012               1.0
# 1       Ochiai      10    1                1013               1.0
# 2       Ochiai      10    1                1014               1.0
# 3       Ochiai      10    1                1015               1.0
# 4       Ochiai      10    1                1918               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2280    Ochiai      10  342                2281               0.0
# 2281    Ochiai      10  342                2282               0.0
# 2282    Ochiai      10  342                2283               0.0
# 2283    Ochiai      10  342                2284               0.0
# 2284    Ochiai      10  342                2285               0.0
#
# [2285 rows x 6 columns]
# math_整理結果Ochiai_math_v10
# 資料已寫入 math_整理結果Ochiai_math_v10 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v11_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      11    1                   4               1.0
# 1       Ochiai      11    1                   5               1.0
# 2       Ochiai      11    1                   8               1.0
# 3       Ochiai      11    1                   9               1.0
# 4       Ochiai      11    1                  10               1.0
# ...        ...     ...  ...                 ...               ... ..
# 7031    Ochiai      11  575                7032               0.0
# 7032    Ochiai      11  575                7033               0.0
# 7033    Ochiai      11  575                7034               0.0
# 7034    Ochiai      11  575                7035               0.0
# 7035    Ochiai      11  575                7036               0.0
#
# [7036 rows x 6 columns]
# math_整理結果Ochiai_math_v11
# 資料已寫入 math_整理結果Ochiai_math_v11 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v12_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      12    1                 524               1.0
# 1       Ochiai      12    1                 539               1.0
# 2       Ochiai      12    1                 540               1.0
# 3       Ochiai      12    1                 541               1.0
# 4       Ochiai      12    1                 542               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2386    Ochiai      12  446                2387               0.0
# 2387    Ochiai      12  446                2388               0.0
# 2388    Ochiai      12  446                2389               0.0
# 2389    Ochiai      12  446                2390               0.0
# 2390    Ochiai      12  446                2391               0.0
#
# [2391 rows x 6 columns]
# math_整理結果Ochiai_math_v12
# 資料已寫入 math_整理結果Ochiai_math_v12 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v13_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      13    1                6114               1.0
# 1       Ochiai      13    1                6115               1.0
# 2       Ochiai      13    1                6116               1.0
# 3       Ochiai      13    1                6119               1.0
# 4       Ochiai      13    1                6718               1.0
# ...        ...     ...  ...                 ...               ... ..
# 7550    Ochiai      13  207                7551               0.0
# 7551    Ochiai      13  207                7552               0.0
# 7552    Ochiai      13  207                7553               0.0
# 7553    Ochiai      13  207                7554               0.0
# 7554    Ochiai      13  207                7555               0.0
#
# [7555 rows x 6 columns]
# math_整理結果Ochiai_math_v13
# 資料已寫入 math_整理結果Ochiai_math_v13 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v14_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      14    1                   1               1.0
# 1       Ochiai      14    1                   2               1.0
# 2       Ochiai      14    1                   4               1.0
# 3       Ochiai      14    1                1945               1.0
# 4       Ochiai      14    1                1946               1.0
# ...        ...     ...  ...                 ...               ... ..
# 6611    Ochiai      14  168                6612               0.0
# 6612    Ochiai      14  168                6613               0.0
# 6613    Ochiai      14  168                6614               0.0
# 6614    Ochiai      14  168                6615               0.0
# 6615    Ochiai      14  168                6616               0.0
#
# [6616 rows x 6 columns]
# math_整理結果Ochiai_math_v14
# 資料已寫入 math_整理結果Ochiai_math_v14 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v15_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      15    1                 559          1.000000
# 1       Ochiai      15    2                1569          0.206284
# 2       Ochiai      15    2                1570          0.206284
# 3       Ochiai      15    2                1571          0.206284
# 4       Ochiai      15    2                1572          0.206284
# ...        ...     ...  ...                 ...               ... ..
# 2858    Ochiai      15  797                2771          0.000000
# 2859    Ochiai      15  797                2772          0.000000
# 2860    Ochiai      15  797                2773          0.000000
# 2861    Ochiai      15  797                2774          0.000000
# 2862    Ochiai      15  797                2863          0.000000
#
# [2863 rows x 6 columns]
# math_整理結果Ochiai_math_v15
# 資料已寫入 math_整理結果Ochiai_math_v15 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v16_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      16    1                1254          1.000000
# 1       Ochiai      16    1                1256          1.000000  錯誤找到
# 2       Ochiai      16    3                1475          0.935414
# 3       Ochiai      16    3                1478          0.935414
# 4       Ochiai      16    5                1257          0.797724  錯誤找到
# ...        ...     ...  ...                 ...               ...   ...
# 2845    Ochiai      16  706                2844          0.000000
# 2846    Ochiai      16  706                2845          0.000000
# 2847    Ochiai      16  706                2846          0.000000
# 2848    Ochiai      16  706                2847          0.000000
# 2849    Ochiai      16  706                2848          0.000000
#
# [2850 rows x 6 columns]
# math_整理結果Ochiai_math_v16
# 資料已寫入 math_整理結果Ochiai_math_v16 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v17_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      17    1                 719               1.0
# 1       Ochiai      17    1                 720               1.0
# 2       Ochiai      17    1                 721               1.0
# 3       Ochiai      17    1                 722               1.0
# 4       Ochiai      17    1                 723               1.0
# ...        ...     ...  ...                 ...               ... ..
# 1201    Ochiai      17  718                1192               0.0
# 1202    Ochiai      17  718                1193               0.0
# 1203    Ochiai      17  718                1194               0.0
# 1204    Ochiai      17  718                1195               0.0
# 1205    Ochiai      17  718                1196               0.0
#
# [1206 rows x 6 columns]
# math_整理結果Ochiai_math_v17
# 資料已寫入 math_整理結果Ochiai_math_v17 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v18_sus.txt
#      SBFL_Tool  bug_id   Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      18     1                4593          1.000000
# 1       Ochiai      18     1                4755          1.000000
# 2       Ochiai      18     1                4758          1.000000
# 3       Ochiai      18     4                4807          0.707107
# 4       Ochiai      18     4                4891          0.707107
# ...        ...     ...   ...                 ...               ... ..
# 7200    Ochiai      18  1112                7201          0.000000
# 7201    Ochiai      18  1112                7202          0.000000
# 7202    Ochiai      18  1112                7203          0.000000
# 7203    Ochiai      18  1112                7204          0.000000
# 7204    Ochiai      18  1112                7205          0.000000
#
# [7205 rows x 6 columns]
# math_整理結果Ochiai_math_v18
# 資料已寫入 math_整理結果Ochiai_math_v18 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v19_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      19    1                 579               1.0
# 1       Ochiai      19    1                 580               1.0
# 2       Ochiai      19    1                 581               1.0
# 3       Ochiai      19    1                 582               1.0
# 4       Ochiai      19    1                 587               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2809    Ochiai      19  669                2809               0.0
# 2810    Ochiai      19  669                2810               0.0
# 2811    Ochiai      19  669                2811               0.0
# 2812    Ochiai      19  669                2812               0.0
# 2813    Ochiai      19  669                2814               0.0
#
# [2814 rows x 6 columns]
# math_整理結果Ochiai_math_v19
# 資料已寫入 math_整理結果Ochiai_math_v19 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v20_sus.txt
#      SBFL_Tool  bug_id   Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      20     1                   1               1.0
# 1       Ochiai      20     1                   2               1.0
# 2       Ochiai      20     1                   3               1.0
# 3       Ochiai      20     1                   4               1.0
# 4       Ochiai      20     1                 150               1.0
# ...        ...     ...   ...                 ...               ... ..
# 7167    Ochiai      20  1065                7166               0.0
# 7168    Ochiai      20  1065                7167               0.0
# 7169    Ochiai      20  1065                7168               0.0
# 7170    Ochiai      20  1065                7169               0.0
# 7171    Ochiai      20  1065                7170               0.0
#
# [7172 rows x 6 columns]
# math_整理結果Ochiai_math_v20
# 資料已寫入 math_整理結果Ochiai_math_v20 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v21_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      21    1                 983               1.0
# 1       Ochiai      21    1                 984               1.0
# 2       Ochiai      21    1                 985               1.0
# 3       Ochiai      21    1                 986               1.0
# 4       Ochiai      21    1                 987               1.0
# ...        ...     ...  ...                 ...               ... ..
# 5385    Ochiai      21  215                5386               0.0
# 5386    Ochiai      21  215                5387               0.0
# 5387    Ochiai      21  215                5388               0.0
# 5388    Ochiai      21  215                5389               0.0
# 5389    Ochiai      21  215                5390               0.0
#
# [5390 rows x 6 columns]
# math_整理結果Ochiai_math_v21
# 資料已寫入 math_整理結果Ochiai_math_v21 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v22_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      22    1                1938          1.000000  錯誤找到
# 1       Ochiai      22    1                2040          1.000000  錯誤找到
# 2       Ochiai      22    3                 436          0.707107
# 3       Ochiai      22    4                1906          0.500000
# 4       Ochiai      22    4                1907          0.500000
# ...        ...     ...  ...                 ...               ...   ...
# 2305    Ochiai      22  293                2306          0.000000
# 2306    Ochiai      22  293                2307          0.000000
# 2307    Ochiai      22  293                2308          0.000000
# 2308    Ochiai      22  293                2309          0.000000
# 2309    Ochiai      22  293                2310          0.000000
#
# [2310 rows x 6 columns]
# math_整理結果Ochiai_math_v22
# 資料已寫入 math_整理結果Ochiai_math_v22 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v23_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      23    1                1537               1.0
# 1       Ochiai      23    1                1538               1.0
# 2       Ochiai      23    1                1539               1.0
# 3       Ochiai      23    1                1540               1.0
# 4       Ochiai      23    1                1541               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2348    Ochiai      23  305                2344               0.0
# 2349    Ochiai      23  305                2347               0.0
# 2350    Ochiai      23  305                2348               0.0
# 2351    Ochiai      23  305                2349               0.0
# 2352    Ochiai      23  305                2350               0.0
#
# [2353 rows x 6 columns]
# math_整理結果Ochiai_math_v23
# 資料已寫入 math_整理結果Ochiai_math_v23 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v24_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      24    1                 243               1.0
# 1       Ochiai      24    1                 244               1.0
# 2       Ochiai      24    1                 245               1.0
# 3       Ochiai      24    1                1777               1.0
# 4       Ochiai      24    1                1778               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2342    Ochiai      24  312                2343               0.0
# 2343    Ochiai      24  312                2344               0.0
# 2344    Ochiai      24  312                2345               0.0
# 2345    Ochiai      24  312                2346               0.0
# 2346    Ochiai      24  312                2347               0.0
#
# [2347 rows x 6 columns]
# math_整理結果Ochiai_math_v24
# 資料已寫入 math_整理結果Ochiai_math_v24 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v25_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      25    1                  70          1.000000  錯誤找到
# 1      Ochiai      25    1                  71          1.000000
# 2      Ochiai      25    3                   4          0.894427
# 3      Ochiai      25    3                   5          0.894427
# 4      Ochiai      25    3                   6          0.894427
# ..        ...     ...  ...                 ...               ...   ...
# 543    Ochiai      25   73                 544          0.000000
# 544    Ochiai      25   73                 545          0.000000
# 545    Ochiai      25   73                 546          0.000000
# 546    Ochiai      25   73                 547          0.000000
# 547    Ochiai      25   73                 548          0.000000
#
# [548 rows x 6 columns]
# math_整理結果Ochiai_math_v25
# 資料已寫入 math_整理結果Ochiai_math_v25 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v26_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      26    1                   3          1.000000
# 1       Ochiai      26    1                   4          1.000000
# 2       Ochiai      26    1                 114          1.000000
# 3       Ochiai      26    1                 133          1.000000
# 4       Ochiai      26    5                   7          0.707107
# ...        ...     ...  ...                 ...               ... ..
# 2351    Ochiai      26  449                2352          0.000000
# 2352    Ochiai      26  449                2353          0.000000
# 2353    Ochiai      26  449                2354          0.000000
# 2354    Ochiai      26  449                2355          0.000000
# 2355    Ochiai      26  449                2356          0.000000
#
# [2356 rows x 6 columns]
# math_整理結果Ochiai_math_v26
# 資料已寫入 math_整理結果Ochiai_math_v26 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v27_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      27    1                 168          1.000000  錯誤找到
# 1       Ochiai      27    2                 161          0.816497
# 2       Ochiai      27    3                 113          0.272166
# 3       Ochiai      27    4                  74          0.098533
# 4       Ochiai      27    4                  75          0.098533
# ...        ...     ...  ...                 ...               ...   ...
# 1940    Ochiai      27   67                1941          0.000000
# 1941    Ochiai      27   67                1942          0.000000
# 1942    Ochiai      27   67                1943          0.000000
# 1943    Ochiai      27   67                1944          0.000000
# 1944    Ochiai      27   67                1945          0.000000
#
# [1945 rows x 6 columns]
# math_整理結果Ochiai_math_v27
# 資料已寫入 math_整理結果Ochiai_math_v27 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v28_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      28    1                  35               1.0
# 1       Ochiai      28    1                  36               1.0
# 2       Ochiai      28    1                  37               1.0
# 3       Ochiai      28    1                  38               1.0
# 4       Ochiai      28    1                  39               1.0
# ...        ...     ...  ...                 ...               ... ..
# 5929    Ochiai      28  413                5930               0.0
# 5930    Ochiai      28  413                5931               0.0
# 5931    Ochiai      28  413                5932               0.0
# 5932    Ochiai      28  413                5933               0.0
# 5933    Ochiai      28  413                5934               0.0
#
# [5934 rows x 6 columns]
# math_整理結果Ochiai_math_v28
# 資料已寫入 math_整理結果Ochiai_math_v28 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v29_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      29    1                2468               1.0
# 1       Ochiai      29    1                2469               1.0
# 2       Ochiai      29    1                2470               1.0  錯誤找到
# 3       Ochiai      29    1                2471               1.0
# 4       Ochiai      29    1                2472               1.0
# ...        ...     ...  ...                 ...               ...   ...
# 3402    Ochiai      29  207                3403               0.0
# 3403    Ochiai      29  207                3404               0.0
# 3404    Ochiai      29  207                3405               0.0
# 3405    Ochiai      29  207                3406               0.0
# 3406    Ochiai      29  207                3407               0.0
#
# [3407 rows x 6 columns]
# math_整理結果Ochiai_math_v29
# 資料已寫入 math_整理結果Ochiai_math_v29 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v30_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      30    1                 387          1.000000
# 1       Ochiai      30    1                1875          1.000000
# 2       Ochiai      30    1                1876          1.000000
# 3       Ochiai      30    4                 376          0.707107
# 4       Ochiai      30    4                 377          0.707107
# ...        ...     ...  ...                 ...               ... ..
# 2703    Ochiai      30  350                2704          0.000000
# 2704    Ochiai      30  350                2705          0.000000
# 2705    Ochiai      30  350                2706          0.000000
# 2706    Ochiai      30  350                2707          0.000000
# 2707    Ochiai      30  350                2708          0.000000
#
# [2708 rows x 6 columns]
# math_整理結果Ochiai_math_v30
# 資料已寫入 math_整理結果Ochiai_math_v30 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v31_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      31    1                  47               1.0
# 1       Ochiai      31    1                  48               1.0
# 2       Ochiai      31    1                  49               1.0
# 3       Ochiai      31    1                  50               1.0
# 4       Ochiai      31    1                  55               1.0
# ...        ...     ...  ...                 ...               ... ..
# 3028    Ochiai      31  492                3024               0.0
# 3029    Ochiai      31  492                3027               0.0
# 3030    Ochiai      31  492                3028               0.0
# 3031    Ochiai      31  492                3031               0.0
# 3032    Ochiai      31  492                3032               0.0
#
# [3033 rows x 6 columns]
# math_整理結果Ochiai_math_v31
# 資料已寫入 math_整理結果Ochiai_math_v31 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v32_sus.txt
#      SBFL_Tool  bug_id   Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      32     1                2217               1.0
# 1       Ochiai      32     1                2218               1.0  錯誤找到
# 2       Ochiai      32     1                2315               1.0
# 3       Ochiai      32     1                2698               1.0
# 4       Ochiai      32     1                2699               1.0
# ...        ...     ...   ...                 ...               ...   ...
# 3925    Ochiai      32  1406                3914               0.0
# 3926    Ochiai      32  1406                3915               0.0
# 3927    Ochiai      32  1406                3916               0.0
# 3928    Ochiai      32  1406                3917               0.0
# 3929    Ochiai      32  1406                3918               0.0
#
# [3930 rows x 6 columns]
# math_整理結果Ochiai_math_v32
# 資料已寫入 math_整理結果Ochiai_math_v32 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v33_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      33    1                 201          1.000000
# 1       Ochiai      33    2                 151          0.816497
# 2       Ochiai      33    2                 152          0.816497
# 3       Ochiai      33    4                  92          0.632456
# 4       Ochiai      33    4                 120          0.632456
# ...        ...     ...  ...                 ...               ... ..
# 5751    Ochiai      33  407                5752          0.000000
# 5752    Ochiai      33  407                5753          0.000000
# 5753    Ochiai      33  407                5754          0.000000
# 5754    Ochiai      33  407                5755          0.000000
# 5755    Ochiai      33  407                5756          0.000000
#
# [5756 rows x 6 columns]
# math_整理結果Ochiai_math_v33
# 資料已寫入 math_整理結果Ochiai_math_v33 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v34_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      34    1                  32          1.000000
# 1      Ochiai      34    1                  33          1.000000
# 2      Ochiai      34    1                  55          1.000000  錯誤找到
# 3      Ochiai      34    4                  30          0.816497
# 4      Ochiai      34    5                 116          0.471405
# ..        ...     ...  ...                 ...               ...   ...
# 183    Ochiai      34   34                 184          0.000000
# 184    Ochiai      34   34                 185          0.000000
# 185    Ochiai      34   34                 186          0.000000
# 186    Ochiai      34   34                 187          0.000000
# 187    Ochiai      34   34                 188          0.000000
#
# [188 rows x 6 columns]
# math_整理結果Ochiai_math_v34
# 資料已寫入 math_整理結果Ochiai_math_v34 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v35_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai      35    1                  49          1.000000
# 1      Ochiai      35    2                   1          0.774597
# 2      Ochiai      35    2                   2          0.774597
# 3      Ochiai      35    2                   4          0.774597
# 4      Ochiai      35    2                   6          0.774597
# ..        ...     ...  ...                 ...               ... ..
# 512    Ochiai      35   19                 513          0.000000
# 513    Ochiai      35   19                 514          0.000000
# 514    Ochiai      35   19                 515          0.000000
# 515    Ochiai      35   19                 516          0.000000
# 516    Ochiai      35   19                 517          0.000000
#
# [517 rows x 6 columns]
# math_整理結果Ochiai_math_v35
# 資料已寫入 math_整理結果Ochiai_math_v35 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v36_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      36    1                 230          1.000000  錯誤找到
# 1      Ochiai      36    1                 231          1.000000  錯誤找到
# 2      Ochiai      36    3                  35          0.324443
# 3      Ochiai      36    3                  37          0.324443
# 4      Ochiai      36    3                  73          0.324443
# ..        ...     ...  ...                 ...               ...   ...
# 638    Ochiai      36  359                 639          0.000000
# 639    Ochiai      36  359                 640          0.000000
# 640    Ochiai      36  359                 641          0.000000
# 641    Ochiai      36  359                 642          0.000000
# 642    Ochiai      36  359                 643          0.000000
#
# [643 rows x 6 columns]
# math_整理結果Ochiai_math_v36
# 資料已寫入 math_整理結果Ochiai_math_v36 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v37_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      37    1                  54          1.000000
# 1       Ochiai      37    1                  85          1.000000
# 2       Ochiai      37    1                1709          1.000000
# 3       Ochiai      37    1                1711          1.000000
# 4       Ochiai      37    5                1678          0.816497  錯誤找到
# ...        ...     ...  ...                 ...               ...   ...
# 1740    Ochiai      37  264                1741          0.000000
# 1741    Ochiai      37  264                1742          0.000000
# 1742    Ochiai      37  264                1743          0.000000
# 1743    Ochiai      37  264                1744          0.000000
# 1744    Ochiai      37  264                1745          0.000000
#
# [1745 rows x 6 columns]
# math_整理結果Ochiai_math_v37
# 資料已寫入 math_整理結果Ochiai_math_v37 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v38_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      38    1                  62               1.0
# 1       Ochiai      38    1                  63               1.0
# 2       Ochiai      38    1                 809               1.0
# 3       Ochiai      38    1                 810               1.0
# 4       Ochiai      38    1                 811               1.0
# ...        ...     ...  ...                 ...               ... ..
# 5089    Ochiai      38  292                5090               0.0
# 5090    Ochiai      38  292                5091               0.0
# 5091    Ochiai      38  292                5092               0.0
# 5092    Ochiai      38  292                5093               0.0
# 5093    Ochiai      38  292                5094               0.0
#
# [5094 rows x 6 columns]
# math_整理結果Ochiai_math_v38
# 資料已寫入 math_整理結果Ochiai_math_v38 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v39_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      39    1                1414               1.0
# 1       Ochiai      39    1                1416               1.0
# 2       Ochiai      39    1                1418               1.0
# 3       Ochiai      39    1                1420               1.0
# 4       Ochiai      39    1                1421               1.0
# ...        ...     ...  ...                 ...               ... ..
# 2455    Ochiai      39  514                2456               0.0
# 2456    Ochiai      39  514                2457               0.0
# 2457    Ochiai      39  514                2458               0.0
# 2458    Ochiai      39  514                2459               0.0
# 2459    Ochiai      39  514                2460               0.0
#
# [2460 rows x 6 columns]
# math_整理結果Ochiai_math_v39
# 資料已寫入 math_整理結果Ochiai_math_v39 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v40_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      40    1                  22          1.000000
# 1       Ochiai      40    1                  23          1.000000
# 2       Ochiai      40    3                   1          0.707107
# 3       Ochiai      40    3                   2          0.707107
# 4       Ochiai      40    3                   3          0.707107
# ...        ...     ...  ...                 ...               ... ..
# 2009    Ochiai      40  184                2010          0.000000
# 2010    Ochiai      40  184                2011          0.000000
# 2011    Ochiai      40  184                2012          0.000000
# 2012    Ochiai      40  184                2013          0.000000
# 2013    Ochiai      40  184                2014          0.000000
#
# [2014 rows x 6 columns]
# math_整理結果Ochiai_math_v40
# 資料已寫入 math_整理結果Ochiai_math_v40 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v41_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      41    1                1737          1.000000
# 1       Ochiai      41    2                1619          0.816497
# 2       Ochiai      41    2                1620          0.816497
# 3       Ochiai      41    2                1622          0.816497
# 4       Ochiai      41    2                1624          0.816497
# ...        ...     ...  ...                 ...               ... ..
# 1870    Ochiai      41  117                1871          0.000000
# 1871    Ochiai      41  117                1872          0.000000
# 1872    Ochiai      41  117                1873          0.000000
# 1873    Ochiai      41  117                1874          0.000000
# 1874    Ochiai      41  117                1875          0.000000
#
# [1875 rows x 6 columns]
# math_整理結果Ochiai_math_v41
# 資料已寫入 math_整理結果Ochiai_math_v41 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v42_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      42    1                3839          1.000000
# 1       Ochiai      42    2                3815          0.968246
# 2       Ochiai      42    2                4012          0.968246
# 3       Ochiai      42    4                1705          0.939336
# 4       Ochiai      42    4                1706          0.939336
# ...        ...     ...  ...                 ...               ... ..
# 5774    Ochiai      42  377                5775          0.000000
# 5775    Ochiai      42  377                5776          0.000000
# 5776    Ochiai      42  377                5777          0.000000
# 5777    Ochiai      42  377                5778          0.000000
# 5778    Ochiai      42  377                5779          0.000000
#
# [5779 rows x 6 columns]
# math_整理結果Ochiai_math_v42
# 資料已寫入 math_整理結果Ochiai_math_v42 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v43_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      43    1                1770          1.000000
# 1       Ochiai      43    2                1768          0.912871
# 2       Ochiai      43    3                1757          0.745356
# 3       Ochiai      43    3                1758          0.745356
# 4       Ochiai      43    3                1759          0.745356
# ...        ...     ...  ...                 ...               ... ..
# 2296    Ochiai      43  339                2297          0.000000
# 2297    Ochiai      43  339                2298          0.000000
# 2298    Ochiai      43  339                2299          0.000000
# 2299    Ochiai      43  339                2300          0.000000
# 2300    Ochiai      43  339                2301          0.000000
#
# [2301 rows x 6 columns]
# math_整理結果Ochiai_math_v43
# 資料已寫入 math_整理結果Ochiai_math_v43 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v44_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      44    1                 378          1.000000
# 1       Ochiai      44    1                 380          1.000000
# 2       Ochiai      44    1                 381          1.000000
# 3       Ochiai      44    1                 390          1.000000
# 4       Ochiai      44    5                2368          0.654654
# ...        ...     ...  ...                 ...               ... ..
# 2889    Ochiai      44  818                2884          0.000000
# 2890    Ochiai      44  818                2885          0.000000
# 2891    Ochiai      44  818                2886          0.000000
# 2892    Ochiai      44  818                2887          0.000000
# 2893    Ochiai      44  818                2888          0.000000
#
# [2894 rows x 6 columns]
# math_整理結果Ochiai_math_v44
# 資料已寫入 math_整理結果Ochiai_math_v44 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v45_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      45    1                1105               1.0  錯誤找到
# 1       Ochiai      45    1                1106               1.0  錯誤找到
# 2       Ochiai      45    1                1107               1.0  錯誤找到
# 3       Ochiai      45    1                1108               1.0  錯誤找到
# 4       Ochiai      45    1                1109               1.0
# ...        ...     ...  ...                 ...               ...   ...
# 1541    Ochiai      45   11                1542               0.0
# 1542    Ochiai      45   11                1543               0.0
# 1543    Ochiai      45   11                1544               0.0
# 1544    Ochiai      45   11                1545               0.0
# 1545    Ochiai      45   11                1546               0.0
#
# [1546 rows x 6 columns]
# math_整理結果Ochiai_math_v45
# 資料已寫入 math_整理結果Ochiai_math_v45 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v46_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      46    1                  42          1.000000  錯誤找到
# 1       Ochiai      46    1                 178          1.000000
# 2       Ochiai      46    3                 105          0.577350
# 3       Ochiai      46    4                  41          0.516398
# 4       Ochiai      46    5                 103          0.500000
# ...        ...     ...  ...                 ...               ...   ...
# 2673    Ochiai      46  353                2674          0.000000
# 2674    Ochiai      46  353                2675          0.000000
# 2675    Ochiai      46  353                2676          0.000000
# 2676    Ochiai      46  353                2677          0.000000
# 2677    Ochiai      46  353                2678          0.000000
#
# [2678 rows x 6 columns]
# math_整理結果Ochiai_math_v46
# 資料已寫入 math_整理結果Ochiai_math_v46 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v47_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      47    1                2676          1.000000
# 1       Ochiai      47    2                2540          0.707107  錯誤找到
# 2       Ochiai      47    3                2032          0.500000
# 3       Ochiai      47    3                2034          0.500000
# 4       Ochiai      47    5                2603          0.408248
# ...        ...     ...  ...                 ...               ...   ...
# 2672    Ochiai      47  403                2672          0.000000
# 2673    Ochiai      47  403                2673          0.000000
# 2674    Ochiai      47  403                2674          0.000000
# 2675    Ochiai      47  403                2675          0.000000
# 2676    Ochiai      47  403                2677          0.000000
#
# [2677 rows x 6 columns]
# math_整理結果Ochiai_math_v47
# 資料已寫入 math_整理結果Ochiai_math_v47 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v48_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      48    1                  36               1.0
# 1       Ochiai      48    1                  37               1.0
# 2       Ochiai      48    1                  39               1.0
# 3       Ochiai      48    1                  40               1.0
# 4       Ochiai      48    1                  41               1.0
# ...        ...     ...  ...                 ...               ... ..
# 3164    Ochiai      48  743                3157               0.0
# 3165    Ochiai      48  743                3158               0.0
# 3166    Ochiai      48  743                3159               0.0
# 3167    Ochiai      48  743                3161               0.0
# 3168    Ochiai      48  743                3164               0.0
#
# [3169 rows x 6 columns]
# math_整理結果Ochiai_math_v48
# 資料已寫入 math_整理結果Ochiai_math_v48 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v49_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      49    1                  53          1.000000
# 1       Ochiai      49    1                  54          1.000000
# 2       Ochiai      49    1                1904          1.000000
# 3       Ochiai      49    4                1985          0.707107
# 4       Ochiai      49    4                2678          0.707107
# ...        ...     ...  ...                 ...               ... ..
# 3240    Ochiai      49  425                3241          0.000000
# 3241    Ochiai      49  425                3242          0.000000
# 3242    Ochiai      49  425                3243          0.000000
# 3243    Ochiai      49  425                3244          0.000000
# 3244    Ochiai      49  425                3245          0.000000
#
# [3245 rows x 6 columns]
# math_整理結果Ochiai_math_v49
# 資料已寫入 math_整理結果Ochiai_math_v49 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v50_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      50    1                  97          1.000000  錯誤找到
# 1       Ochiai      50    1                  98          1.000000  錯誤找到
# 2       Ochiai      50    3                 116          0.408248
# 3       Ochiai      50    4                  96          0.377964  錯誤找到
# 4       Ochiai      50    5                 259          0.333333
# ...        ...     ...  ...                 ...               ...   ...
# ...
# 216    Ochiai      94   22                 217          0.000000
# 217    Ochiai      94   22                 218          0.000000
# 218    Ochiai      94   22                 219          0.000000
# 219    Ochiai      94   22                 220          0.000000
# 220    Ochiai      94   22                 221          0.000000
#
# [221 rows x 6 columns]
# math_整理結果Ochiai_math_v94
# 資料已寫入 math_整理結果Ochiai_math_v94 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v95_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai      95    1                  76           1.00000
# 1      Ochiai      95    2                  63           0.57735
# 2      Ochiai      95    2                  70           0.57735
# 3      Ochiai      95    2                  71           0.57735
# 4      Ochiai      95    2                  73           0.57735
# ..        ...     ...  ...                 ...               ... ..
# 446    Ochiai      95   97                 431           0.00000
# 447    Ochiai      95   97                 433           0.00000
# 448    Ochiai      95   97                 435           0.00000
# 449    Ochiai      95   97                 439           0.00000
# 450    Ochiai      95   97                 441           0.00000
#
# [451 rows x 6 columns]
# math_整理結果Ochiai_math_v95
# 資料已寫入 math_整理結果Ochiai_math_v95 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v96_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      96    1                  58          1.000000
# 1      Ochiai      96    1                  60          1.000000
# 2      Ochiai      96    3                  69          0.316228
# 3      Ochiai      96    4                  67          0.288675
# 4      Ochiai      96    5                  53          0.258199  錯誤找到
# ..        ...     ...  ...                 ...               ...   ...
# 123    Ochiai      96   25                 123          0.000000
# 124    Ochiai      96   25                 124          0.000000
# 125    Ochiai      96   25                 125          0.000000
# 126    Ochiai      96   25                 126          0.000000
# 127    Ochiai      96   25                 127          0.000000
#
# [128 rows x 6 columns]
# math_整理結果Ochiai_math_v96
# 資料已寫入 math_整理結果Ochiai_math_v96 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v97_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      97    1                 101          1.000000  錯誤找到
# 1      Ochiai      97    1                 187          1.000000
# 2      Ochiai      97    3                 116          0.485071
# 3      Ochiai      97    3                 117          0.485071
# 4      Ochiai      97    5                 109          0.384900
# ..        ...     ...  ...                 ...               ...   ...
# 213    Ochiai      97   49                 214          0.000000
# 214    Ochiai      97   49                 215          0.000000
# 215    Ochiai      97   49                 216          0.000000
# 216    Ochiai      97   49                 217          0.000000
# 217    Ochiai      97   49                 218          0.000000
#
# [218 rows x 6 columns]
# math_整理結果Ochiai_math_v97
# 資料已寫入 math_整理結果Ochiai_math_v97 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v98_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      98    1                 310               1.0
# 1      Ochiai      98    1                 312               1.0
# 2      Ochiai      98    1                 313               1.0
# 3      Ochiai      98    1                 314               1.0  錯誤找到
# 4      Ochiai      98    1                 315               1.0
# ..        ...     ...  ...                 ...               ...   ...
# 914    Ochiai      98   61                 915               0.0
# 915    Ochiai      98   61                 916               0.0
# 916    Ochiai      98   61                 917               0.0
# 917    Ochiai      98   61                 918               0.0
# 918    Ochiai      98   61                 919               0.0
#
# [919 rows x 6 columns]
# math_整理結果Ochiai_math_v98
# 資料已寫入 math_整理結果Ochiai_math_v98 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v99_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      99    1                 205          1.000000
# 1      Ochiai      99    1                 206          1.000000
# 2      Ochiai      99    1                 207          1.000000  錯誤找到
# 3      Ochiai      99    1                 208          1.000000  錯誤找到
# 4      Ochiai      99    5                 179          0.371391
# ..        ...     ...  ...                 ...               ...   ...
# 320    Ochiai      99   32                 321          0.000000
# 321    Ochiai      99   32                 322          0.000000
# 322    Ochiai      99   32                 323          0.000000
# 323    Ochiai      99   32                 324          0.000000
# 324    Ochiai      99   32                 325          0.000000
#
# [325 rows x 6 columns]
# math_整理結果Ochiai_math_v99
# 資料已寫入 math_整理結果Ochiai_math_v99 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v100_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai     100    1                 541               1.0
# 1      Ochiai     100    1                 542               1.0
# 2      Ochiai     100    1                 543               1.0
# 3      Ochiai     100    1                 544               1.0
# 4      Ochiai     100    1                 545               1.0
# ..        ...     ...  ...                 ...               ... ..
# 626    Ochiai     100  233                 563               0.0
# 627    Ochiai     100  233                 564               0.0
# 628    Ochiai     100  233                 571               0.0
# 629    Ochiai     100  233                 626               0.0
# 630    Ochiai     100  233                 627               0.0
#
# [631 rows x 6 columns]
# math_整理結果Ochiai_math_v100
# 資料已寫入 math_整理結果Ochiai_math_v100 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v101_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai     101    1                  73          1.000000
# 1      Ochiai     101    1                  74          1.000000
# 2      Ochiai     101    3                   1          0.935414
# 3      Ochiai     101    3                   2          0.935414
# 4      Ochiai     101    3                  45          0.935414
# ..        ...     ...  ...                 ...               ... ..
# 135    Ochiai     101   64                 126          0.000000
# 136    Ochiai     101   64                 128          0.000000
# 137    Ochiai     101   64                 130          0.000000
# 138    Ochiai     101   64                 134          0.000000
# 139    Ochiai     101   64                 138          0.000000
#
# [140 rows x 6 columns]
# math_整理結果Ochiai_math_v101
# 資料已寫入 math_整理結果Ochiai_math_v101 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v102_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai     102    1                 412               1.0
# 1      Ochiai     102    1                 414               1.0
# 2      Ochiai     102    1                 416               1.0  錯誤找到
# 3      Ochiai     102    1                 417               1.0
# 4      Ochiai     102    1                 418               1.0
# ..        ...     ...  ...                 ...               ...   ...
# 924    Ochiai     102  206                 925               0.0
# 925    Ochiai     102  206                 926               0.0
# 926    Ochiai     102  206                 927               0.0
# 927    Ochiai     102  206                 928               0.0
# 928    Ochiai     102  206                 929               0.0
#
# [929 rows x 6 columns]
# math_整理結果Ochiai_math_v102
# 資料已寫入 math_整理結果Ochiai_math_v102 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v103_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai     103    1                  38               1.0
# 1      Ochiai     103    1                  39               1.0
# 2      Ochiai     103    1                  40               1.0
# 3      Ochiai     103    1                  41               1.0
# 4      Ochiai     103    1                  42               1.0
# ..        ...     ...  ...                 ...               ... ..
# 233    Ochiai     103   76                 230               0.0
# 234    Ochiai     103   76                 231               0.0
# 235    Ochiai     103   76                 232               0.0
# 236    Ochiai     103   76                 233               0.0
# 237    Ochiai     103   76                 234               0.0
#
# [238 rows x 6 columns]
# math_整理結果Ochiai_math_v103
# 資料已寫入 math_整理結果Ochiai_math_v103 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v104_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai     104    1                 159          1.000000
# 1      Ochiai     104    2                 124          0.518875
# 2      Ochiai     104    2                 125          0.518875
# 3      Ochiai     104    2                 126          0.518875
# 4      Ochiai     104    2                 164          0.518875
# ..        ...     ...  ...                 ...               ... ..
# 164    Ochiai     104   63                 147          0.000000
# 165    Ochiai     104   63                 156          0.000000
# 166    Ochiai     104   63                 161          0.000000
# 167    Ochiai     104   63                 163          0.000000
# 168    Ochiai     104   63                 165          0.000000
#
# [169 rows x 6 columns]
# math_整理結果Ochiai_math_v104
# 資料已寫入 math_整理結果Ochiai_math_v104 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v105_sus.txt
#    SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0     Ochiai     105    1                   1               1.0
# 1     Ochiai     105    1                   2               1.0
# 2     Ochiai     105    1                   3               1.0
# 3     Ochiai     105    1                   4               1.0
# 4     Ochiai     105    1                   5               1.0
# ..       ...     ...  ...                 ...               ... ..
# 63    Ochiai     105   26                  64               0.0
# 64    Ochiai     105   26                  65               0.0
# 65    Ochiai     105   26                  66               0.0
# 66    Ochiai     105   26                  67               0.0
# 67    Ochiai     105   26                  68               0.0
#
# [68 rows x 6 columns]
# math_整理結果Ochiai_math_v105
# 資料已寫入 math_整理結果Ochiai_math_v105 文件中
# 懷疑值檔案 懷疑值source/Math/old/Ochiai_v106_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai     106    1                 100               1.0
# 1      Ochiai     106    1                 101               1.0
# 2      Ochiai     106    1                 102               1.0
# 3      Ochiai     106    1                 167               1.0  錯誤找到
# 4      Ochiai     106    1                 168               1.0
# ..        ...     ...  ...                 ...               ...   ...
# 182    Ochiai     106   73                 173               0.0
# 183    Ochiai     106   73                 174               0.0
# 184    Ochiai     106   73                 178               0.0
# 185    Ochiai     106   73                 179               0.0
# 186    Ochiai     106   73                 185               0.0
#
# [187 rows x 6 columns]
# math_整理結果Ochiai_math_v106
# 資料已寫入 math_整理結果Ochiai_math_v106 文件中
# [['錯誤index: 70, Top位置: 12', '錯誤index: 314, Top位置: 12', '錯誤index: 69, Top位置: 33', '錯誤index: 313, Top位置: 405'], ['錯誤index: 1563, Top位置: 38'], ['錯誤index: 286, Top位置: 1', '錯誤index: 288, Top位置: 1'], ['錯誤index: 2114, Top位置: 1', '錯誤index: 2115, Top位置: 1', '錯誤index: 2885, Top位置: 1', '錯誤index: 2886, Top位置: 1'], ['錯誤index: 63, Top位置: 1'], ['錯誤index: 1979, Top位置: 109', '錯誤index: 1980, Top位置: 109', '錯誤index: 195, Top位置: 1167', '錯誤index: 1712, Top位置: 1226', '錯誤index: 1721, Top位置: 1226', '錯誤index: 1631, Top位置: 1567', '錯誤index: 1632, Top位置: 1567', '錯誤index: 1504, Top位置: 1751', '錯誤index: 1506, Top位置: 1751', '錯誤index: 1511, Top位置: 1751', '錯誤index: 1538, Top位置: 1751', '錯誤index: 1410, Top位置: 2332', '錯誤index: 1379, Top位置: 2511', '錯誤index: 1381, Top位置: 2511', '錯誤index: 325, Top位置: 2585', '錯誤index: 327, Top位置: 2585', '錯誤index: 425, Top位置: 2785', '錯誤index: 1654, Top位置: 2785'], ['錯誤index: 1819, Top位置: 40', '錯誤index: 1814, Top位置: 45', '錯誤index: 1803, Top位置: 95', '錯誤index: 1804, Top位置: 95', '錯誤index: 1810, Top位置: 987', '錯誤index: 1811, Top位置: 987', '錯誤index: 1812, Top位置: 987', '錯誤index: 1820, Top位置: 987', '錯誤index: 1821, Top位置: 987'], ['錯誤index: 533, Top位置: 1'], ['錯誤index: 15, Top位置: 1'], ['錯誤index: 1929, Top位置: 1', '錯誤index: 1935, Top位置: 342'], ['錯誤index: 100, Top位置: 29'], [], ['錯誤index: 6258, Top位置: 69', '錯誤index: 6259, Top位置: 207'], ['錯誤index: 2064, Top位置: 83', '錯誤index: 2065, Top位置: 168', '錯誤index: 2066, Top位置: 168', '錯誤index: 2120, Top位置: 168', '錯誤index: 2121, Top位置: 168'], ['錯誤index: 558, Top位置: 43'], ['錯誤index: 1256, Top位置: 1', '錯誤index: 1257, Top位置: 5', '錯誤index: 1259, Top位置: 5', '錯誤index: 1258, Top位置: 638', '錯誤index: 1287, Top位置: 706', '錯誤index: 1288, Top位置: 706', '錯誤index: 1289, Top位置: 706', '錯誤index: 1290, Top位置: 706'], ['錯誤index: 759, Top位置: 82'], ['錯誤index: 4549, Top位置: 10', '錯誤index: 4557, Top位置: 10', '錯誤index: 4568, Top位置: 1112', '錯誤index: 4570, Top位置: 1112'], ['錯誤index: 300, Top位置: 56', '錯誤index: 302, Top位置: 526'], ['錯誤index: 597, Top位置: 296'], ['錯誤index: 3494, Top位置: 38', '錯誤index: 3500, Top位置: 38', '錯誤index: 3503, Top位置: 38', '錯誤index: 3504, Top位置: 38', '錯誤index: 3505, Top位置: 38', '錯誤index: 3506, Top位置: 38', '錯誤index: 3507, Top位置: 38', '錯誤index: 3508, Top位置: 38', '錯誤index: 3509, Top位置: 38', '錯誤index: 3522, Top位置: 38', '錯誤index: 3526, Top位置: 38'], ['錯誤index: 1938, Top位置: 1', '錯誤index: 2040, Top位置: 1'], ['錯誤index: 2338, Top位置: 148', '錯誤index: 2312, Top位置: 158', '錯誤index: 2313, Top位置: 158', '錯誤index: 2315, Top位置: 305'], ['錯誤index: 114, Top位置: 149', '錯誤index: 91, Top位置: 312'], ['錯誤index: 70, Top位置: 1'], ['錯誤index: 132, Top位置: 25', '錯誤index: 113, Top位置: 44'], ['錯誤index: 168, Top位置: 1'], ['錯誤index: 5633, Top位置: 13', '錯誤index: 5632, Top位置: 28', '錯誤index: 5626, Top位置: 33', '錯誤index: 5625, Top位置: 134'], ['錯誤index: 2470, Top位置: 1', '錯誤index: 2473, Top位置: 1', '錯誤index: 2462, Top位置: 61', '錯誤index: 2463, Top位置: 61', '錯誤index: 2464, Top位置: 61', '錯誤index: 2465, Top位置: 61'], ['錯誤index: 2446, Top位置: 4'], ['錯誤index: 648, Top位置: 103', '錯誤index: 649, Top位置: 103', '錯誤index: 650, Top位置: 103', '錯誤index: 651, Top位置: 103', '錯誤index: 652, Top位置: 103', '錯誤index: 613, Top位置: 193', '錯誤index: 614, Top位置: 193', '錯誤index: 620, Top位置: 193', '錯誤index: 621, Top位置: 193', '錯誤index: 622, Top位置: 193', '錯誤index: 640, Top位置: 193', '錯誤index: 641, Top位置: 193', '錯誤index: 657, Top位置: 486', '錯誤index: 623, Top位置: 492', '錯誤index: 624, Top位置: 492', '錯誤index: 625, Top位置: 492', '錯誤index: 626, Top位置: 492', '錯誤index: 627, Top位置: 492', '錯誤index: 628, Top位置: 492', '錯誤index: 629, Top位置: 492', '錯誤index: 630, Top位置: 492', '錯誤index: 631, Top位置: 492', '錯誤index: 632, Top位置: 492', '錯誤index: 633, Top位置: 492', '錯誤index: 634, Top位置: 492', '錯誤index: 635, Top位置: 492', '錯誤index: 636, Top位置: 492', '錯誤index: 637, Top位置: 492', '錯誤index: 638, Top位置: 492', '錯誤index: 639, Top位置: 492'], ['錯誤index: 2218, Top位置: 1'], ['錯誤index: 119, Top位置: 21'], ['錯誤index: 55, Top位置: 1'], ['錯誤index: 50, Top位置: 2', '錯誤index: 53, Top位置: 11'], ['錯誤index: 230, Top位置: 1', '錯誤index: 231, Top位置: 1', '錯誤index: 220, Top位置: 357', '錯誤inde ...

# %%
# # 創建 DataFrame
# df = pd.DataFrame(data)
# print(df)

# %%
# import openpyxl

# wb = openpyxl.Workbook() #建立空的excel
# #wb = openpyxl.load_workbook('oxxo.xlsx') #開啟excel
# wb.save( Excel_name + '.xlsx')

# %%
# # 將資料寫入 Excel 檔案
# file_name = Excel_name + '.xlsx'
# df.to_excel(file_name, index=False)

# print(f"資料已寫入 {file_name} 文件中")

# %%
# print(Project_bugid_faultStatement[0])
# print(Project_bugid_faultStatement[0][0])
# print(Project_bugid_faultStatement[1])
# print(Project_bugid_faultStatement[1][0])
# print(Project_bugid_faultStatement[1][1])

# %%
print(bug_id_rank[0][0])
print(bug_id_rank[0][0].split(', '))
print(bug_id_rank[0][0].split(', ')[0].split(' ')[1])
print(bug_id_rank[0][0].split(', ')[1].split(' ')[1])
print(bug_id_rank[0][0].split(': '))
# Out:
# 錯誤index: 70, Top位置: 12
# ['錯誤index: 70', 'Top位置: 12']
# 70
# 12
# ['錯誤index', '70, Top位置', '12']

# %%
# 初始化 DataFrame
df = pd.DataFrame(columns=['ID', 'Index', 'Top'])

# 遍歷每個元素,並解析出 Index 和 Top 值
for i in range(0,project_bugid_num):  
    for j in range(0,len(bug_id_rank[i])):
        index = int(bug_id_rank[i][j].split(', ')[0].split(' ')[1])
        top = int(bug_id_rank[i][j].split(', ')[1].split(' ')[1])
        df.loc[len(df)] = [i+1, index, top]

print(df)

# 輸出 Excel 表格
df.to_excel( Excel_save_path + '/' + Project + '_report.xlsx', index=False)
print('Excel 表格已生成: ' + Project + '_report.xlsx')
# Out:
#       ID  Index  Top
# 0      1     70   12
# 1      1    314   12
# 2      1     69   33
# 3      1    313  405
# 4      2   1563   38
# ..   ...    ...  ...
# 369  105     44    1
# 370  106    167    1
# 371  106    177    1
# 372  106    182    1
# 373  106    164   15
#
# [374 rows x 3 columns]
# Excel 表格已生成: math_report.xlsx
