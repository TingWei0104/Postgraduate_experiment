# %%
import pandas as pd
import openpyxl
# 變數設定，目的在於其他的project只要修改這部分就好了
Project = 'chart'
Project2 = 'Chart'
project_bugid_num = 26
#SBFL_tool = 'Ample'
Excel_name = 'chart_整理結果'
Excel_save_path = 'chart_result'

# 這是要放要拿來使用的絕對路徑
# unsort_data_path = 'Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old'
unsort_data_path = '懷疑值source/' + Project2 + '/old'

SBFL_all = ["Ochiai"]

# %%
# 取得project的每一個bug-id有多少行的方法。
SBFL_fault_statement_number = []
project_statement_file = 'project_line/' + Project +'_line.txt'

# 使用 with 語句打開文件，確保文件在使用後自動關閉
with open(project_statement_file, 'r', encoding='utf-8') as file:
    project_lines = file.readlines()  # 讀取所有行

# 去掉每行末尾的換行符
project_lines = [int(line.strip()) for line in project_lines] # 順便將str轉為數字
print(project_lines)

max_line = max(project_lines) # 找出最大行數，用於後續輸出使用
print(max_line)
# Out:
# [7057, 1328, 840, 25163, 284, 676, 481, 195, 953, 53, 193, 4361, 886, 6315, 12107, 298, 1074, 392, 4493, 517, 595, 246, 4655, 25, 10879, 20672]
# 25163

# %%
# get_fault_statement
#動態產生二微陣列的方法
Project_bugid_faultStatement = []

for i in range(0,project_bugid_num):
    fault_statement_file_path = '錯誤位置/'+ Project + '/' + Project2 +'_v' + str(i+1) + '_FaultStatement.txt'
    print(fault_statement_file_path)

    # 使用 with 語句打開文件，確保文件在使用後自動關閉
    with open(fault_statement_file_path, 'r', encoding='utf-8') as file:
        lines2 = file.readlines()  # 讀取所有行

    # 去掉每行末尾的換行符
    lines2 = [line.strip() for line in lines2]
    print(lines2)

    lines2 = lines2[0].split()
    print(len(lines2))

    Project_bugid_faultStatement.append([])
    for j in range(0,len(lines2)):
        Project_bugid_faultStatement[i].append(int(lines2[j])) # 順便將str轉為數字

print(Project_bugid_faultStatement)
# Out:
# 錯誤位置/chart/Chart_v1_FaultStatement.txt
# ['2436']
# 1
# 錯誤位置/chart/Chart_v2_FaultStatement.txt
# ['182 183 184 185 186 187 379 380 381 382 383 384']
# 12
# 錯誤位置/chart/Chart_v3_FaultStatement.txt
# ['663 664 665']
# 3
# 錯誤位置/chart/Chart_v4_FaultStatement.txt
# ['10472']
# 1
# 錯誤位置/chart/Chart_v5_FaultStatement.txt
# ['162 163 164']
# 3
# 錯誤位置/chart/Chart_v6_FaultStatement.txt
# ['267']
# 1
# 錯誤位置/chart/Chart_v7_FaultStatement.txt
# ['276 277']
# 2
# 錯誤位置/chart/Chart_v8_FaultStatement.txt
# ['54']
# 1
# 錯誤位置/chart/Chart_v9_FaultStatement.txt
# ['797']
# 1
# 錯誤位置/chart/Chart_v10_FaultStatement.txt
# ['53']
# 1
# 錯誤位置/chart/Chart_v11_FaultStatement.txt
# ['67']
# 1
# 錯誤位置/chart/Chart_v12_FaultStatement.txt
# ['79']
# 1
# 錯誤位置/chart/Chart_v13_FaultStatement.txt
# ['361']
# 1
# 錯誤位置/chart/Chart_v14_FaultStatement.txt
# ['1400 1401 1473 1474 3740 3741 3823 3824']
# 8
# 錯誤位置/chart/Chart_v15_FaultStatement.txt
# ['4726 4727 4850 4851']
# 4
# 錯誤位置/chart/Chart_v16_FaultStatement.txt
# ['37 38 70']
# 3
# 錯誤位置/chart/Chart_v17_FaultStatement.txt
# ['268']
# 1
# 錯誤位置/chart/Chart_v18_FaultStatement.txt
# ['226 227 228 229 230 332 337']
# 7
# 錯誤位置/chart/Chart_v19_FaultStatement.txt
# ['1526 1596']
# 2
# 錯誤位置/chart/Chart_v20_FaultStatement.txt
# ['6']
# 1
# 錯誤位置/chart/Chart_v21_FaultStatement.txt
# ['270 399 400 401']
# 4
# 錯誤位置/chart/Chart_v22_FaultStatement.txt
# ['33 35 66 70 71 82']
# 6
# 錯誤位置/chart/Chart_v23_FaultStatement.txt
# ['0']
# 1
# 錯誤位置/chart/Chart_v24_FaultStatement.txt
# ['13']
# 1
# 錯誤位置/chart/Chart_v25_FaultStatement.txt
# ['10003 10004 10038 9936 9937 9971']
# 6
# 錯誤位置/chart/Chart_v26_FaultStatement.txt
# ['3908 3909']
# 2
# [[2436], [182, 183, 184, 185, 186, 187, 379, 380, 381, 382, 383, 384], [663, 664, 665], [10472], [162, 163, 164], [267], [276, 277], [54], [797], [53], [67], [79], [361], [1400, 1401, 1473, 1474, 3740, 3741, 3823, 3824], [4726, 4727, 4850, 4851], [37, 38, 70], [268], [226, 227, 228, 229, 230, 332, 337], [1526, 1596], [6], [270, 399, 400, 401], [33, 35, 66, 70, 71, 82], [0], [13], [10003, 10004, 10038, 9936, 9937, 9971], [3908, 3909]]

# %%
# #要存成的excel index有甚麼
# data = {
#     'SBFL_Tool': [],
#     'Top': [],
#     'Spectra_file_index': [],
#     'Suspicious_Value': []
# }

# %%
#動態產生二微陣列的方法
bug_id_rank = []

for SBFL_index, SBFL_a in enumerate(SBFL_all):
    
    
    for i in range(0,project_bugid_num):   

        # 要存成的excel index有甚麼
        # 因為每次一個for迴圈就會要新的df，所以每次都要重新定義，保證能清空前一個錯誤版本的資料
        data = {
        'SBFL_Tool': [],
        'bug_id': [],
        'Top': [],
        'Spectra_file_index': [],
        'Suspicious_Value': [],
        '錯誤': []
        }

        # 後續記錄用
        # 紀錄不同錯誤版本用於SBFL後，錯誤在哪個排名
        bug_id_rank.append([])

        file_path = unsort_data_path + '/' + SBFL_a + '_v' + str(i+1) + '_sus.txt' #使用絕對路徑
        print("懷疑值檔案", file_path)

        # 使用 with 語句打開文件，確保文件在使用後自動關閉
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()  # 讀取所有行

        # 去掉每行末尾的換行符
        lines = [line.strip() for line in lines]

        # 轉換為float，以及處理例外的問題。
        numbers = []
        for line in lines:
            try:
                number = float(line.strip())
            except ValueError:  # 捕獲轉換錯誤
                print("抓到非數字!")
                number = 0  # 將無法轉換的值設為0
            numbers.append(number)


        # 將列表中的元素和其索引配對，用於表示的幾個statement
        indexed_list = list(enumerate(numbers))

        # 取出最大的數字
        max_prob = max(indexed_list)
        count = numbers.count(max_prob)

        # 將列表中的元素和其索引配對,索引從1開始
        indexed_list = [(i+1, numbers) for i, numbers in enumerate(numbers)]

        # 找出前 XX 名（若列表長度小於 XX，則返回所有元素）
        # top_test = sorted(indexed_list, key=lambda x: x[1], reverse=True)[:max_line]

        # 找出前 200 名（若列表長度小於 200，則返回所有元素），因為全部都存起來，excel會爆炸，所以改成200名就好了。
        #top_test = sorted(indexed_list, key=lambda x: x[1], reverse=True)[:200]

        # 因為不需要前200名，所以取全部。
        top_test = sorted(indexed_list, key=lambda x: x[1], reverse=True)

        Now_top = 0 # 用於紀錄top用的
        previous_rank_sus = '' #表示與前一個rank的懷疑質做比較做比較
        count_top = 0

        for index, value in top_test:

            #用於處理計算Top使用----
            count_top += 1
            if value != previous_rank_sus:
                #Now_top = Now_top
                #Now_top += 1
                Now_top = count_top
            else:
                Now_top = Now_top
            #----------------------
            
            # 標示錯誤位置用
            flag = 0
            for faultStatement_index in range(0,len(Project_bugid_faultStatement[i])): # 檢查這一行有沒有存在正確的錯誤位置(Project_bugid_faultStatement)裡面。
                if index == Project_bugid_faultStatement[i][faultStatement_index]:
                    bug_id_rank[i].append("錯誤index: " + str(index) + ", Top位置: " + str(Now_top)) # 順便將str轉為數字
                    flag = 1
                    break

            previous_rank_sus = value
            data['SBFL_Tool'].append(SBFL_a)
            data['bug_id'].append(i+1)
            data['Top'].append(Now_top)
            data['Spectra_file_index'].append(index)
            data['Suspicious_Value'].append(value)
            if  flag == 1:
                data['錯誤'].append("錯誤找到")
            elif flag == 0:
                data['錯誤'].append(" ")

        # 創建 DataFrame
        df = pd.DataFrame(data)
        print(df)

        save_excel_file_name = Excel_name + SBFL_a + '_' + Project + '_v' + str(i+1)
        print(save_excel_file_name)
        wb = openpyxl.Workbook() #建立空的excel
        #wb = openpyxl.load_workbook('oxxo.xlsx') #開啟excel
        wb.save( Excel_save_path + '/' + save_excel_file_name + '.xlsx')

        # # 將資料寫入 Excel 檔案
        file_name = Excel_save_path + '/' + save_excel_file_name + '.xlsx'
        df.to_excel(Excel_save_path + '/' + save_excel_file_name + '.xlsx', index=False)

        print(f"資料已寫入 {save_excel_file_name} 文件中")


print(bug_id_rank)
# Out:
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v1_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai       1    1                2433          1.000000
# 1       Ochiai       1    2                3747          0.447214
# 2       Ochiai       1    2                3748          0.447214
# 3       Ochiai       1    4                3753          0.353553
# 4       Ochiai       1    4                3754          0.353553
# ...        ...     ...  ...                 ...               ... ..
# 7052    Ochiai       1  630                7053          0.000000
# 7053    Ochiai       1  630                7054          0.000000
# 7054    Ochiai       1  630                7055          0.000000
# 7055    Ochiai       1  630                7056          0.000000
# 7056    Ochiai       1  630                7057          0.000000
#
# [7057 rows x 6 columns]
# chart_整理結果Ochiai_chart_v1
# 資料已寫入 chart_整理結果Ochiai_chart_v1 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v2_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai       2    1                1045               1.0
# 1       Ochiai       2    1                1046               1.0
# 2       Ochiai       2    1                1105               1.0
# 3       Ochiai       2    1                1106               1.0
# 4       Ochiai       2    1                1107               1.0
# ...        ...     ...  ...                 ...               ... ..
# 1323    Ochiai       2  163                1324               0.0
# 1324    Ochiai       2  163                1325               0.0
# 1325    Ochiai       2  163                1326               0.0
# 1326    Ochiai       2  163                1327               0.0
# 1327    Ochiai       2  163                1328               0.0
#
# [1328 rows x 6 columns]
# chart_整理結果Ochiai_chart_v2
# 資料已寫入 chart_整理結果Ochiai_chart_v2 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v3_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai       3    1                 659               1.0
# 1      Ochiai       3    1                 661               1.0
# 2      Ochiai       3    1                 663               1.0  錯誤找到
# 3      Ochiai       3    1                 664               1.0  錯誤找到
# 4      Ochiai       3    1                 665               1.0  錯誤找到
# ..        ...     ...  ...                 ...               ...   ...
# 835    Ochiai       3  144                 831               0.0
# 836    Ochiai       3  144                 832               0.0
# 837    Ochiai       3  144                 838               0.0
# 838    Ochiai       3  144                 839               0.0
# 839    Ochiai       3  144                 840               0.0
#
# [840 rows x 6 columns]
# chart_整理結果Ochiai_chart_v3
# 資料已寫入 chart_整理結果Ochiai_chart_v3 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v4_sus.txt
#       SBFL_Tool  bug_id   Top  Spectra_file_index  Suspicious_Value 錯誤
# 0        Ochiai       4     1               10468          1.000000
# 1        Ochiai       4     1               23659          1.000000
# 2        Ochiai       4     3               24313          0.909091
# 3        Ochiai       4     3               24314          0.909091
# 4        Ochiai       4     3               24888          0.909091
# ...         ...     ...   ...                 ...               ... ..
# 25158    Ochiai       4  2372               25159          0.000000
# 25159    Ochiai       4  2372               25160          0.000000
# 25160    Ochiai       4  2372               25161          0.000000
# 25161    Ochiai       4  2372               25162          0.000000
# 25162    Ochiai       4  2372               25163          0.000000
#
# [25163 rows x 6 columns]
# chart_整理結果Ochiai_chart_v4
# 資料已寫入 chart_整理結果Ochiai_chart_v4 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v5_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai       5    1                 159          1.000000
# 1      Ochiai       5    1                 173          1.000000
# 2      Ochiai       5    3                 172          0.816497
# 3      Ochiai       5    3                 175          0.816497
# 4      Ochiai       5    5                 160          0.707107
# ..        ...     ...  ...                 ...               ... ..
# 279    Ochiai       5   52                 280          0.000000
# 280    Ochiai       5   52                 281          0.000000
# 281    Ochiai       5   52                 282          0.000000
# 282    Ochiai       5   52                 283          0.000000
# 283    Ochiai       5   52                 284          0.000000
#
# [284 rows x 6 columns]
# chart_整理結果Ochiai_chart_v5
# 資料已寫入 chart_整理結果Ochiai_chart_v5 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v6_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai       6    1                 268               1.0
# 1      Ochiai       6    1                 273               1.0
# 2      Ochiai       6    1                 274               1.0
# 3      Ochiai       6    1                 275               1.0
# 4      Ochiai       6    1                 276               1.0
# ..        ...     ...  ...                 ...               ... ..
# 671    Ochiai       6  128                 672               0.0
# 672    Ochiai       6  128                 673               0.0
# 673    Ochiai       6  128                 674               0.0
# 674    Ochiai       6  128                 675               0.0
# 675    Ochiai       6  128                 676               0.0
#
# [676 rows x 6 columns]
# chart_整理結果Ochiai_chart_v6
# 資料已寫入 chart_整理結果Ochiai_chart_v6 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v7_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai       7    1                 365          1.000000
# 1      Ochiai       7    2                 258          0.632456
# 2      Ochiai       7    2                 272          0.632456
# 3      Ochiai       7    2                 286          0.632456
# 4      Ochiai       7    5                 434          0.534522
# ..        ...     ...  ...                 ...               ... ..
# 476    Ochiai       7  124                 475          0.000000
# 477    Ochiai       7  124                 476          0.000000
# 478    Ochiai       7  124                 477          0.000000
# 479    Ochiai       7  124                 478          0.000000
# 480    Ochiai       7  124                 479          0.000000
#
# [481 rows x 6 columns]
# chart_整理結果Ochiai_chart_v7
# 資料已寫入 chart_整理結果Ochiai_chart_v7 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v8_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai       8    1                  54               1.0  錯誤找到
# 1      Ochiai       8    1                  55               1.0
# 2      Ochiai       8    1                  56               1.0
# 3      Ochiai       8    1                  57               1.0
# 4      Ochiai       8    1                  59               1.0
# ..        ...     ...  ...                 ...               ...   ...
# 190    Ochiai       8   49                 191               0.0
# 191    Ochiai       8   49                 192               0.0
# 192    Ochiai       8   49                 193               0.0
# 193    Ochiai       8   49                 194               0.0
# 194    Ochiai       8   49                 195               0.0
#
# [195 rows x 6 columns]
# chart_整理結果Ochiai_chart_v8
# 資料已寫入 chart_整理結果Ochiai_chart_v8 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v9_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai       9    1                 769               1.0
# 1      Ochiai       9    1                 781               1.0
# 2      Ochiai       9    1                 783               1.0
# 3      Ochiai       9    1                 785               1.0
# 4      Ochiai       9    1                 787               1.0
# ..        ...     ...  ...                 ...               ... ..
# 948    Ochiai       9  195                 949               0.0
# 949    Ochiai       9  195                 950               0.0
# 950    Ochiai       9  195                 951               0.0
# 951    Ochiai       9  195                 952               0.0
# 952    Ochiai       9  195                 953               0.0
#
# [953 rows x 6 columns]
# chart_整理結果Ochiai_chart_v9
# 資料已寫入 chart_整理結果Ochiai_chart_v9 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v10_sus.txt
#    SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0     Ochiai      10    1                  51               1.0
# 1     Ochiai      10    1                  52               1.0
# 2     Ochiai      10    1                  53               1.0  錯誤找到
# 3     Ochiai      10    4                   1               0.0
# 4     Ochiai      10    4                   2               0.0
# 5     Ochiai      10    4                   3               0.0
# 6     Ochiai      10    4                   4               0.0
# 7     Ochiai      10    4                   5               0.0
# 8     Ochiai      10    4                   6               0.0
# 9     Ochiai      10    4                   7               0.0
# 10    Ochiai      10    4                   8               0.0
# 11    Ochiai      10    4                   9               0.0
# 12    Ochiai      10    4                  10               0.0
# 13    Ochiai      10    4                  11               0.0
# 14    Ochiai      10    4                  12               0.0
# 15    Ochiai      10    4                  13               0.0
# 16    Ochiai      10    4                  14               0.0
# 17    Ochiai      10    4                  15               0.0
# 18    Ochiai      10    4                  16               0.0
# 19    Ochiai      10    4                  17               0.0
# 20    Ochiai      10    4                  18               0.0
# 21    Ochiai      10    4                  19               0.0
# 22    Ochiai      10    4                  20               0.0
# 23    Ochiai      10    4                  21               0.0
# 24    Ochiai      10    4                  22               0.0
# 25    Ochiai      10    4                  23               0.0
# 26    Ochiai      10    4                  24               0.0
# 27    Ochiai      10    4                  25               0.0
# 28    Ochiai      10    4                  26               0.0
# 29    Ochiai      10    4                  27               0.0
# 30    Ochiai      10    4                  28               0.0
# 31    Ochiai      10    4                  29               0.0
# 32    Ochiai      10    4                  30               0.0
# 33    Ochiai      10    4                  31               0.0
# 34    Ochiai      10    4                  32               0.0
# 35    Ochiai      10    4                  33               0.0
# 36    Ochiai      10    4                  34               0.0
# 37    Ochiai      10    4                  35               0.0
# 38    Ochiai      10    4                  36               0.0
# 39    Ochiai      10    4                  37               0.0
# 40    Ochiai      10    4                  38               0.0
# 41    Ochiai      10    4                  39               0.0
# 42    Ochiai      10    4                  40               0.0
# 43    Ochiai      10    4                  41               0.0
# 44    Ochiai      10    4                  42               0.0
# 45    Ochiai      10    4                  43               0.0
# 46    Ochiai      10    4                  44               0.0
# 47    Ochiai      10    4                  45               0.0
# 48    Ochiai      10    4                  46               0.0
# 49    Ochiai      10    4                  47               0.0
# 50    Ochiai      10    4                  48               0.0
# 51    Ochiai      10    4                  49               0.0
# 52    Ochiai      10    4                  50               0.0
# chart_整理結果Ochiai_chart_v10
# 資料已寫入 chart_整理結果Ochiai_chart_v10 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v11_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      11    1                  60               1.0
# 1      Ochiai      11    1                  62               1.0
# 2      Ochiai      11    1                  64               1.0
# 3      Ochiai      11    1                  66               1.0
# 4      Ochiai      11    1                  67               1.0  錯誤找到
# ..        ...     ...  ...                 ...               ...   ...
# 188    Ochiai      11   21                 189               0.0
# 189    Ochiai      11   21                 190               0.0
# 190    Ochiai      11   21                 191               0.0
# 191    Ochiai      11   21                 192               0.0
# 192    Ochiai      11   21                 193               0.0
#
# [193 rows x 6 columns]
# chart_整理結果Ochiai_chart_v11
# 資料已寫入 chart_整理結果Ochiai_chart_v11 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v12_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      12    1                  92           1.00000
# 1       Ochiai      12    2                  75           0.57735
# 2       Ochiai      12    2                  76           0.57735
# 3       Ochiai      12    2                4342           0.57735
# 4       Ochiai      12    2                4343           0.57735
# ...        ...     ...  ...                 ...               ... ..
# 4356    Ochiai      12  536                4357           0.00000
# 4357    Ochiai      12  536                4358           0.00000
# 4358    Ochiai      12  536                4359           0.00000
# 4359    Ochiai      12  536                4360           0.00000
# 4360    Ochiai      12  536                4361           0.00000
#
# [4361 rows x 6 columns]
# chart_整理結果Ochiai_chart_v12
# 資料已寫入 chart_整理結果Ochiai_chart_v12 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v13_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai      13    1                   1               1.0
# 1      Ochiai      13    1                   2               1.0
# 2      Ochiai      13    1                  71               1.0
# 3      Ochiai      13    1                  72               1.0
# 4      Ochiai      13    1                 206               1.0
# ..        ...     ...  ...                 ...               ... ..
# 881    Ochiai      13  265                 882               0.0
# 882    Ochiai      13  265                 883               0.0
# 883    Ochiai      13  265                 884               0.0
# 884    Ochiai      13  265                 885               0.0
# 885    Ochiai      13  265                 886               0.0
#
# [886 rows x 6 columns]
# chart_整理結果Ochiai_chart_v13
# 資料已寫入 chart_整理結果Ochiai_chart_v13 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v14_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      14    1                1394               1.0
# 1       Ochiai      14    1                1395               1.0
# 2       Ochiai      14    1                1396               1.0
# 3       Ochiai      14    1                1397               1.0
# 4       Ochiai      14    1                1398               1.0
# ...        ...     ...  ...                 ...               ... ..
# 6310    Ochiai      14  520                6311               0.0
# 6311    Ochiai      14  520                6312               0.0
# 6312    Ochiai      14  520                6313               0.0
# 6313    Ochiai      14  520                6314               0.0
# 6314    Ochiai      14  520                6315               0.0
#
# [6315 rows x 6 columns]
# chart_整理結果Ochiai_chart_v14
# 資料已寫入 chart_整理結果Ochiai_chart_v14 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v15_sus.txt
#       SBFL_Tool  bug_id   Top  Spectra_file_index  Suspicious_Value 錯誤
# 0        Ochiai      15     1                5101          1.000000
# 1        Ochiai      15     1               11598          1.000000
# 2        Ochiai      15     3                4596          0.707107
# 3        Ochiai      15     3                4735          0.707107
# 4        Ochiai      15     3                4739          0.707107
# ...         ...     ...   ...                 ...               ... ..
# 12102    Ochiai      15  1121               12103          0.000000
# 12103    Ochiai      15  1121               12104          0.000000
# 12104    Ochiai      15  1121               12105          0.000000
# 12105    Ochiai      15  1121               12106          0.000000
# 12106    Ochiai      15  1121               12107          0.000000
#
# [12107 rows x 6 columns]
# chart_整理結果Ochiai_chart_v15
# 資料已寫入 chart_整理結果Ochiai_chart_v15 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v16_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      16    1                  37          1.000000  錯誤找到
# 1      Ochiai      16    1                  38          1.000000  錯誤找到
# 2      Ochiai      16    3                   3          0.816497
# 3      Ochiai      16    3                   4          0.816497
# 4      Ochiai      16    3                   5          0.816497
# ..        ...     ...  ...                 ...               ...   ...
# 293    Ochiai      16   48                 294          0.000000
# 294    Ochiai      16   48                 295          0.000000
# 295    Ochiai      16   48                 296          0.000000
# 296    Ochiai      16   48                 297          0.000000
# 297    Ochiai      16   48                 298          0.000000
#
# [298 rows x 6 columns]
# chart_整理結果Ochiai_chart_v16
# 資料已寫入 chart_整理結果Ochiai_chart_v16 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v17_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      17    1                 273          1.000000
# 1       Ochiai      17    2                 268          0.816497  錯誤找到
# 2       Ochiai      17    3                 270          0.632456
# 3       Ochiai      17    3                 272          0.632456
# 4       Ochiai      17    5                  69          0.426401
# ...        ...     ...  ...                 ...               ...   ...
# 1069    Ochiai      17  100                1070          0.000000
# 1070    Ochiai      17  100                1071          0.000000
# 1071    Ochiai      17  100                1072          0.000000
# 1072    Ochiai      17  100                1073          0.000000
# 1073    Ochiai      17  100                1074          0.000000
#
# [1074 rows x 6 columns]
# chart_整理結果Ochiai_chart_v17
# 資料已寫入 chart_整理結果Ochiai_chart_v17 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v18_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      18    1                 330               1.0
# 1      Ochiai      18    1                 331               1.0
# 2      Ochiai      18    1                 332               1.0  錯誤找到
# 3      Ochiai      18    1                 334               1.0
# 4      Ochiai      18    1                 335               1.0
# ..        ...     ...  ...                 ...               ...   ...
# 387    Ochiai      18   96                 388               0.0
# 388    Ochiai      18   96                 389               0.0
# 389    Ochiai      18   96                 390               0.0
# 390    Ochiai      18   96                 391               0.0
# 391    Ochiai      18   96                 392               0.0
#
# [392 rows x 6 columns]
# chart_整理結果Ochiai_chart_v18
# 資料已寫入 chart_整理結果Ochiai_chart_v18 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v19_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0       Ochiai      19    1                1526               1.0  錯誤找到
# 1       Ochiai      19    1                1596               1.0  錯誤找到
# 2       Ochiai      19    1                1597               1.0
# 3       Ochiai      19    1                1598               1.0
# 4       Ochiai      19    1                1599               1.0
# ...        ...     ...  ...                 ...               ...   ...
# 4488    Ochiai      19  730                4489               0.0
# 4489    Ochiai      19  730                4490               0.0
# 4490    Ochiai      19  730                4491               0.0
# 4491    Ochiai      19  730                4492               0.0
# 4492    Ochiai      19  730                4493               0.0
#
# [4493 rows x 6 columns]
# chart_整理結果Ochiai_chart_v19
# 資料已寫入 chart_整理結果Ochiai_chart_v19 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v20_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0      Ochiai      20    1                  60          1.000000
# 1      Ochiai      20    2                  54          0.430331
# 2      Ochiai      20    3                  48          0.408248
# 3      Ochiai      20    4                   9          0.401610
# 4      Ochiai      20    5                   6          0.229416  錯誤找到
# ..        ...     ...  ...                 ...               ...   ...
# 512    Ochiai      20   78                 513          0.000000
# 513    Ochiai      20   78                 514          0.000000
# 514    Ochiai      20   78                 515          0.000000
# 515    Ochiai      20   78                 516          0.000000
# 516    Ochiai      20   78                 517          0.000000
#
# [517 rows x 6 columns]
# chart_整理結果Ochiai_chart_v20
# 資料已寫入 chart_整理結果Ochiai_chart_v20 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v21_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai      21    1                 281               1.0
# 1      Ochiai      21    1                 282               1.0
# 2      Ochiai      21    1                 283               1.0
# 3      Ochiai      21    1                 466               1.0
# 4      Ochiai      21    1                 475               1.0
# ..        ...     ...  ...                 ...               ... ..
# 590    Ochiai      21  132                 591               0.0
# 591    Ochiai      21  132                 592               0.0
# 592    Ochiai      21  132                 593               0.0
# 593    Ochiai      21  132                 594               0.0
# 594    Ochiai      21  132                 595               0.0
#
# [595 rows x 6 columns]
# chart_整理結果Ochiai_chart_v21
# 資料已寫入 chart_整理結果Ochiai_chart_v21 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v22_sus.txt
#     SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0      Ochiai      22    1                 125          1.000000
# 1      Ochiai      22    1                 126          1.000000
# 2      Ochiai      22    3                  76          0.707107
# 3      Ochiai      22    3                  77          0.707107
# 4      Ochiai      22    3                  79          0.707107
# ..        ...     ...  ...                 ...               ... ..
# 241    Ochiai      22  118                 242          0.000000
# 242    Ochiai      22  118                 243          0.000000
# 243    Ochiai      22  118                 244          0.000000
# 244    Ochiai      22  118                 245          0.000000
# 245    Ochiai      22  118                 246          0.000000
#
# [246 rows x 6 columns]
# chart_整理結果Ochiai_chart_v22
# 資料已寫入 chart_整理結果Ochiai_chart_v22 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v23_sus.txt
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value 錯誤
# 0       Ochiai      23    1                2874               1.0
# 1       Ochiai      23    1                2875               1.0
# 2       Ochiai      23    1                2876               1.0
# 3       Ochiai      23    1                3918               1.0
# 4       Ochiai      23    1                3919               1.0
# ...        ...     ...  ...                 ...               ... ..
# 4650    Ochiai      23  282                4651               0.0
# 4651    Ochiai      23  282                4652               0.0
# 4652    Ochiai      23  282                4653               0.0
# 4653    Ochiai      23  282                4654               0.0
# 4654    Ochiai      23  282                4655               0.0
#
# [4655 rows x 6 columns]
# chart_整理結果Ochiai_chart_v23
# 資料已寫入 chart_整理結果Ochiai_chart_v23 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v24_sus.txt
#    SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value    錯誤
# 0     Ochiai      24    1                  11          1.000000
# 1     Ochiai      24    1                  12          1.000000
# 2     Ochiai      24    1                  13          1.000000  錯誤找到
# 3     Ochiai      24    1                  14          1.000000
# 4     Ochiai      24    5                   1          0.333333
# 5     Ochiai      24    5                   2          0.333333
# 6     Ochiai      24    7                   3          0.316228
# 7     Ochiai      24    7                   4          0.316228
# 8     Ochiai      24    7                   6          0.316228
# 9     Ochiai      24    7                   7          0.316228
# 10    Ochiai      24    7                   8          0.316228
# 11    Ochiai      24   12                   5          0.000000
# 12    Ochiai      24   12                   9          0.000000
# 13    Ochiai      24   12                  10          0.000000
# 14    Ochiai      24   12                  15          0.000000
# 15    Ochiai      24   12                  16          0.000000
# 16    Ochiai      24   12                  17          0.000000
# 17    Ochiai      24   12                  18          0.000000
# 18    Ochiai      24   12                  19          0.000000
# 19    Ochiai      24   12                  20          0.000000
# 20    Ochiai      24   12                  21          0.000000
# 21    Ochiai      24   12                  22          0.000000
# 22    Ochiai      24   12                  23          0.000000
# 23    Ochiai      24   12                  24          0.000000
# 24    Ochiai      24   12                  25          0.000000
# chart_整理結果Ochiai_chart_v24
# 資料已寫入 chart_整理結果Ochiai_chart_v24 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v25_sus.txt
#       SBFL_Tool  bug_id   Top  Spectra_file_index  Suspicious_Value 錯誤
# 0        Ochiai      25     1                   1               1.0
# 1        Ochiai      25     1                   2               1.0
# 2        Ochiai      25     1                   3               1.0
# 3        Ochiai      25     1                   4               1.0
# 4        Ochiai      25     1                   5               1.0
# ...         ...     ...   ...                 ...               ... ..
# 10874    Ochiai      25  3365               10875               0.0
# 10875    Ochiai      25  3365               10876               0.0
# 10876    Ochiai      25  3365               10877               0.0
# 10877    Ochiai      25  3365               10878               0.0
# 10878    Ochiai      25  3365               10879               0.0
#
# [10879 rows x 6 columns]
# chart_整理結果Ochiai_chart_v25
# 資料已寫入 chart_整理結果Ochiai_chart_v25 文件中
# 懷疑值檔案 懷疑值source/Chart/old/Ochiai_v26_sus.txt
#       SBFL_Tool  bug_id   Top  Spectra_file_index  Suspicious_Value 錯誤
# 0        Ochiai      26     1                8951          1.000000
# 1        Ochiai      26     2                3646          0.957427
# 2        Ochiai      26     2                4829          0.957427
# 3        Ochiai      26     2                4831          0.957427
# 4        Ochiai      26     2                4833          0.957427
# ...         ...     ...   ...                 ...               ... ..
# 20667    Ochiai      26  5589               20668          0.000000
# 20668    Ochiai      26  5589               20669          0.000000
# 20669    Ochiai      26  5589               20670          0.000000
# 20670    Ochiai      26  5589               20671          0.000000
# 20671    Ochiai      26  5589               20672          0.000000
#
# [20672 rows x 6 columns]
# chart_整理結果Ochiai_chart_v26
# 資料已寫入 chart_整理結果Ochiai_chart_v26 文件中
# [['錯誤index: 2436, Top位置: 31'], ['錯誤index: 379, Top位置: 88', '錯誤index: 380, Top位置: 88', '錯誤index: 381, Top位置: 88', '錯誤index: 383, Top位置: 88', '錯誤index: 182, Top位置: 98', '錯誤index: 183, Top位置: 98', '錯誤index: 184, Top位置: 98', '錯誤index: 186, Top位置: 98', '錯誤index: 185, Top位置: 163', '錯誤index: 187, Top位置: 163', '錯誤index: 382, Top位置: 163', '錯誤index: 384, Top位置: 163'], ['錯誤index: 663, Top位置: 1', '錯誤index: 664, Top位置: 1', '錯誤index: 665, Top位置: 1'], ['錯誤index: 10472, Top位置: 167'], ['錯誤index: 162, Top位置: 5', '錯誤index: 163, Top位置: 5', '錯誤index: 164, Top位置: 5'], ['錯誤index: 267, Top位置: 55'], ['錯誤index: 276, Top位置: 40', '錯誤index: 277, Top位置: 40'], ['錯誤index: 54, Top位置: 1'], ['錯誤index: 797, Top位置: 1'], ['錯誤index: 53, Top位置: 1'], ['錯誤index: 67, Top位置: 1'], ['錯誤index: 79, Top位置: 6'], ['錯誤index: 361, Top位置: 1'], ['錯誤index: 1400, Top位置: 1', '錯誤index: 1473, Top位置: 1', '錯誤index: 3740, Top位置: 1', '錯誤index: 3823, Top位置: 1', '錯誤index: 1401, Top位置: 520', '錯誤index: 1474, Top位置: 520', '錯誤index: 3741, Top位置: 520', '錯誤index: 3824, Top位置: 520'], ['錯誤index: 4850, Top位置: 26', '錯誤index: 4726, Top位置: 1121', '錯誤index: 4727, Top位置: 1121', '錯誤index: 4851, Top位置: 1121'], ['錯誤index: 37, Top位置: 1', '錯誤index: 38, Top位置: 1', '錯誤index: 70, Top位置: 33'], ['錯誤index: 268, Top位置: 2'], ['錯誤index: 332, Top位置: 1', '錯誤index: 337, Top位置: 9', '錯誤index: 226, Top位置: 10', '錯誤index: 227, Top位置: 10', '錯誤index: 228, Top位置: 10', '錯誤index: 229, Top位置: 10', '錯誤index: 230, Top位置: 10'], ['錯誤index: 1526, Top位置: 1', '錯誤index: 1596, Top位置: 1'], ['錯誤index: 6, Top位置: 5'], ['錯誤index: 399, Top位置: 6', '錯誤index: 400, Top位置: 6', '錯誤index: 401, Top位置: 6', '錯誤index: 270, Top位置: 30'], ['錯誤index: 82, Top位置: 3', '錯誤index: 66, Top位置: 45', '錯誤index: 70, Top位置: 45', '錯誤index: 71, Top位置: 45', '錯誤index: 33, Top位置: 75', '錯誤index: 35, Top位置: 75'], [], ['錯誤index: 13, Top位置: 1'], ['錯誤index: 9936, Top位置: 2807', '錯誤index: 9937, Top位置: 2807', '錯誤index: 9971, Top位置: 2807', '錯誤index: 10003, Top位置: 3175', '錯誤index: 10004, Top位置: 3175', '錯誤index: 10038, Top位置: 3175'], ['錯誤index: 3908, Top位置: 133', '錯誤index: 3909, Top位置: 133']]

# %%
# # 創建 DataFrame
# df = pd.DataFrame(data)
# print(df)

# %%
# import openpyxl

# wb = openpyxl.Workbook() #建立空的excel
# #wb = openpyxl.load_workbook('oxxo.xlsx') #開啟excel
# wb.save( Excel_name + '.xlsx')

# %%
# # 將資料寫入 Excel 檔案
# file_name = Excel_name + '.xlsx'
# df.to_excel(file_name, index=False)

# print(f"資料已寫入 {file_name} 文件中")

# %%
print(Project_bugid_faultStatement[0])
print(Project_bugid_faultStatement[0][0])
print(Project_bugid_faultStatement[1])
print(Project_bugid_faultStatement[1][0])
print(Project_bugid_faultStatement[1][1])
# Out:
# [2436]
# 2436
# [182, 183, 184, 185, 186, 187, 379, 380, 381, 382, 383, 384]
# 182
# 183

# %%
print(bug_id_rank[0][0])
print(bug_id_rank[0][0].split(', '))
print(bug_id_rank[0][0].split(', ')[0].split(' ')[1])
print(bug_id_rank[0][0].split(', ')[1].split(' ')[1])
print(bug_id_rank[0][0].split(': '))
# Out:
# 錯誤index: 2436, Top位置: 31
# ['錯誤index: 2436', 'Top位置: 31']
# 2436
# 31
# ['錯誤index', '2436, Top位置', '31']

# %%
# 初始化 DataFrame
df = pd.DataFrame(columns=['ID', 'Index', 'Top'])

# 遍歷每個元素,並解析出 Index 和 Top 值
for i in range(0,project_bugid_num):  
    for j in range(0,len(bug_id_rank[i])):
        index = int(bug_id_rank[i][j].split(', ')[0].split(' ')[1])
        top = int(bug_id_rank[i][j].split(', ')[1].split(' ')[1])
        df.loc[len(df)] = [i+1, index, top]

print(df)

# 輸出 Excel 表格
df.to_excel( Excel_save_path + '/' + Project + '_report.xlsx', index=False)
print('Excel 表格已生成: ' + Project + '_report.xlsx')
# Out:
#     ID  Index   Top
# 0    1   2436    31
# 1    2    379    88
# 2    2    380    88
# 3    2    381    88
# 4    2    383    88
# ..  ..    ...   ...
# 69  25  10003  3175
# 70  25  10004  3175
# 71  25  10038  3175
# 72  26   3908   133
# 73  26   3909   133
#
# [74 rows x 3 columns]
# Excel 表格已生成: chart_report.xlsx
