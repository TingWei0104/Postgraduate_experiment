# %% [markdown]
# 這個程式主要來將整理出來的top檔案，分類出真正的fault statement有沒有在top-1、3、5、10

# %%
# 變數設定，目的在於其他的project只要修改這部分就好了
Project = 'time'
Project2 = 'Time'
project_bugid_num = 27
# SBFL_tool = 'Ample'

# 這是要放要拿來使用的絕對路徑
# 這是已經整理的top多少
data_path = 'Z:/廷偉/偉/研究所/未來實驗用的資料-重要要留好/20241105-整理學長資料用/time_result'
# SBFL_index = 27
SBFL_all = [
    "Ample",
    "Anderberg",
    "ArithmeticMean",
    "BaroniUrbaniBuser",
    "BraunBanqust",
    "Cohen",
    "Dennis",
    "Dice",
    "Dstar",
    "Euclid",
    "Fleiss",
    "Fossum",
    "Goodman",
    "Gower",
    "GP13",
    "Hamann",
    "Hamming",
    "HarmonicMean",
    "Jaccard",
    #"Kulczynski", # Lang沒有，考慮其他的也不要用。
    "Kulczynski1",
    "Kulczynskil2",
    "M1",
    "M2",
    "Michael",
    "Mountford",
    "Ochiai",
    "Ochiai2",
    "Optimal",
    "OptimalP",
    "Overlap",
    #"Pearson", # Lang沒有，考慮其他的也不要用。
    "Phi",
    "Pierce",
    "RogersTanimoto",
    "Rogot1",
    "Rogot2",
    "RussellRao",
    "SBI",
    "Scott",
    "SimpleMatching",
    "Sokal",
    "SorensenDice",
    "Tarantula",
    "Tarwid",
    "Wong1",
    "Wong2",
    "Wong3",
    "Zoltar"
]

# %%
# 取得project的每一個bug-id有多少行的方法。
SBFL_fault_statement_number = []
project_statement_file = 'project_line/' + Project +'_line.txt'

# 使用 with 語句打開文件，確保文件在使用後自動關閉
with open(project_statement_file, 'r', encoding='utf-8') as file:
    project_lines = file.readlines()  # 讀取所有行

# 去掉每行末尾的換行符
project_lines = [int(line.strip()) for line in project_lines] # 順便將str轉為數字
print(project_lines)

max_line = max(project_lines) # 找出最大行數，用於後續輸出使用
print(max_line)

# 輸出此project總共有多少行。
print(sum(project_lines))
# Out:
# [3959, 5718, 5916, 7558, 4375, 5036, 7109, 3569, 3565, 7227, 4794, 5569, 5163, 6990, 175, 7015, 3981, 4373, 5707, 5748, 3578, 4641, 1584, 7512, 5606, 6641, 5947]
# 7558
# 139056

# %%
# get_fault_statement
#動態產生二微陣列的方法
Project_bugid_faultStatement = []

for i in range(0,project_bugid_num):
    fault_statement_file_path = '錯誤位置/'+ Project + '/' + Project2 +'_v' + str(i+1) + '_FaultStatement.txt'
    print(fault_statement_file_path)

    # 使用 with 語句打開文件，確保文件在使用後自動關閉
    with open(fault_statement_file_path, 'r', encoding='utf-8') as file:
        lines2 = file.readlines()  # 讀取所有行

    # 去掉每行末尾的換行符
    lines2 = [line.strip() for line in lines2]
    print(lines2)

    lines2 = lines2[0].split()
    print(len(lines2))

    Project_bugid_faultStatement.append([])
    for j in range(0,len(lines2)):
        Project_bugid_faultStatement[i].append(int(lines2[j])) # 順便將str轉為數字

print(Project_bugid_faultStatement)
# Out:
# 錯誤位置/time/Time_v1_FaultStatement.txt
# ['3708 3709 3712 669 670']
# 5
# 錯誤位置/time/Time_v2_FaultStatement.txt
# ['2797 2867 2868 2869 2870 927']
# 6
# 錯誤位置/time/Time_v3_FaultStatement.txt
# ['2341 2342 2345 2346 2349 2350 2353 2354 2357 2358 2365 2366 2369 2370 2375 2376 2381 2382 2387 2388']
# 20
# 錯誤位置/time/Time_v4_FaultStatement.txt
# ['4781']
# 1
# 錯誤位置/time/Time_v5_FaultStatement.txt
# ['385 386 387 388 389 390']
# 6
# 錯誤位置/time/Time_v6_FaultStatement.txt
# ['3344 3345 3354 3355 3525 3526 3527']
# 7
# 錯誤位置/time/Time_v7_FaultStatement.txt
# ['1325 1327']
# 2
# 錯誤位置/time/Time_v8_FaultStatement.txt
# ['384 386 387 389']
# 4
# 錯誤位置/time/Time_v9_FaultStatement.txt
# ['382 385 387 388 394']
# 5
# 錯誤位置/time/Time_v10_FaultStatement.txt
# ['2080 2081']
# 2
# 錯誤位置/time/Time_v11_FaultStatement.txt
# ['1111 1112 1113']
# 3
# 錯誤位置/time/Time_v12_FaultStatement.txt
# ['498 499 500 502 5210 5211 5212 5214']
# 8
# 錯誤位置/time/Time_v13_FaultStatement.txt
# ['4615 4634 4640 4641']
# 4
# 錯誤位置/time/Time_v14_FaultStatement.txt
# ['5345']
# 1
# 錯誤位置/time/Time_v15_FaultStatement.txt
# ['129']
# 1
# 錯誤位置/time/Time_v16_FaultStatement.txt
# ['1506']
# 1
# 錯誤位置/time/Time_v17_FaultStatement.txt
# ['1546 1547 1548 1549 1550 1551']
# 6
# 錯誤位置/time/Time_v18_FaultStatement.txt
# ['2917 2918']
# 2
# 錯誤位置/time/Time_v19_FaultStatement.txt
# ['538']
# 1
# 錯誤位置/time/Time_v20_FaultStatement.txt
# ['1175 1177 1178 1179']
# 4
# 錯誤位置/time/Time_v21_FaultStatement.txt
# ['1933 1937 1938 1939 1940 1941 1942']
# 7
# 錯誤位置/time/Time_v22_FaultStatement.txt
# ['1145 1146 2428']
# 3
# 錯誤位置/time/Time_v23_FaultStatement.txt
# ['193 194 195 196 197 198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215 216 217 218 219 220 221 222 223 224 225 226']
# 34
# 錯誤位置/time/Time_v24_FaultStatement.txt
# ['303 306']
# 2
# 錯誤位置/time/Time_v25_FaultStatement.txt
# ['1543 1549']
# 2
# 錯誤位置/time/Time_v26_FaultStatement.txt
# ['3605 3612 3619 3622 3628 3646 3653']
# 7
# 錯誤位置/time/Time_v27_FaultStatement.txt
# ['5416 5417']
# 2
# [[3708, 3709, 3712, 669, 670], [2797, 2867, 2868, 2869, 2870, 927], [2341, 2342, 2345, 2346, 2349, 2350, 2353, 2354, 2357, 2358, 2365, 2366, 2369, 2370, 2375, 2376, 2381, 2382, 2387, 2388], [4781], [385, 386, 387, 388, 389, 390], [3344, 3345, 3354, 3355, 3525, 3526, 3527], [1325, 1327], [384, 386, 387, 389], [382, 385, 387, 388, 394], [2080, 2081], [1111, 1112, 1113], [498, 499, 500, 502, 5210, 5211, 5212, 5214], [4615, 4634, 4640, 4641], [5345], [129], [1506], [1546, 1547, 1548, 1549, 1550, 1551], [2917, 2918], [538], [1175, 1177, 1178, 1179], [1933, 1937, 1938, 1939, 1940, 1941, 1942], [1145, 1146, 2428], [193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226], [303, 306], [1543, 1549], [3605, 3612, 3619, 3622, 3628, 3646, 3653], [5416, 5417]]

# %%
# Top_1 = []
# Top_3 = []
# Top_5 = []
# Top_10 = []

# print(SBFL_all[0])
# print(SBFL_all[1])
# print(len(Project_bugid_faultStatement[0]))

# %%
import pandas as pd
import os

# def create_df():
#     excel_path = Project + '_result/' + Project + '_整理結果' + SBFL_all[SBFL_index] + '.xlsx'
#     print(excel_path)
#     df = pd.read_excel(excel_path, engine='openpyxl', sheet_name='Sheet1') #輸入要用的project excel是甚麼
#     print(df)

#txt_file_name = 'SBFL_math'#輸入要儲存的檔案名稱

# %%
# print(df.index)
# print(df.columns)
# print(df.loc[:,1:3])

# 先建立一個空的一維陣列
Top_1 = []
Top_3 = []
Top_5 = []
Top_10 = []

# 查看 DataFrame 當前的記憶體用量
#df.info(memory_usage="deep")

# print(df.loc[0].values)
for SBFL_Tool_index in range(0,len(SBFL_all)):

    # 每個SBFL都要建立一個二維
    Top_1.append([])
    Top_3.append([])
    Top_5.append([])
    Top_10.append([])
    #-----------------------------

    # 每個SBFL都要建立一個dataframe
    excel_path = Project + '_result/' + Project + '_整理結果' + SBFL_all[SBFL_Tool_index] + '.xlsx'
    print(excel_path)
    df = pd.read_excel(excel_path, engine='openpyxl', sheet_name='Sheet1') #輸入要用的project excel是甚麼
    print(df)
    #-----------------------------

    excel_index = 0 #紀錄目前的SBFL工具，bugid會用掉多少行
    for i in range(0,project_bugid_num):
        print(project_lines[i])

        # 處理不到200行的情況。
        if int(project_lines[i]) < 200:
            index_add = project_lines[i]
        elif int(project_lines[i]) >= 200:
            index_add = 200
        #---------------------------------

        #for bugid_index in range(0, int(project_lines[i])):
        for bugid_index in range(0, index_add): # closure因為行數比較多，所以改成只取最大的200行。
            #create_df
            find_flag = 0 # 表示有沒有找到
            get_row_data = df.loc[bugid_index + excel_index].values # 取出目前row的資料
            print("get_row_data: ", get_row_data)
            #print(df.loc[bugid_index + excel_index].values) 
            for faultStatement_index in range(0,len(Project_bugid_faultStatement[i])): # 每個錯誤位置都要檢查。
                #print(get_row_data)
                if get_row_data[2] == 1 and get_row_data[3] == Project_bugid_faultStatement[i][faultStatement_index]:
                    Top_1[SBFL_Tool_index].append(i+1)
                    Top_3[SBFL_Tool_index].append(i+1)
                    Top_5[SBFL_Tool_index].append(i+1)
                    Top_10[SBFL_Tool_index].append(i+1)
                    print("Top_1")
                    find_flag = 1
                    break #跳出for
                elif 1 < get_row_data[2] <= 3 and get_row_data[3] == Project_bugid_faultStatement[i][faultStatement_index]:
                    Top_3[SBFL_Tool_index].append(i+1)
                    Top_5[SBFL_Tool_index].append(i+1)
                    Top_10[SBFL_Tool_index].append(i+1)
                    print("Top_3")
                    find_flag = 1
                    break #跳出for
                elif 3 < get_row_data[2] <= 5 and get_row_data[3] == Project_bugid_faultStatement[i][faultStatement_index]:
                    Top_5[SBFL_Tool_index].append(i+1)
                    Top_10[SBFL_Tool_index].append(i+1)
                    print("Top_5")
                    find_flag = 1
                    break #跳出for
                elif 5 < get_row_data[2] <= 10 and get_row_data[3] == Project_bugid_faultStatement[i][faultStatement_index]:
                    Top_10[SBFL_Tool_index].append(i+1)
                    print("Top_10")
                    find_flag = 1
                    break #跳出for
                elif get_row_data[2] > 10:
                    find_flag = 1
                    print("Not Found!")
                    break #跳出for
            if find_flag == 1:
                break #找到後跳出
        #excel_index = excel_index + int(project_lines[i]) # bugid完成後，excel的index跳到下一個bugid的index。

        # bugid完成後，excel的index跳到下一個bugid的index。
        # closure因為行數比較多，所以改成只取最大的200行，也因為有不到200行的，因此用index_add處理。
        excel_index = excel_index + index_add

        Now_message = "Now bugid_" + str(i+1) + " end excel index: "
        print( Now_message, excel_index)
        #print(df.loc[excel_index].values)
        print("Top_1: " , Top_1[SBFL_Tool_index])
        print("Top_3: " , Top_3[SBFL_Tool_index])
        print("Top_5: " , Top_5[SBFL_Tool_index])
        print("Top_10: " , Top_10[SBFL_Tool_index])
        print("-----------------------------------")
    df = pd.DataFrame() # 清空dataframe
# Out:
# time_result/time_整理結果Ample.xlsx
#      SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value
# 0        Ample       1    1                3711          1.000000
# 1        Ample       1    2                 669          0.998479
# 2        Ample       1    2                 670          0.998479
# 3        Ample       1    2                 684          0.998479
# 4        Ample       1    5                3618          0.997719
# ...        ...     ...  ...                 ...               ...
# 5370     Ample      27  180                2145          0.867028
# 5371     Ample      27  180                2146          0.867028
# 5372     Ample      27  180                2147          0.867028
# 5373     Ample      27  180                2148          0.867028
# 5374     Ample      27  180                2149          0.867028
#
# [5375 rows x 5 columns]
# 3959
# get_row_data:  ['Ample' 1 1 3711 1.0]
# get_row_data:  ['Ample' 1 2 669 0.998479]
# Top_3
# Now bugid_1 end excel index:  200
# Top_1:  []
# Top_3:  [1]
# Top_5:  [1]
# Top_10:  [1]
# -----------------------------------
# 5718
# get_row_data:  ['Ample' 2 1 2802 1.0]
# get_row_data:  ['Ample' 2 2 927 0.998986]
# Top_3
# Now bugid_2 end excel index:  400
# Top_1:  []
# Top_3:  [1, 2]
# Top_5:  [1, 2]
# Top_10:  [1, 2]
# -----------------------------------
# 5916
# get_row_data:  ['Ample' 3 1 2369 1.0]
# Top_1
# Now bugid_3 end excel index:  600
# Top_1:  [3]
# Top_3:  [1, 2, 3]
# Top_5:  [1, 2, 3]
# Top_10:  [1, 2, 3]
# -----------------------------------
# 7558
# get_row_data:  ['Ample' 4 1 6568 1.0]
# get_row_data:  ['Ample' 4 1 6571 1.0]
# get_row_data:  ['Ample' 4 1 6575 1.0]
# get_row_data:  ['Ample' 4 4 6572 0.997399]
# get_row_data:  ['Ample' 4 5 7525 0.994798]
# get_row_data:  ['Ample' 4 6 4771 0.993498]
# get_row_data:  ['Ample' 4 6 4772 0.993498]
# get_row_data:  ['Ample' 4 6 4773 0.993498]
# get_row_data:  ['Ample' 4 9 4769 0.992198]
# get_row_data:  ['Ample' 4 10 5449 0.988296]
# get_row_data:  ['Ample' 4 11 7501 0.976593]
# Not Found!
# Now bugid_4 end excel index:  800
# Top_1:  [3]
# Top_3:  [1, 2, 3]
# Top_5:  [1, 2, 3]
# Top_10:  [1, 2, 3]
# -----------------------------------
# 4375
# get_row_data:  ['Ample' 5 1 1030 1.0]
# get_row_data:  ['Ample' 5 2 388 0.997342]
# Top_3
# Now bugid_5 end excel index:  1000
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5]
# Top_5:  [1, 2, 3, 5]
# Top_10:  [1, 2, 3, 5]
# -----------------------------------
# 5036
# get_row_data:  ['Ample' 6 1 1358 1.0]
# get_row_data:  ['Ample' 6 1 1359 1.0]
# get_row_data:  ['Ample' 6 1 1360 1.0]
# get_row_data:  ['Ample' 6 1 1361 1.0]
# get_row_data:  ['Ample' 6 1 1362 1.0]
# get_row_data:  ['Ample' 6 1 1363 1.0]
# get_row_data:  ['Ample' 6 7 1427 0.99837]
# get_row_data:  ['Ample' 6 8 1428 0.993073]
# get_row_data:  ['Ample' 6 9 3518 0.976365]
# get_row_data:  ['Ample' 6 10 1364 0.974328]
# get_row_data:  ['Ample' 6 10 1365 0.974328]
# get_row_data:  ['Ample' 6 10 1366 0.974328]
# get_row_data:  ['Ample' 6 10 1367 0.974328]
# get_row_data:  ['Ample' 6 10 1368 0.974328]
# get_row_data:  ['Ample' 6 10 1369 0.974328]
# get_row_data:  ['Ample' 6 10 1370 0.974328]
# get_row_data:  ['Ample' 6 10 1371 0.974328]
# get_row_data:  ['Ample' 6 10 1372 0.974328]
# get_row_data:  ['Ample' 6 19 896 0.933985]
# Not Found!
# Now bugid_6 end excel index:  1200
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5]
# Top_5:  [1, 2, 3, 5]
# Top_10:  [1, 2, 3, 5]
# -----------------------------------
# 7109
# get_row_data:  ['Ample' 7 1 3020 1.0]
# get_row_data:  ['Ample' 7 1 3021 1.0]
# get_row_data:  ['Ample' 7 1 3022 1.0]
# get_row_data:  ['Ample' 7 1 3023 1.0]
# get_row_data:  ['Ample' 7 1 4429 1.0]
# get_row_data:  ['Ample' 7 1 4430 1.0]
# get_row_data:  ['Ample' 7 1 4432 1.0]
# get_row_data:  ['Ample' 7 1 4433 1.0]
# get_row_data:  ['Ample' 7 1 4434 1.0]
# get_row_data:  ['Ample' 7 10 1320 0.991485]
# get_row_data:  ['Ample' 7 10 1321 0.991485]
# get_row_data:  ['Ample' 7 10 1323 0.991485]
# get_row_data:  ['Ample' 7 10 1324 0.991485]
# get_row_data:  ['Ample' 7 10 1325 0.991485]
# Top_10
# Now bugid_7 end excel index:  1400
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5]
# Top_5:  [1, 2, 3, 5]
# Top_10:  [1, 2, 3, 5, 7]
# -----------------------------------
# 3569
# get_row_data:  ['Ample' 8 1 385 1.0]
# get_row_data:  ['Ample' 8 2 375 0.999742]
# get_row_data:  ['Ample' 8 2 381 0.999742]
# get_row_data:  ['Ample' 8 4 539 0.996909]
# get_row_data:  ['Ample' 8 4 540 0.996909]
# get_row_data:  ['Ample' 8 6 429 0.995106]
# get_row_data:  ['Ample' 8 6 430 0.995106]
# get_row_data:  ['Ample' 8 6 431 0.995106]
# get_row_data:  ['Ample' 8 9 2802 0.994848]
# get_row_data:  ['Ample' 8 10 373 0.992787]
# get_row_data:  ['Ample' 8 10 374 0.992787]
# get_row_data:  ['Ample' 8 10 376 0.992787]
# get_row_data:  ['Ample' 8 10 377 0.992787]
# get_row_data:  ['Ample' 8 14 372 0.99253]
# Not Found!
# Now bugid_8 end excel index:  1600
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5]
# Top_5:  [1, 2, 3, 5]
# Top_10:  [1, 2, 3, 5, 7]
# -----------------------------------
# 3565
# get_row_data:  ['Ample' 9 1 383 1.0]
# get_row_data:  ['Ample' 9 2 381 0.999742]
# get_row_data:  ['Ample' 9 3 387 0.998712]
# Top_3
# Now bugid_9 end excel index:  1800
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5, 9]
# Top_5:  [1, 2, 3, 5, 9]
# Top_10:  [1, 2, 3, 5, 7, 9]
# -----------------------------------
# 7227
# get_row_data:  ['Ample' 10 1 50 1.0]
# get_row_data:  ['Ample' 10 1 463 1.0]
# get_row_data:  ['Ample' 10 1 464 1.0]
# get_row_data:  ['Ample' 10 1 465 1.0]
# get_row_data:  ['Ample' 10 1 466 1.0]
# get_row_data:  ['Ample' 10 1 467 1.0]
# get_row_data:  ['Ample' 10 1 468 1.0]
# get_row_data:  ['Ample' 10 1 469 1.0]
# get_row_data:  ['Ample' 10 1 470 1.0]
# get_row_data:  ['Ample' 10 1 471 1.0]
# get_row_data:  ['Ample' 10 1 472 1.0]
# get_row_data:  ['Ample' 10 1 533 1.0]
# get_row_data:  ['Ample' 10 1 534 1.0]
# get_row_data:  ['Ample' 10 1 538 1.0]
# get_row_data:  ['Ample' 10 1 540 1.0]
# get_row_data:  ['Ample' 10 1 541 1.0]
# get_row_data:  ['Ample' 10 1 543 1.0]
# get_row_data:  ['Ample' 10 1 563 1.0]
# get_row_data:  ['Ample' 10 1 2792 1.0]
# get_row_data:  ['Ample' 10 20 89 0.99458]
# Not Found!
# Now bugid_10 end excel index:  2000
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5, 9]
# Top_5:  [1, 2, 3, 5, 9]
# Top_10:  [1, 2, 3, 5, 7, 9]
# -----------------------------------
# 4794
# get_row_data:  ['Ample' 11 1 1369 1.0]
# get_row_data:  ['Ample' 11 1 2056 1.0]
# get_row_data:  ['Ample' 11 1 2058 1.0]
# get_row_data:  ['Ample' 11 1 2059 1.0]
# get_row_data:  ['Ample' 11 1 2206 1.0]
# get_row_data:  ['Ample' 11 1 2207 1.0]
# get_row_data:  ['Ample' 11 1 2512 1.0]
# get_row_data:  ['Ample' 11 1 2513 1.0]
# get_row_data:  ['Ample' 11 1 2767 1.0]
# get_row_data:  ['Ample' 11 1 2922 1.0]
# get_row_data:  ['Ample' 11 1 2923 1.0]
# get_row_data:  ['Ample' 11 12 127 0.857143]
# Not Found!
# Now bugid_11 end excel index:  2200
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5, 9]
# Top_5:  [1, 2, 3, 5, 9]
# Top_10:  [1, 2, 3, 5, 7, 9]
# -----------------------------------
# 5569
# get_row_data:  ['Ample' 12 1 889 1.0]
# get_row_data:  ['Ample' 12 2 2380 0.949022]
# get_row_data:  ['Ample' 12 2 2381 0.949022]
# get_row_data:  ['Ample' 12 4 2389 0.929469]
# get_row_data:  ['Ample' 12 5 5520 0.900838]
# get_row_data:  ['Ample' 12 6 5517 0.875698]
# get_row_data:  ['Ample' 12 7 5519 0.86662]
# get_row_data:  ['Ample' 12 8 858 0.84986]
# get_row_data:  ['Ample' 12 8 860 0.84986]
# get_row_data:  ['Ample' 12 8 861 0.84986]
# get_row_data:  ['Ample' 12 8 862 0.84986]
# get_row_data:  ['Ample' 12 8 864 0.84986]
# get_row_data:  ['Ample' 12 8 865 0.84986]
# get_row_data:  ['Ample' 12 8 866 0.84986]
# get_row_data:  ['Ample' 12 8 869 0.84986]
# get_row_data:  ['Ample' 12 8 870 0.84986]
# get_row_data:  ['Ample' 12 8 871 0.84986]
# get_row_data:  ['Ample' 12 18 867 0.842179]
# Not Found!
# Now bugid_12 end excel index:  2400
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5, 9]
# Top_5:  [1, 2, 3, 5, 9]
# Top_10:  [1, 2, 3, 5, 7, 9]
# -----------------------------------
# 5163
# get_row_data:  ['Ample' 13 1 746 1.0]
# get_row_data:  ['Ample' 13 1 747 1.0]
# get_row_data:  ['Ample' 13 1 748 1.0]
# get_row_data:  ['Ample' 13 4 5039 0.998968]
# get_row_data:  ['Ample' 13 4 5040 0.998968]
# get_row_data:  ['Ample' 13 6 4999 0.997936]
# get_row_data:  ['Ample' 13 6 5000 0.997936]
# get_row_data:  ['Ample' 13 6 5001 0.997936]
# get_row_data:  ['Ample' 13 9 4926 0.996904]
# get_row_data:  ['Ample' 13 9 5007 0.996904]
# get_row_data:  ['Ample' 13 9 5008 0.996904]
# get_row_data:  ['Ample' 13 9 5009 0.996904]
# get_row_data:  ['Ample' 13 9 5010 0.996904]
# get_row_data:  ['Ample' 13 14 5006 0.995872]
# Not Found!
# Now bugid_13 end excel index:  2600
# Top_1:  [3]
# Top_3:  [1, 2, 3, 5, 9]
# Top_5:  [1, 2, 3, 5, 9]
# Top_10:  [1, 2, 3, 5, 7, 9]
# -----------------------------------
# 6990
# get_row_data:  ['Ample' 14 1 5343 1.0]
# get_row_data:  ['Ample' 14 1 5345 1.0]
# Top_1
# Now bugid_14 end excel index:  2800
# Top_1:  [3, 14]
# Top_3:  [1, 2, 3, 5, 9, 14]
# Top_5:  [1, 2, 3, 5, 9, 14]
# Top_10:  [1, 2, 3, 5, 7, 9, 14]
# -----------------------------------
# 175
# get_row_data:  ['Ample' 15 1 130 1.0]
# get_row_data:  ['Ample' 15 2 129 0.995595]
# Top_3
# Now bugid_15 end excel index:  2975
# Top_1:  [3, 14]
# Top_3:  [1, 2, 3, 5, 9, 14, 15]
# Top_5:  [1, 2, 3, 5, 9, 14, 15]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15]
# -----------------------------------
# 7015
# get_row_data:  ['Ample' 16 1 1499 1.0]
# get_row_data:  ['Ample' 16 1 1500 1.0]
# get_row_data:  ['Ample' 16 1 1502 1.0]
# get_row_data:  ['Ample' 16 1 1503 1.0]
# get_row_data:  ['Ample' 16 1 1504 1.0]
# get_row_data:  ['Ample' 16 1 1505 1.0]
# get_row_data:  ['Ample' 16 1 1506 1.0]
# Top_1
# Now bugid_16 end excel index:  3175
# Top_1:  [3, 14, 16]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16]
# -----------------------------------
# 3981
# get_row_data:  ['Ample' 17 1 1546 1.0]
# Top_1
# Now bugid_17 end excel index:  3375
# Top_1:  [3, 14, 16, 17]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17]
# -----------------------------------
# 4373
# get_row_data:  ['Ample' 18 1 183 1.0]
# get_row_data:  ['Ample' 18 2 2915 0.992754]
# get_row_data:  ['Ample' 18 2 2917 0.992754]
# Top_3
# Now bugid_18 end excel index:  3575
# Top_1:  [3, 14, 16, 17]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18]
# -----------------------------------
# 5707
# get_row_data:  ['Ample' 19 1 2973 1.0]
# get_row_data:  ['Ample' 19 1 2974 1.0]
# get_row_data:  ['Ample' 19 3 3944 0.973768]
# get_row_data:  ['Ample' 19 4 1231 0.970853]
# get_row_data:  ['Ample' 19 4 1232 0.970853]
# get_row_data:  ['Ample' 19 6 2948 0.944621]
# get_row_data:  ['Ample' 19 7 1434 0.941176]
# get_row_data:  ['Ample' 19 7 1435 0.941176]
# get_row_data:  ['Ample' 19 7 1436 0.941176]
# get_row_data:  ['Ample' 19 7 1439 0.941176]
# get_row_data:  ['Ample' 19 11 5001 0.939587]
# Not Found!
# Now bugid_19 end excel index:  3775
# Top_1:  [3, 14, 16, 17]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18]
# -----------------------------------
# 5748
# get_row_data:  ['Ample' 20 1 1167 1.0]
# get_row_data:  ['Ample' 20 1 1168 1.0]
# get_row_data:  ['Ample' 20 1 1173 1.0]
# get_row_data:  ['Ample' 20 4 1174 0.99961]
# get_row_data:  ['Ample' 20 4 1175 0.99961]
# Top_5
# Now bugid_20 end excel index:  3975
# Top_1:  [3, 14, 16, 17]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20]
# -----------------------------------
# 3578
# get_row_data:  ['Ample' 21 1 1941 1.0]
# Top_1
# Now bugid_21 end excel index:  4175
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21]
# -----------------------------------
# 4641
# get_row_data:  ['Ample' 22 1 1577 1.0]
# get_row_data:  ['Ample' 22 2 1576 0.995025]
# get_row_data:  ['Ample' 22 3 2428 0.984522]
# Top_3
# Now bugid_22 end excel index:  4375
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22]
# -----------------------------------
# 1584
# get_row_data:  ['Ample' 23 1 103 1.0]
# get_row_data:  ['Ample' 23 2 107 0.998599]
# get_row_data:  ['Ample' 23 3 95 0.998319]
# get_row_data:  ['Ample' 23 3 97 0.998319]
# get_row_data:  ['Ample' 23 3 98 0.998319]
# get_row_data:  ['Ample' 23 3 100 0.998319]
# get_row_data:  ['Ample' 23 3 101 0.998319]
# get_row_data:  ['Ample' 23 3 102 0.998319]
# get_row_data:  ['Ample' 23 3 104 0.998319]
# get_row_data:  ['Ample' 23 3 106 0.998319]
# get_row_data:  ['Ample' 23 3 191 0.998319]
# get_row_data:  ['Ample' 23 3 192 0.998319]
# get_row_data:  ['Ample' 23 3 193 0.998319]
# Top_3
# Now bugid_23 end excel index:  4575
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 7512
# get_row_data:  ['Ample' 24 1 1414 1.0]
# get_row_data:  ['Ample' 24 1 3497 1.0]
# get_row_data:  ['Ample' 24 1 3498 1.0]
# get_row_data:  ['Ample' 24 4 1224 0.997079]
# get_row_data:  ['Ample' 24 4 1229 0.997079]
# get_row_data:  ['Ample' 24 4 6082 0.997079]
# get_row_data:  ['Ample' 24 4 6084 0.997079]
# get_row_data:  ['Ample' 24 4 6085 0.997079]
# get_row_data:  ['Ample' 24 4 6089 0.997079]
# get_row_data:  ['Ample' 24 10 1220 0.996105]
# get_row_data:  ['Ample' 24 10 1222 0.996105]
# get_row_data:  ['Ample' 24 10 1225 0.996105]
# get_row_data:  ['Ample' 24 10 1227 0.996105]
# get_row_data:  ['Ample' 24 10 1228 0.996105]
# get_row_data:  ['Ample' 24 10 2163 0.996105]
# get_row_data:  ['Ample' 24 16 1038 0.994158]
# Not Found!
# Now bugid_24 end excel index:  4775
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 5606
# get_row_data:  ['Ample' 25 1 5291 1.0]
# get_row_data:  ['Ample' 25 2 5419 0.97418]
# get_row_data:  ['Ample' 25 3 1712 0.965573]
# get_row_data:  ['Ample' 25 4 5051 0.964497]
# get_row_data:  ['Ample' 25 4 5052 0.964497]
# get_row_data:  ['Ample' 25 4 5053 0.964497]
# get_row_data:  ['Ample' 25 7 2886 0.945401]
# get_row_data:  ['Ample' 25 8 3984 0.944056]
# get_row_data:  ['Ample' 25 9 3086 0.940559]
# get_row_data:  ['Ample' 25 9 3087 0.940559]
# get_row_data:  ['Ample' 25 9 3088 0.940559]
# get_row_data:  ['Ample' 25 9 3091 0.940559]
# get_row_data:  ['Ample' 25 13 2902 0.931415]
# Not Found!
# Now bugid_25 end excel index:  4975
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 6641
# get_row_data:  ['Ample' 26 1 174 1.0]
# get_row_data:  ['Ample' 26 2 472 0.992999]
# get_row_data:  ['Ample' 26 3 5414 0.979838]
# get_row_data:  ['Ample' 26 3 5415 0.979838]
# get_row_data:  ['Ample' 26 3 5416 0.979838]
# get_row_data:  ['Ample' 26 6 5410 0.979558]
# get_row_data:  ['Ample' 26 7 5397 0.976477]
# get_row_data:  ['Ample' 26 7 5401 0.976477]
# get_row_data:  ['Ample' 26 7 5402 0.976477]
# get_row_data:  ['Ample' 26 7 5403 0.976477]
# get_row_data:  ['Ample' 26 7 5405 0.976477]
# get_row_data:  ['Ample' 26 7 5406 0.976477]
# get_row_data:  ['Ample' 26 7 5408 0.976477]
# get_row_data:  ['Ample' 26 7 5409 0.976477]
# get_row_data:  ['Ample' 26 7 5411 0.976477]
# get_row_data:  ['Ample' 26 7 5412 0.976477]
# get_row_data:  ['Ample' 26 17 6435 0.968916]
# Not Found!
# Now bugid_26 end excel index:  5175
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 5947
# get_row_data:  ['Ample' 27 1 5572 1.0]
# get_row_data:  ['Ample' 27 1 5749 1.0]
# get_row_data:  ['Ample' 27 3 5282 0.998643]
# get_row_data:  ['Ample' 27 3 5284 0.998643]
# get_row_data:  ['Ample' 27 3 5285 0.998643]
# get_row_data:  ['Ample' 27 3 5286 0.998643]
# get_row_data:  ['Ample' 27 3 5427 0.998643]
# get_row_data:  ['Ample' 27 8 4370 0.991859]
# get_row_data:  ['Ample' 27 9 4371 0.990502]
# get_row_data:  ['Ample' 27 9 5728 0.990502]
# get_row_data:  ['Ample' 27 9 5729 0.990502]
# get_row_data:  ['Ample' 27 12 4303 0.970149]
# Not Found!
# Now bugid_27 end excel index:  5375
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# time_result/time_整理結果Anderberg.xlsx
#       SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value
# 0     Anderberg       1    1                3711          1.000000
# 1     Anderberg       1    2                 669          0.076923
# 2     Anderberg       1    2                 670          0.076923
# 3     Anderberg       1    2                 684          0.076923
# 4     Anderberg       1    5                3618          0.052632
# ...         ...     ...  ...                 ...               ...
# 5370  Anderberg      27  180                2145          0.005076
# 5371  Anderberg      27  180                2146          0.005076
# 5372  Anderberg      27  180                2147          0.005076
# 5373  Anderberg      27  180                2148          0.005076
# 5374  Anderberg      27  180                2149          0.005076
#
# [5375 rows x 5 columns]
# 3959
# get_row_data:  ['Anderberg' 1 1 3711 1.0]
# get_row_data:  ['Anderberg' 1 2 669 0.0769231]
# Top_3
# Now bugid_1 end excel index:  200
# Top_1:  []
# Top_3:  [1]
# Top_5:  [1]
# Top_10:  [1]
# -----------------------------------
# 5718
# get_row_data:  ['Anderberg' 2 1 2802 1.0]
# get_row_data:  ['Anderberg' 2 2 927 0.272727]
# Top_3
# Now bugid_2 end excel index:  400
# Top_1:  []
# Top_3:  [1, 2]
# Top_5:  [1, 2]
# Top_10:  [1, 2]
# -----------------------------------
# 5916
# get_row_data:  ['Anderberg' 3 1 2369 1.0]
# Top_1
# Now bugid_3 end excel index:  600
# Top_1:  [3]
# Top_3:  [1, 2, 3]
# Top_5:  [1, 2, 3]
# Top_10:  [1, 2, 3]
# -----------------------------------
# 7558
# get_row_data:  ['Anderberg' 4 1 6568 1.0]
# get_row_data:  ['Anderberg' 4 1 6571 1.0]
# get_row_data:  ['Anderberg' 4 1 6575 1.0]
# get_row_data:  ['Anderberg' 4 4 6572 0.2]
# get_row_data:  ['Anderberg' 4 5 7525 0.111111]
# get_row_data:  ['Anderberg' 4 6 4771 0.0909091]
# get_row_data:  ['Anderberg' 4 6 4772 0.0909091]
# get_row_data:  ['Anderberg' 4 6 4773 0.0909091]
# get_row_data:  ['Anderberg' 4 9 4769 0.0769231]
# get_row_data:  ['Anderberg' 4 10 5449 0.0526316]
# get_row_data:  ['Anderberg' 4 11 7501 0.027027]
# Not Found!
# Now bugid_4 end excel index:  800
# Top_1:  [3]
# Top_3:  [1, 2, 3]
# Top_5:  [1, 2, 3]
# Top_10:  [1, 2, 3]
# -----------------------------------
# 4375
# get_row_data:  ['Anderberg' 5 1 1030 1.0]
# get_row_data:  ['Anderberg' 5 2 987 0.6]
# get_row_data:  ['Anderberg' 5 2 989 0.6]
# get_row_data:  ['Anderberg' 5 2 990 0.6]
# get_row_data:  ['Anderberg' 5 2 991 0.6]
# get_row_data:  ['Anderberg' 5 2 992 0.6]
# get_row_data:  ['Anderberg' 5 2 993 0.6]
# get_row_data:  ['Anderberg' 5 2 995 0.6]
# get_row_data:  ['Anderberg' 5 2 997 0.6]
# get_row_data:  ['Anderberg' 5 2 999 0.6]
# get_row_data:  ['Anderberg' 5 2 1000 0.6]
# get_row_data:  ['Anderberg' 5 2 1001 0.6]
# get_row_data:  ['Anderberg' 5 2 1002 0.6]
# get_row_data:  ['Anderberg' 5 2 1003 0.6]
# get_row_data:  ['Anderberg' 5 2 1004 0.6]
# get_row_data:  ['Anderberg' 5 2 1005 0.6]
# get_row_data:  ['Anderberg' 5 2 1006 0.6]
# get_row_data:  ['Anderberg' 5 2 1007 0.6]
# get_row_data:  ['Anderberg' 5 2 1010 0.6]
# get_row_data:  ['Anderberg' 5 2 1011 0.6]
# get_row_data:  ['Anderberg' 5 2 1012 0.6]
# get_row_data:  ['Anderberg' 5 2 1015 0.6]
# get_row_data:  ['Anderberg' 5 2 1016 0.6]
# get_row_data:  ['Anderberg' 5 2 1269 0.6]
# get_row_data:  ['Anderberg' 5 2 1270 0.6]
# get_row_data:  ['Anderberg' 5 26 388 0.473684]
# Not Found!
# Now bugid_5 end excel index:  1000
# Top_1:  [3]
# Top_3:  [1, 2, 3]
# Top_5:  [1, 2, 3]
# Top_10:  [1, 2, 3]
# -----------------------------------
# 5036
# get_row_data:  ['Anderberg' 6 1 3342 1.0]
# get_row_data:  ['Anderberg' 6 1 3343 1.0]
# get_row_data:  ['Anderberg' 6 1 3344 1.0]
# Top_1
# Now bugid_6 end excel index:  1200
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6]
# Top_5:  [1, 2, 3, 6]
# Top_10:  [1, 2, 3, 6]
# -----------------------------------
# 7109
# get_row_data:  ['Anderberg' 7 1 3020 1.0]
# get_row_data:  ['Anderberg' 7 1 3021 1.0]
# get_row_data:  ['Anderberg' 7 1 3022 1.0]
# get_row_data:  ['Anderberg' 7 1 3023 1.0]
# get_row_data:  ['Anderberg' 7 1 4429 1.0]
# get_row_data:  ['Anderberg' 7 1 4430 1.0]
# get_row_data:  ['Anderberg' 7 1 4432 1.0]
# get_row_data:  ['Anderberg' 7 1 4433 1.0]
# get_row_data:  ['Anderberg' 7 1 4434 1.0]
# get_row_data:  ['Anderberg' 7 10 6620 0.0434783]
# get_row_data:  ['Anderberg' 7 11 1320 0.0416667]
# Not Found!
# Now bugid_7 end excel index:  1400
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6]
# Top_5:  [1, 2, 3, 6]
# Top_10:  [1, 2, 3, 6]
# -----------------------------------
# 3569
# get_row_data:  ['Anderberg' 8 1 385 1.0]
# get_row_data:  ['Anderberg' 8 2 375 0.333333]
# get_row_data:  ['Anderberg' 8 2 381 0.333333]
# get_row_data:  ['Anderberg' 8 4 539 0.04]
# get_row_data:  ['Anderberg' 8 4 540 0.04]
# get_row_data:  ['Anderberg' 8 6 429 0.025641]
# get_row_data:  ['Anderberg' 8 6 430 0.025641]
# get_row_data:  ['Anderberg' 8 6 431 0.025641]
# get_row_data:  ['Anderberg' 8 9 2802 0.0243902]
# get_row_data:  ['Anderberg' 8 10 373 0.0175439]
# get_row_data:  ['Anderberg' 8 10 374 0.0175439]
# get_row_data:  ['Anderberg' 8 10 376 0.0175439]
# get_row_data:  ['Anderberg' 8 10 377 0.0175439]
# get_row_data:  ['Anderberg' 8 14 372 0.0169492]
# Not Found!
# Now bugid_8 end excel index:  1600
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6]
# Top_5:  [1, 2, 3, 6]
# Top_10:  [1, 2, 3, 6]
# -----------------------------------
# 3565
# get_row_data:  ['Anderberg' 9 1 383 1.0]
# get_row_data:  ['Anderberg' 9 2 381 0.333333]
# get_row_data:  ['Anderberg' 9 3 387 0.0909091]
# Top_3
# Now bugid_9 end excel index:  1800
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9]
# -----------------------------------
# 7227
# get_row_data:  ['Anderberg' 10 1 50 1.0]
# get_row_data:  ['Anderberg' 10 1 463 1.0]
# get_row_data:  ['Anderberg' 10 1 464 1.0]
# get_row_data:  ['Anderberg' 10 1 465 1.0]
# get_row_data:  ['Anderberg' 10 1 466 1.0]
# get_row_data:  ['Anderberg' 10 1 467 1.0]
# get_row_data:  ['Anderberg' 10 1 468 1.0]
# get_row_data:  ['Anderberg' 10 1 469 1.0]
# get_row_data:  ['Anderberg' 10 1 470 1.0]
# get_row_data:  ['Anderberg' 10 1 471 1.0]
# get_row_data:  ['Anderberg' 10 1 472 1.0]
# get_row_data:  ['Anderberg' 10 1 533 1.0]
# get_row_data:  ['Anderberg' 10 1 534 1.0]
# get_row_data:  ['Anderberg' 10 1 538 1.0]
# get_row_data:  ['Anderberg' 10 1 540 1.0]
# get_row_data:  ['Anderberg' 10 1 541 1.0]
# get_row_data:  ['Anderberg' 10 1 543 1.0]
# get_row_data:  ['Anderberg' 10 1 563 1.0]
# get_row_data:  ['Anderberg' 10 1 2792 1.0]
# get_row_data:  ['Anderberg' 10 20 89 0.333333]
# Not Found!
# Now bugid_10 end excel index:  2000
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9]
# -----------------------------------
# 4794
# get_row_data:  ['Anderberg' 11 1 2056 1.0]
# get_row_data:  ['Anderberg' 11 1 2058 1.0]
# get_row_data:  ['Anderberg' 11 1 2059 1.0]
# get_row_data:  ['Anderberg' 11 1 2206 1.0]
# get_row_data:  ['Anderberg' 11 1 2207 1.0]
# get_row_data:  ['Anderberg' 11 1 2512 1.0]
# get_row_data:  ['Anderberg' 11 1 2513 1.0]
# get_row_data:  ['Anderberg' 11 1 2767 1.0]
# get_row_data:  ['Anderberg' 11 1 2922 1.0]
# get_row_data:  ['Anderberg' 11 1 2923 1.0]
# get_row_data:  ['Anderberg' 11 11 127 0.333333]
# Not Found!
# Now bugid_11 end excel index:  2200
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9]
# -----------------------------------
# 5569
# get_row_data:  ['Anderberg' 12 1 2598 1.0]
# get_row_data:  ['Anderberg' 12 2 726 0.545455]
# get_row_data:  ['Anderberg' 12 3 524 0.428571]
# get_row_data:  ['Anderberg' 12 3 526 0.428571]
# get_row_data:  ['Anderberg' 12 3 5425 0.428571]
# get_row_data:  ['Anderberg' 12 6 498 0.375]
# Top_10
# Now bugid_12 end excel index:  2400
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9, 12]
# -----------------------------------
# 5163
# get_row_data:  ['Anderberg' 13 1 746 1.0]
# get_row_data:  ['Anderberg' 13 1 747 1.0]
# get_row_data:  ['Anderberg' 13 1 748 1.0]
# get_row_data:  ['Anderberg' 13 4 5039 0.6]
# get_row_data:  ['Anderberg' 13 4 5040 0.6]
# get_row_data:  ['Anderberg' 13 6 4999 0.428571]
# get_row_data:  ['Anderberg' 13 6 5000 0.428571]
# get_row_data:  ['Anderberg' 13 6 5001 0.428571]
# get_row_data:  ['Anderberg' 13 9 4926 0.333333]
# get_row_data:  ['Anderberg' 13 9 5007 0.333333]
# get_row_data:  ['Anderberg' 13 9 5008 0.333333]
# get_row_data:  ['Anderberg' 13 9 5009 0.333333]
# get_row_data:  ['Anderberg' 13 9 5010 0.333333]
# get_row_data:  ['Anderberg' 13 14 5006 0.272727]
# Not Found!
# Now bugid_13 end excel index:  2600
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9, 12]
# -----------------------------------
# 6990
# get_row_data:  ['Anderberg' 14 1 3283 1.0]
# get_row_data:  ['Anderberg' 14 2 5343 0.392157]
# get_row_data:  ['Anderberg' 14 2 5345 0.392157]
# Top_3
# Now bugid_14 end excel index:  2800
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9, 14]
# Top_5:  [1, 2, 3, 6, 9, 14]
# Top_10:  [1, 2, 3, 6, 9, 12, 14]
# -----------------------------------
# 175
# get_row_data:  ['Anderberg' 15 1 130 1.0]
# get_row_data:  ['Anderberg' 15 2 129 0.04]
# Top_3
# Now bugid_15 end excel index:  2975
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9, 14, 15]
# Top_5:  [1, 2, 3, 6, 9, 14, 15]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15]
# -----------------------------------
# 7015
# get_row_data:  ['Anderberg' 16 1 1499 1.0]
# get_row_data:  ['Anderberg' 16 1 1500 1.0]
# get_row_data:  ['Anderberg' 16 1 1502 1.0]
# get_row_data:  ['Anderberg' 16 1 1503 1.0]
# get_row_data:  ['Anderberg' 16 1 1504 1.0]
# get_row_data:  ['Anderberg' 16 1 1505 1.0]
# get_row_data:  ['Anderberg' 16 1 1506 1.0]
# Top_1
# Now bugid_16 end excel index:  3175
# Top_1:  [3, 6, 16]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16]
# -----------------------------------
# 3981
# get_row_data:  ['Anderberg' 17 1 1546 1.0]
# Top_1
# Now bugid_17 end excel index:  3375
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17]
# -----------------------------------
# 4373
# get_row_data:  ['Anderberg' 18 1 183 1.0]
# get_row_data:  ['Anderberg' 18 2 2915 0.027027]
# get_row_data:  ['Anderberg' 18 2 2917 0.027027]
# Top_3
# Now bugid_18 end excel index:  3575
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18]
# -----------------------------------
# 5707
# get_row_data:  ['Anderberg' 19 1 2973 1.0]
# get_row_data:  ['Anderberg' 19 1 2974 1.0]
# get_row_data:  ['Anderberg' 19 3 3944 0.135371]
# get_row_data:  ['Anderberg' 19 4 1231 0.123506]
# get_row_data:  ['Anderberg' 19 4 1232 0.123506]
# get_row_data:  ['Anderberg' 19 6 2948 0.0690423]
# get_row_data:  ['Anderberg' 19 7 1434 0.0652632]
# get_row_data:  ['Anderberg' 19 7 1435 0.0652632]
# get_row_data:  ['Anderberg' 19 7 1436 0.0652632]
# get_row_data:  ['Anderberg' 19 7 1439 0.0652632]
# get_row_data:  ['Anderberg' 19 11 5001 0.063655]
# Not Found!
# Now bugid_19 end excel index:  3775
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18]
# -----------------------------------
# 5748
# get_row_data:  ['Anderberg' 20 1 1167 1.0]
# get_row_data:  ['Anderberg' 20 1 1168 1.0]
# get_row_data:  ['Anderberg' 20 1 1173 1.0]
# get_row_data:  ['Anderberg' 20 4 1174 0.882353]
# get_row_data:  ['Anderberg' 20 4 1175 0.882353]
# Top_5
# Now bugid_20 end excel index:  3975
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20]
# -----------------------------------
# 3578
# get_row_data:  ['Anderberg' 21 1 513 1.0]
# get_row_data:  ['Anderberg' 21 1 523 1.0]
# get_row_data:  ['Anderberg' 21 3 1941 0.25]
# Top_3
# Now bugid_21 end excel index:  4175
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21]
# -----------------------------------
# 4641
# get_row_data:  ['Anderberg' 22 1 1577 1.0]
# get_row_data:  ['Anderberg' 22 2 1321 0.8]
# get_row_data:  ['Anderberg' 22 3 1576 0.307692]
# get_row_data:  ['Anderberg' 22 4 2428 0.125]
# Top_5
# Now bugid_22 end excel index:  4375
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22]
# -----------------------------------
# 1584
# get_row_data:  ['Anderberg' 23 1 103 1.0]
# get_row_data:  ['Anderberg' 23 2 107 0.230769]
# get_row_data:  ['Anderberg' 23 3 95 0.2]
# get_row_data:  ['Anderberg' 23 3 97 0.2]
# get_row_data:  ['Anderberg' 23 3 98 0.2]
# get_row_data:  ['Anderberg' 23 3 100 0.2]
# get_row_data:  ['Anderberg' 23 3 101 0.2]
# get_row_data:  ['Anderberg' 23 3 102 0.2]
# get_row_data:  ['Anderberg' 23 3 104 0.2]
# get_row_data:  ['Anderberg' 23 3 106 0.2]
# get_row_data:  ['Anderberg' 23 3 191 0.2]
# get_row_data:  ['Anderberg' 23 3 192 0.2]
# get_row_data:  ['Anderberg' 23 3 193 0.2]
# Top_3
# Now bugid_23 end excel index:  4575
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 7512
# get_row_data:  ['Anderberg' 24 1 1414 1.0]
# get_row_data:  ['Anderberg' 24 1 3497 1.0]
# get_row_data:  ['Anderberg' 24 1 3498 1.0]
# get_row_data:  ['Anderberg' 24 4 1224 0.714286]
# get_row_data:  ['Anderberg' 24 4 1229 0.714286]
# get_row_data:  ['Anderberg' 24 4 6082 0.714286]
# get_row_data:  ['Anderberg' 24 4 6084 0.714286]
# get_row_data:  ['Anderberg' 24 4 6085 0.714286]
# get_row_data:  ['Anderberg' 24 4 6089 0.714286]
# get_row_data:  ['Anderberg' 24 10 1220 0.652174]
# get_row_data:  ['Anderberg' 24 10 1222 0.652174]
# get_row_data:  ['Anderberg' 24 10 1225 0.652174]
# get_row_data:  ['Anderberg' 24 10 1227 0.652174]
# get_row_data:  ['Anderberg' 24 10 1228 0.652174]
# get_row_data:  ['Anderberg' 24 10 2163 0.652174]
# get_row_data:  ['Anderberg' 24 16 1038 0.555556]
# Not Found!
# Now bugid_24 end excel index:  4775
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 5606
# get_row_data:  ['Anderberg' 25 1 5291 1.0]
# get_row_data:  ['Anderberg' 25 2 3656 0.301587]
# get_row_data:  ['Anderberg' 25 2 3657 0.301587]
# get_row_data:  ['Anderberg' 25 4 3644 0.191919]
# get_row_data:  ['Anderberg' 25 4 3645 0.191919]
# get_row_data:  ['Anderberg' 25 6 1545 0.129252]
# get_row_data:  ['Anderberg' 25 6 1546 0.129252]
# get_row_data:  ['Anderberg' 25 6 1547 0.129252]
# get_row_data:  ['Anderberg' 25 9 5028 0.124183]
# get_row_data:  ['Anderberg' 25 10 5419 0.0900474]
# get_row_data:  ['Anderberg' 25 11 1544 0.0745098]
# Not Found!
# Now bugid_25 end excel index:  4975
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 6641
# get_row_data:  ['Anderberg' 26 1 317 1.0]
# get_row_data:  ['Anderberg' 26 2 314 0.904762]
# get_row_data:  ['Anderberg' 26 2 3952 0.904762]
# get_row_data:  ['Anderberg' 26 4 170 0.791667]
# get_row_data:  ['Anderberg' 26 4 171 0.791667]
# get_row_data:  ['Anderberg' 26 4 173 0.791667]
# get_row_data:  ['Anderberg' 26 4 315 0.791667]
# get_row_data:  ['Anderberg' 26 8 981 0.703704]
# get_row_data:  ['Anderberg' 26 9 436 0.633333]
# get_row_data:  ['Anderberg' 26 9 4777 0.633333]
# get_row_data:  ['Anderberg' 26 11 4410 0.527778]
# Not Found!
# Now bugid_26 end excel index:  5175
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 5947
# get_row_data:  ['Anderberg' 27 1 5572 1.0]
# get_row_data:  ['Anderberg' 27 1 5749 1.0]
# get_row_data:  ['Anderberg' 27 3 5282 0.333333]
# get_row_data:  ['Anderberg' 27 3 5284 0.333333]
# get_row_data:  ['Anderberg' 27 3 5285 0.333333]
# get_row_data:  ['Anderberg' 27 3 5286 0.333333]
# get_row_data:  ['Anderberg' 27 3 5427 0.333333]
# get_row_data:  ['Anderberg' 27 8 4370 0.0769231]
# get_row_data:  ['Anderberg' 27 9 4371 0.0666667]
# get_row_data:  ['Anderberg' 27 9 5728 0.0666667]
# get_row_data:  ['Anderberg' 27 9 5729 0.0666667]
# get_row_data:  ['Anderberg' 27 12 4303 0.0222222]
# Not Found!
# Now bugid_27 end excel index:  5375
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# time_result/time_整理結果ArithmeticMean.xlsx
#            SBFL_Tool  bug_id  Top  Spectra_file_index  Suspicious_Value
# 0     ArithmeticMean       1    1                3711          1.000000
# 1     ArithmeticMean       1    2                 669          0.250943
# 2     ArithmeticMean       1    2                 670          0.250943
# 3     ArithmeticMean       1    2                 684          0.250943
# 4     ArithmeticMean       1    5                3618          0.182861
# ...              ...     ...  ...                 ...               ...
# 5370  ArithmeticMean      27  180                2145          0.024281
# 5371  ArithmeticMean      27  180                2146          0.024281
# 5372  ArithmeticMean      27  180                2147          0.024281
# 5373  ArithmeticMean      27  180                2148          0.024281
# 5374  ArithmeticMean      27  180                2149          0.024281
#
# [5375 rows x 5 columns]
# 3959
# get_row_data:  ['ArithmeticMean' 1 1 3711 1.0]
# get_row_data:  ['ArithmeticMean' 1 2 669 0.250943]
# Top_3
# Now bugid_1 end excel index:  200
# Top_1:  []
# Top_3:  [1]
# Top_5:  [1]
# Top_10:  [1]
# -----------------------------------
# 5718
# get_row_data:  ['ArithmeticMean' 2 1 2802 1.0]
# get_row_data:  ['ArithmeticMean' 2 2 927 0.42941]
# Top_3
# Now bugid_2 end excel index:  400
# Top_1:  []
# Top_3:  [1, 2]
# Top_5:  [1, 2]
# Top_10:  [1, 2]
# -----------------------------------
# 5916
# get_row_data:  ['ArithmeticMean' 3 1 2369 1.0]
# Top_1
# Now bugid_3 end excel index:  600
# Top_1:  [3]
# Top_3:  [1, 2, 3]
# Top_5:  [1, 2, 3]
# Top_10:  [1, 2, 3]
# -----------------------------------
# 7558
# get_row_data:  ['ArithmeticMean' 4 1 6568 1.0]
# get_row_data:  ['ArithmeticMean' 4 1 6571 1.0]
# get_row_data:  ['ArithmeticMean' 4 1 6575 1.0]
# get_row_data:  ['ArithmeticMean' 4 4 6572 0.50485]
# get_row_data:  ['ArithmeticMean' 4 5 7525 0.339943]
# get_row_data:  ['ArithmeticMean' 4 6 4771 0.29284]
# get_row_data:  ['ArithmeticMean' 4 6 4772 0.29284]
# get_row_data:  ['ArithmeticMean' 4 6 4773 0.29284]
# get_row_data:  ['ArithmeticMean' 4 9 4769 0.257516]
# get_row_data:  ['ArithmeticMean' 4 10 5449 0.190089]
# get_row_data:  ['ArithmeticMean' 4 11 7501 0.109192]
# Not Found!
# Now bugid_4 end excel index:  800
# Top_1:  [3]
# Top_3:  [1, 2, 3]
# Top_5:  [1, 2, 3]
# Top_10:  [1, 2, 3]
# -----------------------------------
# 4375
# get_row_data:  ['ArithmeticMean' 5 1 1030 1.0]
# get_row_data:  ['ArithmeticMean' 5 2 987 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 989 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 990 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 991 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 992 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 993 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 995 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 997 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 999 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1000 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1001 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1002 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1003 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1004 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1005 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1006 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1007 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1010 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1011 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1012 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1015 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1016 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1269 0.753316]
# get_row_data:  ['ArithmeticMean' 5 2 1270 0.753316]
# get_row_data:  ['ArithmeticMean' 5 26 388 0.64707]
# Not Found!
# Now bugid_5 end excel index:  1000
# Top_1:  [3]
# Top_3:  [1, 2, 3]
# Top_5:  [1, 2, 3]
# Top_10:  [1, 2, 3]
# -----------------------------------
# 5036
# get_row_data:  ['ArithmeticMean' 6 1 3342 1.0]
# get_row_data:  ['ArithmeticMean' 6 1 3343 1.0]
# get_row_data:  ['ArithmeticMean' 6 1 3344 1.0]
# Top_1
# Now bugid_6 end excel index:  1200
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6]
# Top_5:  [1, 2, 3, 6]
# Top_10:  [1, 2, 3, 6]
# -----------------------------------
# 7109
# get_row_data:  ['ArithmeticMean' 7 1 3020 1.0]
# get_row_data:  ['ArithmeticMean' 7 1 3021 1.0]
# get_row_data:  ['ArithmeticMean' 7 1 3022 1.0]
# get_row_data:  ['ArithmeticMean' 7 1 3023 1.0]
# get_row_data:  ['ArithmeticMean' 7 1 4429 1.0]
# get_row_data:  ['ArithmeticMean' 7 1 4430 1.0]
# get_row_data:  ['ArithmeticMean' 7 1 4432 1.0]
# get_row_data:  ['ArithmeticMean' 7 1 4433 1.0]
# get_row_data:  ['ArithmeticMean' 7 1 4434 1.0]
# get_row_data:  ['ArithmeticMean' 7 10 6620 0.156149]
# get_row_data:  ['ArithmeticMean' 7 11 1320 0.151082]
# Not Found!
# Now bugid_7 end excel index:  1400
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6]
# Top_5:  [1, 2, 3, 6]
# Top_10:  [1, 2, 3, 6]
# -----------------------------------
# 3569
# get_row_data:  ['ArithmeticMean' 8 1 385 1.0]
# get_row_data:  ['ArithmeticMean' 8 2 375 0.668327]
# get_row_data:  ['ArithmeticMean' 8 2 381 0.668327]
# get_row_data:  ['ArithmeticMean' 8 4 539 0.147243]
# get_row_data:  ['ArithmeticMean' 8 4 540 0.147243]
# get_row_data:  ['ArithmeticMean' 8 6 429 0.0998783]
# get_row_data:  ['ArithmeticMean' 8 6 430 0.0998783]
# get_row_data:  ['ArithmeticMean' 8 6 431 0.0998783]
# get_row_data:  ['ArithmeticMean' 8 9 2802 0.0955725]
# get_row_data:  ['ArithmeticMean' 8 10 373 0.0714602]
# get_row_data:  ['ArithmeticMean' 8 10 374 0.0714602]
# get_row_data:  ['ArithmeticMean' 8 10 376 0.0714602]
# get_row_data:  ['ArithmeticMean' 8 10 377 0.0714602]
# get_row_data:  ['ArithmeticMean' 8 14 372 0.0693213]
# Not Found!
# Now bugid_8 end excel index:  1600
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6]
# Top_5:  [1, 2, 3, 6]
# Top_10:  [1, 2, 3, 6]
# -----------------------------------
# 3565
# get_row_data:  ['ArithmeticMean' 9 1 383 1.0]
# get_row_data:  ['ArithmeticMean' 9 2 381 0.668327]
# get_row_data:  ['ArithmeticMean' 9 3 387 0.289343]
# Top_3
# Now bugid_9 end excel index:  1800
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9]
# -----------------------------------
# 7227
# get_row_data:  ['ArithmeticMean' 10 1 50 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 463 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 464 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 465 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 466 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 467 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 468 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 469 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 470 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 471 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 472 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 533 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 534 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 538 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 540 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 541 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 543 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 563 1.0]
# get_row_data:  ['ArithmeticMean' 10 1 2792 1.0]
# get_row_data:  ['ArithmeticMean' 10 20 3500 0.672091]
# Not Found!
# Now bugid_10 end excel index:  2000
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9]
# -----------------------------------
# 4794
# get_row_data:  ['ArithmeticMean' 11 1 2056 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2058 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2059 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2206 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2207 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2512 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2513 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2767 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2922 1.0]
# get_row_data:  ['ArithmeticMean' 11 1 2923 1.0]
# get_row_data:  ['ArithmeticMean' 11 11 127 0.815789]
# Not Found!
# Now bugid_11 end excel index:  2200
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9]
# -----------------------------------
# 5569
# get_row_data:  ['ArithmeticMean' 12 1 2598 1.0]
# get_row_data:  ['ArithmeticMean' 12 2 726 0.716958]
# get_row_data:  ['ArithmeticMean' 12 3 524 0.615316]
# get_row_data:  ['ArithmeticMean' 12 3 526 0.615316]
# get_row_data:  ['ArithmeticMean' 12 3 5425 0.615316]
# get_row_data:  ['ArithmeticMean' 12 6 498 0.566391]
# Top_10
# Now bugid_12 end excel index:  2400
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9, 12]
# -----------------------------------
# 5163
# get_row_data:  ['ArithmeticMean' 13 1 746 1.0]
# get_row_data:  ['ArithmeticMean' 13 1 747 1.0]
# get_row_data:  ['ArithmeticMean' 13 1 748 1.0]
# get_row_data:  ['ArithmeticMean' 13 4 5039 0.751485]
# get_row_data:  ['ArithmeticMean' 13 4 5040 0.751485]
# get_row_data:  ['ArithmeticMean' 13 6 4999 0.602417]
# get_row_data:  ['ArithmeticMean' 13 6 5000 0.602417]
# get_row_data:  ['ArithmeticMean' 13 6 5001 0.602417]
# get_row_data:  ['ArithmeticMean' 13 9 4926 0.503056]
# get_row_data:  ['ArithmeticMean' 13 9 5007 0.503056]
# get_row_data:  ['ArithmeticMean' 13 9 5008 0.503056]
# get_row_data:  ['ArithmeticMean' 13 9 5009 0.503056]
# get_row_data:  ['ArithmeticMean' 13 9 5010 0.503056]
# get_row_data:  ['ArithmeticMean' 13 14 5006 0.432092]
# Not Found!
# Now bugid_13 end excel index:  2600
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9]
# Top_5:  [1, 2, 3, 6, 9]
# Top_10:  [1, 2, 3, 6, 9, 12]
# -----------------------------------
# 6990
# get_row_data:  ['ArithmeticMean' 14 1 3283 1.0]
# get_row_data:  ['ArithmeticMean' 14 2 5343 0.647071]
# get_row_data:  ['ArithmeticMean' 14 2 5345 0.647071]
# Top_3
# Now bugid_14 end excel index:  2800
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9, 14]
# Top_5:  [1, 2, 3, 6, 9, 14]
# Top_10:  [1, 2, 3, 6, 9, 12, 14]
# -----------------------------------
# 175
# get_row_data:  ['ArithmeticMean' 15 1 130 1.0]
# get_row_data:  ['ArithmeticMean' 15 2 129 0.145281]
# Top_3
# Now bugid_15 end excel index:  2975
# Top_1:  [3, 6]
# Top_3:  [1, 2, 3, 6, 9, 14, 15]
# Top_5:  [1, 2, 3, 6, 9, 14, 15]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15]
# -----------------------------------
# 7015
# get_row_data:  ['ArithmeticMean' 16 1 1499 1.0]
# get_row_data:  ['ArithmeticMean' 16 1 1500 1.0]
# get_row_data:  ['ArithmeticMean' 16 1 1502 1.0]
# get_row_data:  ['ArithmeticMean' 16 1 1503 1.0]
# get_row_data:  ['ArithmeticMean' 16 1 1504 1.0]
# get_row_data:  ['ArithmeticMean' 16 1 1505 1.0]
# get_row_data:  ['ArithmeticMean' 16 1 1506 1.0]
# Top_1
# Now bugid_16 end excel index:  3175
# Top_1:  [3, 6, 16]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16]
# -----------------------------------
# 3981
# get_row_data:  ['ArithmeticMean' 17 1 1546 1.0]
# Top_1
# Now bugid_17 end excel index:  3375
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17]
# -----------------------------------
# 4373
# get_row_data:  ['ArithmeticMean' 18 1 183 1.0]
# get_row_data:  ['ArithmeticMean' 18 2 2915 0.10719]
# get_row_data:  ['ArithmeticMean' 18 2 2917 0.10719]
# Top_3
# Now bugid_18 end excel index:  3575
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18]
# -----------------------------------
# 5707
# get_row_data:  ['ArithmeticMean' 19 1 2973 1.0]
# get_row_data:  ['ArithmeticMean' 19 1 2974 1.0]
# get_row_data:  ['ArithmeticMean' 19 3 3944 0.173817]
# get_row_data:  ['ArithmeticMean' 19 4 1231 0.161529]
# get_row_data:  ['ArithmeticMean' 19 4 1232 0.161529]
# get_row_data:  ['ArithmeticMean' 19 6 2948 0.104767]
# get_row_data:  ['ArithmeticMean' 19 7 1434 0.100807]
# get_row_data:  ['ArithmeticMean' 19 7 1435 0.100807]
# get_row_data:  ['ArithmeticMean' 19 7 1436 0.100807]
# get_row_data:  ['ArithmeticMean' 19 7 1439 0.100807]
# get_row_data:  ['ArithmeticMean' 19 11 5001 0.0991203]
# Not Found!
# Now bugid_19 end excel index:  3775
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18]
# -----------------------------------
# 5748
# get_row_data:  ['ArithmeticMean' 20 1 1167 1.0]
# get_row_data:  ['ArithmeticMean' 20 1 1168 1.0]
# get_row_data:  ['ArithmeticMean' 20 1 1173 1.0]
# get_row_data:  ['ArithmeticMean' 20 4 1174 0.903106]
# get_row_data:  ['ArithmeticMean' 20 4 1175 0.903106]
# Top_5
# Now bugid_20 end excel index:  3975
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20]
# -----------------------------------
# 3578
# get_row_data:  ['ArithmeticMean' 21 1 513 1.0]
# get_row_data:  ['ArithmeticMean' 21 1 523 1.0]
# get_row_data:  ['ArithmeticMean' 21 3 1941 0.355761]
# Top_3
# Now bugid_21 end excel index:  4175
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21]
# -----------------------------------
# 4641
# get_row_data:  ['ArithmeticMean' 22 1 1577 1.0]
# get_row_data:  ['ArithmeticMean' 22 2 1321 0.877653]
# get_row_data:  ['ArithmeticMean' 22 3 1576 0.451706]
# get_row_data:  ['ArithmeticMean' 22 4 2428 0.220321]
# Top_5
# Now bugid_22 end excel index:  4375
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22]
# -----------------------------------
# 1584
# get_row_data:  ['ArithmeticMean' 23 1 103 1.0]
# get_row_data:  ['ArithmeticMean' 23 2 107 0.380689]
# get_row_data:  ['ArithmeticMean' 23 3 95 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 97 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 98 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 100 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 101 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 102 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 104 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 106 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 191 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 192 0.339407]
# get_row_data:  ['ArithmeticMean' 23 3 193 0.339407]
# Top_3
# Now bugid_23 end excel index:  4575
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# 7512
# get_row_data:  ['ArithmeticMean' 24 1 1414 1.0]
# get_row_data:  ['ArithmeticMean' 24 1 3497 1.0]
# get_row_data:  ['ArithmeticMean' 24 1 3498 1.0]
# get_row_data:  ['ArithmeticMean' 24 4 1224 0.863732]
# get_row_data:  ['ArithmeticMean' 24 4 1229 0.863732]
# get_row_data:  ['ArithmeticMean' 24 4 6082 0.863732]
# get_row_data:  ['ArithmeticMean' 24 4 6084 0.863732]
# get_row_data:  ['ArithmeticMean' 24 4 6085 0.863732]
# get_row_data:  ['ArithmeticMean' 24 4 6089 0.863732]
# get_row_data:  ['ArithmeticMean' 24 10 1220 0.826603]
# get_row_data:  ['ArithmeticMean' 24 10 1222 0.826603]
# get_row_data:  ['ArithmeticMean' 24 10 1225 0.826603]
# get_row_data:  ['ArithmeticMean' 24 10 1227 0.826603]
# ...
# get_row_data:  ['Zoltar' 20 1 3733 1.0]
# get_row_data:  ['Zoltar' 20 1 3735 1.0]
# get_row_data:  ['Zoltar' 20 1 3736 1.0]
# get_row_data:  ['Zoltar' 20 1 3737 1.0]
# get_row_data:  ['Zoltar' 20 1 3739 1.0]
# get_row_data:  ['Zoltar' 20 1 3742 1.0]
# get_row_data:  ['Zoltar' 20 1 3757 1.0]
# get_row_data:  ['Zoltar' 20 1 3758 1.0]
# get_row_data:  ['Zoltar' 20 1 3759 1.0]
# get_row_data:  ['Zoltar' 20 1 3760 1.0]
# get_row_data:  ['Zoltar' 20 1 3761 1.0]
# get_row_data:  ['Zoltar' 20 1 3765 1.0]
# get_row_data:  ['Zoltar' 20 1 3766 1.0]
# get_row_data:  ['Zoltar' 20 1 3767 1.0]
# get_row_data:  ['Zoltar' 20 1 3768 1.0]
# get_row_data:  ['Zoltar' 20 1 3769 1.0]
# get_row_data:  ['Zoltar' 20 1 3770 1.0]
# get_row_data:  ['Zoltar' 20 1 3771 1.0]
# get_row_data:  ['Zoltar' 20 1 3772 1.0]
# get_row_data:  ['Zoltar' 20 1 3773 1.0]
# get_row_data:  ['Zoltar' 20 1 3774 1.0]
# get_row_data:  ['Zoltar' 20 1 3777 1.0]
# get_row_data:  ['Zoltar' 20 1 4298 1.0]
# get_row_data:  ['Zoltar' 20 1 4299 1.0]
# get_row_data:  ['Zoltar' 20 1 4300 1.0]
# get_row_data:  ['Zoltar' 20 1 4331 1.0]
# get_row_data:  ['Zoltar' 20 94 503 0.999611]
# Not Found!
# Now bugid_20 end excel index:  3975
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------
# 3578
# get_row_data:  ['Zoltar' 21 1 505 1.0]
# get_row_data:  ['Zoltar' 21 1 507 1.0]
# get_row_data:  ['Zoltar' 21 1 508 1.0]
# get_row_data:  ['Zoltar' 21 4 510 0.933334]
# get_row_data:  ['Zoltar' 21 4 511 0.933334]
# get_row_data:  ['Zoltar' 21 4 1921 0.933334]
# get_row_data:  ['Zoltar' 21 4 1922 0.933334]
# get_row_data:  ['Zoltar' 21 8 512 0.866667]
# get_row_data:  ['Zoltar' 21 9 515 0.733334]
# get_row_data:  ['Zoltar' 21 9 517 0.733334]
# get_row_data:  ['Zoltar' 21 9 518 0.733334]
# get_row_data:  ['Zoltar' 21 12 520 0.666668]
# Not Found!
# Now bugid_21 end excel index:  4175
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------
# 4641
# get_row_data:  ['Zoltar' 22 1 2900 1.0]
# get_row_data:  ['Zoltar' 22 2 2901 0.938776]
# get_row_data:  ['Zoltar' 22 3 1289 0.802721]
# get_row_data:  ['Zoltar' 22 3 1290 0.802721]
# get_row_data:  ['Zoltar' 22 3 1291 0.802721]
# get_row_data:  ['Zoltar' 22 3 1318 0.802721]
# get_row_data:  ['Zoltar' 22 3 1319 0.802721]
# get_row_data:  ['Zoltar' 22 8 2910 0.795918]
# get_row_data:  ['Zoltar' 22 8 2911 0.795918]
# get_row_data:  ['Zoltar' 22 8 2918 0.795918]
# get_row_data:  ['Zoltar' 22 11 1306 0.707483]
# Not Found!
# Now bugid_22 end excel index:  4375
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------
# 1584
# get_row_data:  ['Zoltar' 23 1 3 1.0]
# get_row_data:  ['Zoltar' 23 1 4 1.0]
# get_row_data:  ['Zoltar' 23 1 5 1.0]
# get_row_data:  ['Zoltar' 23 1 6 1.0]
# get_row_data:  ['Zoltar' 23 1 7 1.0]
# get_row_data:  ['Zoltar' 23 1 19 1.0]
# get_row_data:  ['Zoltar' 23 1 20 1.0]
# get_row_data:  ['Zoltar' 23 1 26 1.0]
# get_row_data:  ['Zoltar' 23 1 27 1.0]
# get_row_data:  ['Zoltar' 23 1 29 1.0]
# get_row_data:  ['Zoltar' 23 1 30 1.0]
# get_row_data:  ['Zoltar' 23 1 31 1.0]
# get_row_data:  ['Zoltar' 23 1 32 1.0]
# get_row_data:  ['Zoltar' 23 1 33 1.0]
# get_row_data:  ['Zoltar' 23 1 34 1.0]
# get_row_data:  ['Zoltar' 23 1 137 1.0]
# get_row_data:  ['Zoltar' 23 1 138 1.0]
# get_row_data:  ['Zoltar' 23 1 139 1.0]
# get_row_data:  ['Zoltar' 23 1 140 1.0]
# get_row_data:  ['Zoltar' 23 1 142 1.0]
# get_row_data:  ['Zoltar' 23 1 144 1.0]
# get_row_data:  ['Zoltar' 23 1 146 1.0]
# get_row_data:  ['Zoltar' 23 1 147 1.0]
# get_row_data:  ['Zoltar' 23 1 148 1.0]
# get_row_data:  ['Zoltar' 23 1 149 1.0]
# get_row_data:  ['Zoltar' 23 1 150 1.0]
# get_row_data:  ['Zoltar' 23 1 151 1.0]
# get_row_data:  ['Zoltar' 23 1 157 1.0]
# get_row_data:  ['Zoltar' 23 1 159 1.0]
# get_row_data:  ['Zoltar' 23 1 160 1.0]
# get_row_data:  ['Zoltar' 23 1 161 1.0]
# get_row_data:  ['Zoltar' 23 1 165 1.0]
# get_row_data:  ['Zoltar' 23 1 167 1.0]
# get_row_data:  ['Zoltar' 23 1 174 1.0]
# get_row_data:  ['Zoltar' 23 1 175 1.0]
# get_row_data:  ['Zoltar' 23 1 176 1.0]
# get_row_data:  ['Zoltar' 23 1 177 1.0]
# get_row_data:  ['Zoltar' 23 1 178 1.0]
# get_row_data:  ['Zoltar' 23 1 179 1.0]
# get_row_data:  ['Zoltar' 23 1 180 1.0]
# get_row_data:  ['Zoltar' 23 1 186 1.0]
# get_row_data:  ['Zoltar' 23 1 188 1.0]
# get_row_data:  ['Zoltar' 23 1 189 1.0]
# get_row_data:  ['Zoltar' 23 1 190 1.0]
# get_row_data:  ['Zoltar' 23 1 474 1.0]
# get_row_data:  ['Zoltar' 23 1 475 1.0]
# get_row_data:  ['Zoltar' 23 1 478 1.0]
# get_row_data:  ['Zoltar' 23 1 479 1.0]
# get_row_data:  ['Zoltar' 23 1 481 1.0]
# get_row_data:  ['Zoltar' 23 1 482 1.0]
# get_row_data:  ['Zoltar' 23 1 483 1.0]
# get_row_data:  ['Zoltar' 23 1 484 1.0]
# get_row_data:  ['Zoltar' 23 1 485 1.0]
# get_row_data:  ['Zoltar' 23 1 486 1.0]
# get_row_data:  ['Zoltar' 23 1 487 1.0]
# get_row_data:  ['Zoltar' 23 1 488 1.0]
# get_row_data:  ['Zoltar' 23 1 489 1.0]
# get_row_data:  ['Zoltar' 23 1 490 1.0]
# get_row_data:  ['Zoltar' 23 1 492 1.0]
# get_row_data:  ['Zoltar' 23 1 493 1.0]
# get_row_data:  ['Zoltar' 23 1 495 1.0]
# get_row_data:  ['Zoltar' 23 1 497 1.0]
# get_row_data:  ['Zoltar' 23 1 498 1.0]
# get_row_data:  ['Zoltar' 23 1 499 1.0]
# get_row_data:  ['Zoltar' 23 1 500 1.0]
# get_row_data:  ['Zoltar' 23 1 501 1.0]
# get_row_data:  ['Zoltar' 23 1 504 1.0]
# get_row_data:  ['Zoltar' 23 1 508 1.0]
# get_row_data:  ['Zoltar' 23 1 510 1.0]
# get_row_data:  ['Zoltar' 23 1 511 1.0]
# get_row_data:  ['Zoltar' 23 1 512 1.0]
# get_row_data:  ['Zoltar' 23 1 514 1.0]
# get_row_data:  ['Zoltar' 23 1 517 1.0]
# get_row_data:  ['Zoltar' 23 1 532 1.0]
# get_row_data:  ['Zoltar' 23 1 533 1.0]
# get_row_data:  ['Zoltar' 23 1 534 1.0]
# get_row_data:  ['Zoltar' 23 1 535 1.0]
# get_row_data:  ['Zoltar' 23 1 536 1.0]
# get_row_data:  ['Zoltar' 23 1 540 1.0]
# get_row_data:  ['Zoltar' 23 1 541 1.0]
# get_row_data:  ['Zoltar' 23 1 542 1.0]
# get_row_data:  ['Zoltar' 23 1 543 1.0]
# get_row_data:  ['Zoltar' 23 1 544 1.0]
# get_row_data:  ['Zoltar' 23 1 545 1.0]
# get_row_data:  ['Zoltar' 23 1 546 1.0]
# get_row_data:  ['Zoltar' 23 1 547 1.0]
# get_row_data:  ['Zoltar' 23 1 548 1.0]
# get_row_data:  ['Zoltar' 23 1 549 1.0]
# get_row_data:  ['Zoltar' 23 1 552 1.0]
# get_row_data:  ['Zoltar' 23 1 1445 1.0]
# get_row_data:  ['Zoltar' 23 1 1446 1.0]
# get_row_data:  ['Zoltar' 23 1 1447 1.0]
# get_row_data:  ['Zoltar' 23 1 1470 1.0]
# get_row_data:  ['Zoltar' 23 94 256 0.99944]
# Not Found!
# Now bugid_23 end excel index:  4575
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------
# 7512
# get_row_data:  ['Zoltar' 24 1 6611 1.0]
# get_row_data:  ['Zoltar' 24 2 180 0.859316]
# get_row_data:  ['Zoltar' 24 3 3209 0.688213]
# get_row_data:  ['Zoltar' 24 3 3211 0.688213]
# get_row_data:  ['Zoltar' 24 3 3212 0.688213]
# get_row_data:  ['Zoltar' 24 3 3213 0.688213]
# get_row_data:  ['Zoltar' 24 3 3214 0.688213]
# get_row_data:  ['Zoltar' 24 8 4182 0.48289]
# get_row_data:  ['Zoltar' 24 9 7290 0.436337]
# get_row_data:  ['Zoltar' 24 10 6616 0.303475]
# get_row_data:  ['Zoltar' 24 11 3461 0.109084]
# Not Found!
# Now bugid_24 end excel index:  4775
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------
# 5606
# get_row_data:  ['Zoltar' 25 1 2271 1.0]
# get_row_data:  ['Zoltar' 25 2 1125 0.475519]
# get_row_data:  ['Zoltar' 25 3 1127 0.474777]
# get_row_data:  ['Zoltar' 25 3 1128 0.474777]
# get_row_data:  ['Zoltar' 25 3 1129 0.474777]
# get_row_data:  ['Zoltar' 25 3 1130 0.474777]
# get_row_data:  ['Zoltar' 25 7 1132 0.470326]
# get_row_data:  ['Zoltar' 25 8 3859 0.14468]
# get_row_data:  ['Zoltar' 25 8 3860 0.14468]
# get_row_data:  ['Zoltar' 25 8 3861 0.14468]
# get_row_data:  ['Zoltar' 25 8 3862 0.14468]
# get_row_data:  ['Zoltar' 25 12 3668 0.0443316]
# Not Found!
# Now bugid_25 end excel index:  4975
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------
# 6641
# get_row_data:  ['Zoltar' 26 1 531 1.0]
# get_row_data:  ['Zoltar' 26 2 491 0.838409]
# get_row_data:  ['Zoltar' 26 3 532 0.550653]
# get_row_data:  ['Zoltar' 26 4 445 0.45867]
# get_row_data:  ['Zoltar' 26 5 982 0.446861]
# get_row_data:  ['Zoltar' 26 5 983 0.446861]
# get_row_data:  ['Zoltar' 26 5 984 0.446861]
# get_row_data:  ['Zoltar' 26 8 2771 0.442697]
# get_row_data:  ['Zoltar' 26 9 990 0.442511]
# get_row_data:  ['Zoltar' 26 10 3479 0.397141]
# get_row_data:  ['Zoltar' 26 11 3481 0.39652]
# Not Found!
# Now bugid_26 end excel index:  5175
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------
# 5947
# get_row_data:  ['Zoltar' 27 1 1491 1.0]
# get_row_data:  ['Zoltar' 27 1 1492 1.0]
# get_row_data:  ['Zoltar' 27 1 1494 1.0]
# get_row_data:  ['Zoltar' 27 1 1495 1.0]
# get_row_data:  ['Zoltar' 27 1 1496 1.0]
# get_row_data:  ['Zoltar' 27 1 1497 1.0]
# get_row_data:  ['Zoltar' 27 1 1498 1.0]
# get_row_data:  ['Zoltar' 27 1 1499 1.0]
# get_row_data:  ['Zoltar' 27 1 1529 1.0]
# get_row_data:  ['Zoltar' 27 1 1531 1.0]
# get_row_data:  ['Zoltar' 27 1 1533 1.0]
# get_row_data:  ['Zoltar' 27 1 1534 1.0]
# get_row_data:  ['Zoltar' 27 1 1535 1.0]
# get_row_data:  ['Zoltar' 27 1 1602 1.0]
# get_row_data:  ['Zoltar' 27 1 1603 1.0]
# get_row_data:  ['Zoltar' 27 1 1604 1.0]
# get_row_data:  ['Zoltar' 27 1 1605 1.0]
# get_row_data:  ['Zoltar' 27 1 1607 1.0]
# get_row_data:  ['Zoltar' 27 1 1609 1.0]
# get_row_data:  ['Zoltar' 27 1 1611 1.0]
# get_row_data:  ['Zoltar' 27 1 1612 1.0]
# get_row_data:  ['Zoltar' 27 1 1613 1.0]
# get_row_data:  ['Zoltar' 27 1 1614 1.0]
# get_row_data:  ['Zoltar' 27 1 1615 1.0]
# get_row_data:  ['Zoltar' 27 1 1616 1.0]
# get_row_data:  ['Zoltar' 27 1 1622 1.0]
# get_row_data:  ['Zoltar' 27 1 1624 1.0]
# get_row_data:  ['Zoltar' 27 1 1625 1.0]
# get_row_data:  ['Zoltar' 27 1 1626 1.0]
# get_row_data:  ['Zoltar' 27 1 1630 1.0]
# get_row_data:  ['Zoltar' 27 1 1632 1.0]
# get_row_data:  ['Zoltar' 27 1 1639 1.0]
# get_row_data:  ['Zoltar' 27 1 1640 1.0]
# get_row_data:  ['Zoltar' 27 1 1641 1.0]
# get_row_data:  ['Zoltar' 27 1 1642 1.0]
# get_row_data:  ['Zoltar' 27 1 1643 1.0]
# get_row_data:  ['Zoltar' 27 1 1644 1.0]
# get_row_data:  ['Zoltar' 27 1 1645 1.0]
# get_row_data:  ['Zoltar' 27 1 1651 1.0]
# get_row_data:  ['Zoltar' 27 1 1653 1.0]
# get_row_data:  ['Zoltar' 27 1 1654 1.0]
# get_row_data:  ['Zoltar' 27 1 1655 1.0]
# get_row_data:  ['Zoltar' 27 1 1721 1.0]
# get_row_data:  ['Zoltar' 27 1 2981 1.0]
# get_row_data:  ['Zoltar' 27 1 2982 1.0]
# get_row_data:  ['Zoltar' 27 1 2983 1.0]
# get_row_data:  ['Zoltar' 27 1 2984 1.0]
# get_row_data:  ['Zoltar' 27 1 2985 1.0]
# get_row_data:  ['Zoltar' 27 1 2986 1.0]
# get_row_data:  ['Zoltar' 27 1 3058 1.0]
# get_row_data:  ['Zoltar' 27 1 3059 1.0]
# get_row_data:  ['Zoltar' 27 1 3060 1.0]
# get_row_data:  ['Zoltar' 27 1 3061 1.0]
# get_row_data:  ['Zoltar' 27 1 3062 1.0]
# get_row_data:  ['Zoltar' 27 1 3074 1.0]
# get_row_data:  ['Zoltar' 27 1 3075 1.0]
# get_row_data:  ['Zoltar' 27 1 3220 1.0]
# get_row_data:  ['Zoltar' 27 1 3221 1.0]
# get_row_data:  ['Zoltar' 27 1 3223 1.0]
# get_row_data:  ['Zoltar' 27 1 3224 1.0]
# get_row_data:  ['Zoltar' 27 1 3225 1.0]
# get_row_data:  ['Zoltar' 27 1 3226 1.0]
# get_row_data:  ['Zoltar' 27 1 3227 1.0]
# get_row_data:  ['Zoltar' 27 1 3228 1.0]
# get_row_data:  ['Zoltar' 27 1 3229 1.0]
# get_row_data:  ['Zoltar' 27 1 3230 1.0]
# get_row_data:  ['Zoltar' 27 1 3338 1.0]
# get_row_data:  ['Zoltar' 27 1 3340 1.0]
# get_row_data:  ['Zoltar' 27 1 3341 1.0]
# get_row_data:  ['Zoltar' 27 1 3346 1.0]
# get_row_data:  ['Zoltar' 27 1 3368 1.0]
# get_row_data:  ['Zoltar' 27 1 3369 1.0]
# get_row_data:  ['Zoltar' 27 1 3370 1.0]
# get_row_data:  ['Zoltar' 27 1 3371 1.0]
# get_row_data:  ['Zoltar' 27 1 3372 1.0]
# get_row_data:  ['Zoltar' 27 1 3373 1.0]
# get_row_data:  ['Zoltar' 27 1 3374 1.0]
# get_row_data:  ['Zoltar' 27 1 3375 1.0]
# get_row_data:  ['Zoltar' 27 1 3376 1.0]
# get_row_data:  ['Zoltar' 27 1 3377 1.0]
# get_row_data:  ['Zoltar' 27 1 3378 1.0]
# get_row_data:  ['Zoltar' 27 1 3379 1.0]
# get_row_data:  ['Zoltar' 27 1 3380 1.0]
# get_row_data:  ['Zoltar' 27 1 3381 1.0]
# get_row_data:  ['Zoltar' 27 1 3382 1.0]
# get_row_data:  ['Zoltar' 27 1 3383 1.0]
# get_row_data:  ['Zoltar' 27 1 3476 1.0]
# get_row_data:  ['Zoltar' 27 1 3477 1.0]
# get_row_data:  ['Zoltar' 27 1 3478 1.0]
# get_row_data:  ['Zoltar' 27 1 3479 1.0]
# get_row_data:  ['Zoltar' 27 1 3480 1.0]
# get_row_data:  ['Zoltar' 27 1 3481 1.0]
# get_row_data:  ['Zoltar' 27 1 3482 1.0]
# get_row_data:  ['Zoltar' 27 1 3483 1.0]
# get_row_data:  ['Zoltar' 27 1 3484 1.0]
# get_row_data:  ['Zoltar' 27 1 3485 1.0]
# get_row_data:  ['Zoltar' 27 1 3486 1.0]
# get_row_data:  ['Zoltar' 27 1 3487 1.0]
# get_row_data:  ['Zoltar' 27 1 3488 1.0]
# get_row_data:  ['Zoltar' 27 1 3489 1.0]
# get_row_data:  ['Zoltar' 27 1 3490 1.0]
# get_row_data:  ['Zoltar' 27 1 3491 1.0]
# get_row_data:  ['Zoltar' 27 1 3492 1.0]
# get_row_data:  ['Zoltar' 27 1 3493 1.0]
# get_row_data:  ['Zoltar' 27 1 3494 1.0]
# get_row_data:  ['Zoltar' 27 1 3495 1.0]
# get_row_data:  ['Zoltar' 27 1 3496 1.0]
# get_row_data:  ['Zoltar' 27 1 3497 1.0]
# get_row_data:  ['Zoltar' 27 1 3499 1.0]
# get_row_data:  ['Zoltar' 27 1 3500 1.0]
# get_row_data:  ['Zoltar' 27 1 3503 1.0]
# get_row_data:  ['Zoltar' 27 1 3504 1.0]
# get_row_data:  ['Zoltar' 27 1 3505 1.0]
# get_row_data:  ['Zoltar' 27 1 3506 1.0]
# get_row_data:  ['Zoltar' 27 1 3679 1.0]
# get_row_data:  ['Zoltar' 27 1 3680 1.0]
# get_row_data:  ['Zoltar' 27 1 3681 1.0]
# get_row_data:  ['Zoltar' 27 1 3682 1.0]
# get_row_data:  ['Zoltar' 27 1 3683 1.0]
# get_row_data:  ['Zoltar' 27 1 3684 1.0]
# get_row_data:  ['Zoltar' 27 1 3687 1.0]
# get_row_data:  ['Zoltar' 27 1 3688 1.0]
# get_row_data:  ['Zoltar' 27 1 3696 1.0]
# get_row_data:  ['Zoltar' 27 1 3697 1.0]
# get_row_data:  ['Zoltar' 27 1 3698 1.0]
# get_row_data:  ['Zoltar' 27 1 3700 1.0]
# get_row_data:  ['Zoltar' 27 1 3757 1.0]
# get_row_data:  ['Zoltar' 27 1 3758 1.0]
# get_row_data:  ['Zoltar' 27 1 3759 1.0]
# get_row_data:  ['Zoltar' 27 1 3782 1.0]
# get_row_data:  ['Zoltar' 27 1 3783 1.0]
# get_row_data:  ['Zoltar' 27 1 3784 1.0]
# get_row_data:  ['Zoltar' 27 1 3785 1.0]
# get_row_data:  ['Zoltar' 27 1 3786 1.0]
# get_row_data:  ['Zoltar' 27 1 3787 1.0]
# get_row_data:  ['Zoltar' 27 1 3788 1.0]
# get_row_data:  ['Zoltar' 27 1 3818 1.0]
# get_row_data:  ['Zoltar' 27 1 3819 1.0]
# get_row_data:  ['Zoltar' 27 1 3822 1.0]
# get_row_data:  ['Zoltar' 27 1 3823 1.0]
# get_row_data:  ['Zoltar' 27 1 3825 1.0]
# get_row_data:  ['Zoltar' 27 1 3826 1.0]
# get_row_data:  ['Zoltar' 27 1 3827 1.0]
# get_row_data:  ['Zoltar' 27 1 3828 1.0]
# get_row_data:  ['Zoltar' 27 1 3829 1.0]
# get_row_data:  ['Zoltar' 27 1 3830 1.0]
# get_row_data:  ['Zoltar' 27 1 3831 1.0]
# get_row_data:  ['Zoltar' 27 1 3832 1.0]
# get_row_data:  ['Zoltar' 27 1 3833 1.0]
# get_row_data:  ['Zoltar' 27 1 3834 1.0]
# get_row_data:  ['Zoltar' 27 1 3836 1.0]
# get_row_data:  ['Zoltar' 27 1 3837 1.0]
# get_row_data:  ['Zoltar' 27 1 3839 1.0]
# get_row_data:  ['Zoltar' 27 1 3840 1.0]
# get_row_data:  ['Zoltar' 27 1 3841 1.0]
# get_row_data:  ['Zoltar' 27 1 3842 1.0]
# get_row_data:  ['Zoltar' 27 1 3843 1.0]
# get_row_data:  ['Zoltar' 27 1 3844 1.0]
# get_row_data:  ['Zoltar' 27 1 3845 1.0]
# get_row_data:  ['Zoltar' 27 1 3848 1.0]
# get_row_data:  ['Zoltar' 27 1 3852 1.0]
# get_row_data:  ['Zoltar' 27 1 3854 1.0]
# get_row_data:  ['Zoltar' 27 1 3855 1.0]
# get_row_data:  ['Zoltar' 27 1 3856 1.0]
# get_row_data:  ['Zoltar' 27 1 3858 1.0]
# get_row_data:  ['Zoltar' 27 1 3861 1.0]
# get_row_data:  ['Zoltar' 27 1 3862 1.0]
# get_row_data:  ['Zoltar' 27 1 3863 1.0]
# get_row_data:  ['Zoltar' 27 1 3864 1.0]
# get_row_data:  ['Zoltar' 27 1 3865 1.0]
# get_row_data:  ['Zoltar' 27 1 3866 1.0]
# get_row_data:  ['Zoltar' 27 1 3867 1.0]
# get_row_data:  ['Zoltar' 27 1 3868 1.0]
# get_row_data:  ['Zoltar' 27 1 3869 1.0]
# get_row_data:  ['Zoltar' 27 1 3876 1.0]
# get_row_data:  ['Zoltar' 27 1 3877 1.0]
# get_row_data:  ['Zoltar' 27 1 3878 1.0]
# get_row_data:  ['Zoltar' 27 1 3879 1.0]
# get_row_data:  ['Zoltar' 27 1 3880 1.0]
# get_row_data:  ['Zoltar' 27 1 3884 1.0]
# get_row_data:  ['Zoltar' 27 1 3885 1.0]
# get_row_data:  ['Zoltar' 27 1 3886 1.0]
# get_row_data:  ['Zoltar' 27 1 3887 1.0]
# get_row_data:  ['Zoltar' 27 1 3888 1.0]
# get_row_data:  ['Zoltar' 27 1 3889 1.0]
# get_row_data:  ['Zoltar' 27 1 3890 1.0]
# get_row_data:  ['Zoltar' 27 1 3891 1.0]
# get_row_data:  ['Zoltar' 27 1 3892 1.0]
# get_row_data:  ['Zoltar' 27 1 3893 1.0]
# get_row_data:  ['Zoltar' 27 1 3896 1.0]
# get_row_data:  ['Zoltar' 27 191 249 0.942623]
# Not Found!
# Now bugid_27 end excel index:  5375
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------

# %%
for i in range(0,len(SBFL_all)):
    print(SBFL_all[i])
    print("Top_1: " , Top_1[i])
    print("Top_3: " , Top_3[i])
    print("Top_5: " , Top_5[i])
    print("Top_10: " , Top_10[i])
    print("-----------------------------------")
# Out:
# Ample
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Anderberg
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# ArithmeticMean
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# BaroniUrbaniBuser
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 23]
# Top_5:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 22, 23]
# -----------------------------------
# BraunBanqust
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Cohen
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Dennis
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Dice
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Dstar
# Top_1:  [1, 3, 6, 7, 15, 16, 17, 18]
# Top_3:  [1, 2, 3, 5, 6, 7, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 5, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Euclid
# Top_1:  [17]
# Top_3:  [6, 12, 17]
# Top_5:  [6, 12, 17]
# Top_10:  [6, 12, 17, 24]
# -----------------------------------
# Fleiss
# Top_1:  [3, 6, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 6, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Fossum
# Top_1:  [3, 6, 16]
# Top_3:  [3, 5, 6, 14, 16]
# Top_5:  [3, 5, 6, 14, 16]
# Top_10:  [3, 5, 6, 12, 14, 16]
# -----------------------------------
# Goodman
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Gower
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  []
# -----------------------------------
# GP13
# Top_1:  [3, 16, 17]
# Top_3:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 23]
# Top_5:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Hamann
# Top_1:  [17]
# Top_3:  [6, 12, 17]
# Top_5:  [6, 12, 17]
# Top_10:  [6, 12, 17, 24]
# -----------------------------------
# Hamming
# Top_1:  [17]
# Top_3:  [6, 12, 17]
# Top_5:  [6, 12, 17]
# Top_10:  [6, 12, 17, 24]
# -----------------------------------
# HarmonicMean
# Top_1:  [11]
# Top_3:  [11]
# Top_5:  [11]
# Top_10:  [11, 15]
# -----------------------------------
# Jaccard
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Kulczynski1
# Top_1:  [1, 3, 6, 15, 16, 17, 18]
# Top_3:  [1, 2, 3, 6, 7, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Kulczynskil2
# Top_1:  [3, 16, 17, 21]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# M1
# Top_1:  [17]
# Top_3:  [6, 12, 17]
# Top_5:  [6, 12, 17]
# Top_10:  [6, 12, 17, 24]
# -----------------------------------
# M2
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Michael
# Top_1:  [23]
# Top_3:  [6, 23]
# Top_5:  [6, 23]
# Top_10:  [6, 15, 23]
# -----------------------------------
# Mountford
# Top_1:  [1, 3, 7, 15, 16, 17, 18]
# Top_3:  [1, 2, 3, 7, 9, 12, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Ochiai
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Ochiai2
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  []
# -----------------------------------
# Optimal
# Top_1:  [17, 24]
# Top_3:  [17, 24]
# Top_5:  [17, 24]
# Top_10:  [17, 24]
# -----------------------------------
# OptimalP
# Top_1:  [3, 14, 16, 17, 21]
# Top_3:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Overlap
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 5, 6, 9, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 5, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 5, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Phi
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Pierce
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  []
# -----------------------------------
# RogersTanimoto
# Top_1:  [17]
# Top_3:  [6, 12, 17]
# Top_5:  [6, 12, 17]
# Top_10:  [6, 12, 17, 24]
# -----------------------------------
# Rogot1
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Rogot2
# Top_1:  [3, 16, 17, 21]
# Top_3:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 21, 22, 23]
# Top_5:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# RussellRao
# Top_1:  [1, 5, 8, 9, 15, 19, 23, 24]
# Top_3:  [1, 5, 8, 9, 15, 19, 23, 24]
# Top_5:  [1, 5, 8, 9, 15, 19, 23, 24]
# Top_10:  [1, 5, 8, 9, 15, 19, 23, 24]
# -----------------------------------
# SBI
# Top_1:  [3, 16, 17]
# Top_3:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 23]
# Top_5:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Scott
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# SimpleMatching
# Top_1:  [17]
# Top_3:  [6, 12, 17]
# Top_5:  [6, 12, 17]
# Top_10:  [6, 12, 17, 24]
# -----------------------------------
# Sokal
# Top_1:  [17]
# Top_3:  [6, 12, 17]
# Top_5:  [6, 12, 17]
# Top_10:  [6, 12, 17, 24]
# -----------------------------------
# SorensenDice
# Top_1:  [3, 6, 16, 17]
# Top_3:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23]
# Top_5:  [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Tarantula
# Top_1:  [3, 16, 17]
# Top_3:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 23]
# Top_5:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Tarwid
# Top_1:  [3, 16, 17]
# Top_3:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 23]
# Top_5:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# Top_10:  [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23]
# -----------------------------------
# Wong1
# Top_1:  [1, 5, 8, 9, 15, 19, 23, 24]
# Top_3:  [1, 5, 8, 9, 15, 19, 23, 24]
# Top_5:  [1, 5, 8, 9, 15, 19, 23, 24]
# Top_10:  [1, 5, 8, 9, 15, 19, 23, 24]
# -----------------------------------
# Wong2
# Top_1:  [17]
# Top_3:  [6, 12, 17]
# Top_5:  [6, 12, 17]
# Top_10:  [6, 12, 17, 24]
# -----------------------------------
# Wong3
# Top_1:  [5, 13, 14, 21]
# Top_3:  [5, 13, 14, 15, 18, 21, 22, 23]
# Top_5:  [5, 13, 14, 15, 18, 21, 22, 23]
# Top_10:  [1, 5, 7, 13, 14, 15, 18, 21, 22, 23]
# -----------------------------------
# Zoltar
# Top_1:  []
# Top_3:  []
# Top_5:  []
# Top_10:  [3]
# -----------------------------------

# %%
print("Top_1: " , Top_1 , "\n\n\n")
print("Top_3: " , Top_3 , "\n\n\n")
print("Top_5: " , Top_5 , "\n\n\n")
print("Top_10: " , Top_10)
# Out:
# Top_1:  [[3, 14, 16, 17, 21], [3, 6, 16, 17], [3, 6, 16, 17], [3, 6, 16, 17], [3, 6, 16, 17], [3, 6, 16, 17], [3, 6, 16, 17], [3, 6, 16, 17], [1, 3, 6, 7, 15, 16, 17, 18], [17], [3, 6, 14, 16, 17, 21], [3, 6, 16], [3, 6, 16, 17], [], [3, 16, 17], [17], [17], [11], [3, 6, 16, 17], [1, 3, 6, 15, 16, 17, 18], [3, 16, 17, 21], [17], [3, 14, 16, 17, 21], [23], [1, 3, 7, 15, 16, 17, 18], [3, 6, 16, 17], [], [17, 24], [3, 14, 16, 17, 21], [3, 6, 16, 17], [3, 6, 16, 17], [], [17], [3, 6, 16, 17], [3, 16, 17, 21], [1, 5, 8, 9, 15, 19, 23, 24], [3, 16, 17], [3, 6, 16, 17], [17], [17], [3, 6, 16, 17], [3, 16, 17], [3, 16, 17], [1, 5, 8, 9, 15, 19, 23, 24], [17], [5, 13, 14, 21], []]
#
#
#
# Top_3:  [[1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 5, 6, 7, 9, 14, 15, 16, 17, 18, 21, 23], [6, 12, 17], [1, 2, 3, 5, 6, 9, 14, 15, 16, 17, 18, 21, 22, 23], [3, 5, 6, 14, 16], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 23], [6, 12, 17], [6, 12, 17], [11], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 6, 7, 9, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 22, 23], [6, 12, 17], [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23], [6, 23], [1, 2, 3, 7, 9, 12, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 21, 23], [], [17, 24], [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 21, 22, 23], [1, 2, 3, 5, 6, 9, 14, 15, 16, 17, 18, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 21, 23], [], [6, 12, 17], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 21, 22, 23], [1, 5, 8, 9, 15, 19, 23, 24], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [6, 12, 17], [6, 12, 17], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 21, 23], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 23], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 23], [1, 5, 8, 9, 15, 19, 23, 24], [6, 12, 17], [5, 13, 14, 15, 18, 21, 22, 23], []]
#
#
#
# Top_5:  [[1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 22, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 5, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 12, 17], [1, 2, 3, 5, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [3, 5, 6, 14, 16], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 12, 17], [6, 12, 17], [11], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 12, 17], [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 23], [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [], [17, 24], [1, 2, 3, 5, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 5, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [], [6, 12, 17], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 5, 8, 9, 15, 19, 23, 24], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 12, 17], [6, 12, 17], [1, 2, 3, 6, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 5, 8, 9, 15, 19, 23, 24], [6, 12, 17], [5, 13, 14, 15, 18, 21, 22, 23], []]
#
#
#
# Top_10:  [[1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 5, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 12, 17, 24], [1, 2, 3, 5, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [3, 5, 6, 12, 14, 16], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 12, 17, 24], [6, 12, 17, 24], [11, 15], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 12, 17, 24], [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 15, 23], [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [], [17, 24], [1, 2, 3, 5, 7, 9, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 5, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [], [6, 12, 17, 24], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 7, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 5, 8, 9, 15, 19, 23, 24], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [6, 12, 17, 24], [6, 12, 17, 24], [1, 2, 3, 6, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 2, 3, 9, 12, 14, 15, 16, 17, 18, 20, 21, 22, 23], [1, 5, 8, 9, 15, 19, 23, 24], [6, 12, 17, 24], [1, 5, 7, 13, 14, 15, 18, 21, 22, 23], [3]]
