# %%
import pandas as pd
import openpyxl
# 變數設定，目的在於其他的project只要修改這部分就好了
Project = 'chart'
Project2 = 'Chart'
project_bugid_num = 26
#SBFL_tool = 'Ample'
Excel_name = 'chart_整理結果'
Excel_save_path = 'chart_result'

# 這是要放要拿來使用的絕對路徑
unsort_data_path = 'Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old'

SBFL_all = [
    "Ample",
    "Anderberg",
    "ArithmeticMean",
    "BaroniUrbaniBuser",
    "BraunBanqust",
    "Cohen",
    "Dennis",
    "Dice",
    "Dstar",
    "Euclid",
    "Fleiss",
    "Fossum",
    "Goodman",
    "Gower",
    "GP13",
    "Hamann",
    "Hamming",
    "HarmonicMean",
    "Jaccard",
    "Kulczynski",
    "Kulczynski1",
    "Kulczynskil2",
    "M1",
    "M2",
    "Michael",
    "Mountford",
    "Ochiai",
    "Ochiai2",
    "Optimal",
    "OptimalP",
    "Overlap",
    "Pearson",
    "Phi",
    "Pierce",
    "RogersTanimoto",
    "Rogot1",
    "Rogot2",
    "RussellRao",
    "SBI",
    "Scott",
    "SimpleMatching",
    "Sokal",
    "SorensenDice",
    "Tarantula",
    "Tarwid",
    "Wong1",
    "Wong2",
    "Wong3",
    "Zoltar"
]

# %%
# 取得project的每一個bug-id有多少行的方法。
SBFL_fault_statement_number = []
project_statement_file = 'project_line/' + Project +'_line.txt'

# 使用 with 語句打開文件，確保文件在使用後自動關閉
with open(project_statement_file, 'r', encoding='utf-8') as file:
    project_lines = file.readlines()  # 讀取所有行

# 去掉每行末尾的換行符
project_lines = [int(line.strip()) for line in project_lines] # 順便將str轉為數字
print(project_lines)

max_line = max(project_lines) # 找出最大行數，用於後續輸出使用
print(max_line)
# Out:
# [7057, 1328, 840, 25163, 284, 676, 481, 195, 953, 53, 193, 4361, 886, 6315, 12107, 298, 1074, 392, 4493, 517, 595, 246, 4655, 25, 10879, 20672]
# 25163

# %%
# get_fault_statement
#動態產生二微陣列的方法
Project_bugid_faultStatement = []

for i in range(0,project_bugid_num):
    fault_statement_file_path = '錯誤位置/'+ Project + '/' + Project2 +'_v' + str(i+1) + '_FaultStatement.txt'
    print(fault_statement_file_path)

    # 使用 with 語句打開文件，確保文件在使用後自動關閉
    with open(fault_statement_file_path, 'r', encoding='utf-8') as file:
        lines2 = file.readlines()  # 讀取所有行

    # 去掉每行末尾的換行符
    lines2 = [line.strip() for line in lines2]
    print(lines2)

    lines2 = lines2[0].split()
    print(len(lines2))

    Project_bugid_faultStatement.append([])
    for j in range(0,len(lines2)):
        Project_bugid_faultStatement[i].append(int(lines2[j])) # 順便將str轉為數字

print(Project_bugid_faultStatement)
# Out:
# 錯誤位置/chart/Chart_v1_FaultStatement.txt
# ['2436']
# 1
# 錯誤位置/chart/Chart_v2_FaultStatement.txt
# ['182 183 184 185 186 187 379 380 381 382 383 384']
# 12
# 錯誤位置/chart/Chart_v3_FaultStatement.txt
# ['663 664 665']
# 3
# 錯誤位置/chart/Chart_v4_FaultStatement.txt
# ['10472']
# 1
# 錯誤位置/chart/Chart_v5_FaultStatement.txt
# ['162 163 164']
# 3
# 錯誤位置/chart/Chart_v6_FaultStatement.txt
# ['267']
# 1
# 錯誤位置/chart/Chart_v7_FaultStatement.txt
# ['276 277']
# 2
# 錯誤位置/chart/Chart_v8_FaultStatement.txt
# ['54']
# 1
# 錯誤位置/chart/Chart_v9_FaultStatement.txt
# ['797']
# 1
# 錯誤位置/chart/Chart_v10_FaultStatement.txt
# ['53']
# 1
# 錯誤位置/chart/Chart_v11_FaultStatement.txt
# ['67']
# 1
# 錯誤位置/chart/Chart_v12_FaultStatement.txt
# ['79']
# 1
# 錯誤位置/chart/Chart_v13_FaultStatement.txt
# ['361']
# 1
# 錯誤位置/chart/Chart_v14_FaultStatement.txt
# ['1400 1401 1473 1474 3740 3741 3823 3824']
# 8
# 錯誤位置/chart/Chart_v15_FaultStatement.txt
# ['4726 4727 4850 4851']
# 4
# 錯誤位置/chart/Chart_v16_FaultStatement.txt
# ['37 38 70']
# 3
# 錯誤位置/chart/Chart_v17_FaultStatement.txt
# ['268']
# 1
# 錯誤位置/chart/Chart_v18_FaultStatement.txt
# ['226 227 228 229 230 332 337']
# 7
# 錯誤位置/chart/Chart_v19_FaultStatement.txt
# ['1526 1596']
# 2
# 錯誤位置/chart/Chart_v20_FaultStatement.txt
# ['6']
# 1
# 錯誤位置/chart/Chart_v21_FaultStatement.txt
# ['270 399 400 401']
# 4
# 錯誤位置/chart/Chart_v22_FaultStatement.txt
# ['33 35 66 70 71 82']
# 6
# 錯誤位置/chart/Chart_v23_FaultStatement.txt
# ['0']
# 1
# 錯誤位置/chart/Chart_v24_FaultStatement.txt
# ['13']
# 1
# 錯誤位置/chart/Chart_v25_FaultStatement.txt
# ['10003 10004 10038 9936 9937 9971']
# 6
# 錯誤位置/chart/Chart_v26_FaultStatement.txt
# ['3908 3909']
# 2
# [[2436], [182, 183, 184, 185, 186, 187, 379, 380, 381, 382, 383, 384], [663, 664, 665], [10472], [162, 163, 164], [267], [276, 277], [54], [797], [53], [67], [79], [361], [1400, 1401, 1473, 1474, 3740, 3741, 3823, 3824], [4726, 4727, 4850, 4851], [37, 38, 70], [268], [226, 227, 228, 229, 230, 332, 337], [1526, 1596], [6], [270, 399, 400, 401], [33, 35, 66, 70, 71, 82], [0], [13], [10003, 10004, 10038, 9936, 9937, 9971], [3908, 3909]]

# %%
# #要存成的excel index有甚麼
# data = {
#     'SBFL_Tool': [],
#     'Top': [],
#     'Spectra_file_index': [],
#     'Suspicious_Value': []
# }

# %%
for SBFL_index, SBFL_a in enumerate(SBFL_all):
    #要存成的excel index有甚麼
    data = {
        'SBFL_Tool': [],
        'bug_id': [],
        'Top': [],
        'Spectra_file_index': [],
        'Suspicious_Value': []
    }
    for i in range(0,project_bugid_num):
        file_path = unsort_data_path + '/' + SBFL_a + '_v' + str(i+1) + '_sus.txt' #使用絕對路徑
        print(file_path)

        output_file2 = Project + '_result/' + SBFL_a +'_' + Project2 + '-' + str(i+1) + '_result'# 輸出的懷疑直Top結果，檔案要存在哪一個資料夾，檔案名稱要存成甚麼。

        # 使用 with 語句打開文件，確保文件在使用後自動關閉
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()  # 讀取所有行

        # 去掉每行末尾的換行符
        lines = [line.strip() for line in lines]

        # 將列表中的元素和其索引配對，用於表示的幾個statement
        indexed_list = list(enumerate(lines))

        # 將列表中的元素和其索引配對,索引從1開始
        indexed_list = [(i+1, line) for i, line in enumerate(lines)]

        # 找出前 XX 名（若列表長度小於 XX，則返回所有元素）
        top_test = sorted(indexed_list, key=lambda x: x[1], reverse=True)[:max_line]
        
        Now_top = 0 # 用於紀錄top用的
        previous_rank_sus = '' #表示與前一個rank的懷疑質做比較做比較
        count_top = 0

        for index, value in top_test:

            #用於處理計算Top使用----
            count_top += 1
            if value != previous_rank_sus:
                #Now_top = Now_top
                #Now_top += 1
                Now_top = count_top
            else:
                Now_top = Now_top
            #----------------------

            previous_rank_sus = value
            data['SBFL_Tool'].append(SBFL_a)
            data['bug_id'].append(i+1)
            data['Top'].append(Now_top)
            data['Spectra_file_index'].append(index)
            data['Suspicious_Value'].append(value)

    # 創建 DataFrame
    df = pd.DataFrame(data)
    print(df)

    save_excel_file_name = Excel_name + SBFL_a
    print(save_excel_file_name)
    wb = openpyxl.Workbook() #建立空的excel
    #wb = openpyxl.load_workbook('oxxo.xlsx') #開啟excel
    wb.save( Excel_save_path + '/' + save_excel_file_name + '.xlsx')

    # # 將資料寫入 Excel 檔案
    file_name = Excel_save_path + '/' + save_excel_file_name + '.xlsx'
    df.to_excel(Excel_save_path + '/' + save_excel_file_name + '.xlsx', index=False)

    # print(f"資料已寫入 {save_excel_file_name} 文件中")
# Out:
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Ample_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0          Ample       1      1                2433                1
# 1          Ample       1      2                3747         0.990632
# 2          Ample       1      2                3748         0.990632
# 3          Ample       1      4                3753         0.983607
# 4          Ample       1      4                3754         0.983607
# ...          ...     ...    ...                 ...              ...
# 104733     Ample      26  10762               20668                0
# 104734     Ample      26  10762               20669                0
# 104735     Ample      26  10762               20670                0
# 104736     Ample      26  10762               20671                0
# 104737     Ample      26  10762               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果Ample
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Anderberg_v26_sus.txt
#         SBFL_Tool  bug_id   Top  Spectra_file_index Suspicious_Value
# 0       Anderberg       1     1                2433                1
# 1       Anderberg       1     2                3747         0.111111
# 2       Anderberg       1     2                3748         0.111111
# 3       Anderberg       1     4                3753        0.0666667
# 4       Anderberg       1     4                3754        0.0666667
# ...           ...     ...   ...                 ...              ...
# 104733  Anderberg      26  5589               20668                0
# 104734  Anderberg      26  5589               20669                0
# 104735  Anderberg      26  5589               20670                0
# 104736  Anderberg      26  5589               20671                0
# 104737  Anderberg      26  5589               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果Anderberg
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/ArithmeticMean_v26_sus.txt
#              SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0       ArithmeticMean       1      1                2433                1
# 1       ArithmeticMean       1      2                3747         0.343282
# 2       ArithmeticMean       1      2                3748         0.343282
# 3       ArithmeticMean       1      4                3753         0.234027
# 4       ArithmeticMean       1      4                3754         0.234027
# ...                ...     ...    ...                 ...              ...
# 104733  ArithmeticMean      26  20666               11805       0.00772295
# 104734  ArithmeticMean      26  20666               11811       0.00772295
# 104735  ArithmeticMean      26  20670               11800       0.00585973
# 104736  ArithmeticMean      26  20671               11428        0.0039527
# 104737  ArithmeticMean      26  20672               11427                0
#
# [104738 rows x 5 columns]
# chart_整理結果ArithmeticMean
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BaroniUrbaniBuser_v26_sus.txt
#                 SBFL_Tool  bug_id   Top  Spectra_file_index Suspicious_Value
# 0       BaroniUrbaniBuser       1     1                2433                1
# 1       BaroniUrbaniBuser       1     2                3747         0.843548
# 2       BaroniUrbaniBuser       1     2                3748         0.843548
# 3       BaroniUrbaniBuser       1     4                3753         0.754333
# 4       BaroniUrbaniBuser       1     4                3754         0.754333
# ...                   ...     ...   ...                 ...              ...
# 104733  BaroniUrbaniBuser      26  5589               20668                0
# 104734  BaroniUrbaniBuser      26  5589               20669                0
# 104735  BaroniUrbaniBuser      26  5589               20670                0
# 104736  BaroniUrbaniBuser      26  5589               20671                0
# 104737  BaroniUrbaniBuser      26  5589               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果BaroniUrbaniBuser
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/BraunBanqust_v26_sus.txt
#            SBFL_Tool  bug_id   Top  Spectra_file_index Suspicious_Value
# 0       BraunBanqust       1     1                2433                1
# 1       BraunBanqust       1     2                3747              0.2
# 2       BraunBanqust       1     2                3748              0.2
# 3       BraunBanqust       1     4                3753            0.125
# 4       BraunBanqust       1     4                3754            0.125
# ...              ...     ...   ...                 ...              ...
# 104733  BraunBanqust      26  5589               20668                0
# 104734  BraunBanqust      26  5589               20669                0
# 104735  BraunBanqust      26  5589               20670                0
# 104736  BraunBanqust      26  5589               20671                0
# 104737  BraunBanqust      26  5589               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果BraunBanqust
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Cohen_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0          Cohen       1      1                4988      9.91039e-05
# 1          Cohen       1      1                4990      9.91039e-05
# 2          Cohen       1      1                4992      9.91039e-05
# 3          Cohen       1      1                4994      9.91039e-05
# 4          Cohen       1      1                4996      9.91039e-05
# ...          ...     ...    ...                 ...              ...
# 104733     Cohen      26  20666               11805      0.000401224
# 104734     Cohen      26  20666               11811      0.000401224
# 104735     Cohen      26  20670               11800      0.000298286
# 104736     Cohen      26  20671               11428      0.000197133
# 104737     Cohen      26  20672               11427                0
#
# [104738 rows x 5 columns]
# chart_整理結果Cohen
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dennis_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0         Dennis       1      1                2433                1
# 1         Dennis       1      2                3747         0.464875
# 2         Dennis       1      2                3748         0.464875
# 3         Dennis       1      4                3753         0.373345
# 4         Dennis       1      4                3754         0.373345
# ...          ...     ...    ...                 ...              ...
# 104733    Dennis      26  20666               11805       0.00283368
# 104734    Dennis      26  20666               11811       0.00283368
# 104735    Dennis      26  20670               11800       0.00211958
# 104736    Dennis      26  20671               11428        0.0014093
# 104737    Dennis      26  20672               11427                0
#
# [104738 rows x 5 columns]
# chart_整理結果Dennis
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dice_v26_sus.txt
#        SBFL_Tool  bug_id   Top  Spectra_file_index Suspicious_Value
# 0           Dice       1     1                2433                1
# 1           Dice       1     2                3747              0.2
# 2           Dice       1     2                3748              0.2
# 3           Dice       1     4                3753            0.125
# 4           Dice       1     4                3754            0.125
# ...          ...     ...   ...                 ...              ...
# 104733      Dice      26  5589               20668                0
# 104734      Dice      26  5589               20669                0
# 104735      Dice      26  5589               20670                0
# 104736      Dice      26  5589               20671                0
# 104737      Dice      26  5589               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果Dice
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Dstar_v26_sus.txt
#        SBFL_Tool  bug_id   Top  Spectra_file_index Suspicious_Value
# 0          Dstar       1     1                3747                1
# 1          Dstar       1     1                3748                1
# 2          Dstar       1     3                3753         0.571429
# 3          Dstar       1     3                3754         0.571429
# 4          Dstar       1     3                3756         0.571429
# ...          ...     ...   ...                 ...              ...
# 104733     Dstar      26  5588               20668                0
# 104734     Dstar      26  5588               20669                0
# 104735     Dstar      26  5588               20670                0
# 104736     Dstar      26  5588               20671                0
# 104737     Dstar      26  5588               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果Dstar
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Euclid_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0         Euclid       1      1                2433                1
# 1         Euclid       1      2                   3         0.998459
# 2         Euclid       1      2                   7         0.998459
# 3         Euclid       1      2                   8         0.998459
# 4         Euclid       1      2                  25         0.998459
# ...          ...     ...    ...                 ...              ...
# 104733    Euclid      26  20655                5710                0
# 104734    Euclid      26  20655                5711                0
# 104735    Euclid      26  20655                5712                0
# 104736    Euclid      26  20655                5713                0
# 104737    Euclid      26  20655                5714                0
#
# [104738 rows x 5 columns]
# chart_整理結果Euclid
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fleiss_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0         Fleiss       1      1                2433                1
# 1         Fleiss       1      2                3747         0.999805
# 2         Fleiss       1      2                3748         0.999805
# 3         Fleiss       1      4                3753         0.999531
# 4         Fleiss       1      4                3754         0.999531
# ...          ...     ...    ...                 ...              ...
# 104733    Fleiss      26  20655                5710                0
# 104734    Fleiss      26  20655                5711                0
# 104735    Fleiss      26  20655                5712                0
# 104736    Fleiss      26  20655                5713                0
# 104737    Fleiss      26  20655                5714                0
#
# [104738 rows x 5 columns]
# chart_整理結果Fleiss
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Fossum_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0         Fossum       1      1                  50                1
# 1         Fossum       1      1                  51                1
# 2         Fossum       1      1                  52                1
# 3         Fossum       1      1                 214                1
# 4         Fossum       1      1                 216                1
# ...          ...     ...    ...                 ...              ...
# 104733    Fossum      26  10762               20668                0
# 104734    Fossum      26  10762               20669                0
# 104735    Fossum      26  10762               20670                0
# 104736    Fossum      26  10762               20671                0
# 104737    Fossum      26  10762               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果Fossum
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Goodman_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Goodman_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Goodman_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Goodman_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Goodman_v5_sus.txt
# ...
# 4         Tarwid       1      4                3754         0.983945
# ...          ...     ...    ...                 ...              ...
# 104733    Tarwid      26  15500               20634                0
# 104734    Tarwid      26  15500               20635                0
# 104735    Tarwid      26  15500               20636                0
# 104736    Tarwid      26  15500               20639                0
# 104737    Tarwid      26  15500               20641                0
#
# [104738 rows x 5 columns]
# chart_整理結果Tarwid
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong1_v26_sus.txt
#        SBFL_Tool  bug_id   Top  Spectra_file_index Suspicious_Value
# 0          Wong1       1     1                   1                1
# 1          Wong1       1     1                   2                1
# 2          Wong1       1     1                   4                1
# 3          Wong1       1     1                   5                1
# 4          Wong1       1     1                   6                1
# ...          ...     ...   ...                 ...              ...
# 104733     Wong1      26  5589               20668                0
# 104734     Wong1      26  5589               20669                0
# 104735     Wong1      26  5589               20670                0
# 104736     Wong1      26  5589               20671                0
# 104737     Wong1      26  5589               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果Wong1
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong2_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0          Wong2       1      1                2433                1
# 1          Wong2       1      2                   3         0.997519
# 2          Wong2       1      2                   7         0.997519
# 3          Wong2       1      2                   8         0.997519
# 4          Wong2       1      2                  25         0.997519
# ...          ...     ...    ...                 ...              ...
# 104733     Wong2      26  20655                5710                0
# 104734     Wong2      26  20655                5711                0
# 104735     Wong2      26  20655                5712                0
# 104736     Wong2      26  20655                5713                0
# 104737     Wong2      26  20655                5714                0
#
# [104738 rows x 5 columns]
# chart_整理結果Wong2
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Wong3_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0          Wong3       1      1                2433                1
# 1          Wong3       1      2                3426         0.998067
# 2          Wong3       1      2                3427         0.998067
# 3          Wong3       1      4                3667         0.997733
# 4          Wong3       1      4                3668         0.997733
# ...          ...     ...    ...                 ...              ...
# 104733     Wong3      26  19677               20558                0
# 104734     Wong3      26  19677               20559                0
# 104735     Wong3      26  19677               20561                0
# 104736     Wong3      26  19677               20588                0
# 104737     Wong3      26  19677               20610                0
#
# [104738 rows x 5 columns]
# chart_整理結果Wong3
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v1_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v2_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v3_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v4_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v5_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v6_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v7_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v8_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v9_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v10_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v11_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v12_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v13_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v14_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v15_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v16_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v17_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v18_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v19_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v20_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v21_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v22_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v23_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v24_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v25_sus.txt
# Z:/廷偉/偉/研究所/其他SBFL資料-用於後續實驗用/CalculateSpectrum/CalculateSpectrum/CalculateSpectrum/Chart/Sus/old/Zoltar_v26_sus.txt
#        SBFL_Tool  bug_id    Top  Spectra_file_index Suspicious_Value
# 0         Zoltar       1      1                5936                1
# 1         Zoltar       1      1                5937                1
# 2         Zoltar       1      1                5944                1
# 3         Zoltar       1      1                5945                1
# 4         Zoltar       1      1                5946                1
# ...          ...     ...    ...                 ...              ...
# 104733    Zoltar      26  10762               20668                0
# 104734    Zoltar      26  10762               20669                0
# 104735    Zoltar      26  10762               20670                0
# 104736    Zoltar      26  10762               20671                0
# 104737    Zoltar      26  10762               20672                0
#
# [104738 rows x 5 columns]
# chart_整理結果Zoltar

# %%
# # 創建 DataFrame
# df = pd.DataFrame(data)
# print(df)

# %%
# import openpyxl

# wb = openpyxl.Workbook() #建立空的excel
# #wb = openpyxl.load_workbook('oxxo.xlsx') #開啟excel
# wb.save( Excel_name + '.xlsx')

# %%
# # 將資料寫入 Excel 檔案
# file_name = Excel_name + '.xlsx'
# df.to_excel(file_name, index=False)

# print(f"資料已寫入 {file_name} 文件中")
# Out:
# 資料已寫入 chart_整理結果.xlsx 文件中

# %%
print(Project_bugid_faultStatement[0])
print(Project_bugid_faultStatement[0][0])
print(Project_bugid_faultStatement[1])
print(Project_bugid_faultStatement[1][0])
print(Project_bugid_faultStatement[1][1])
# Out:
# [2436]
# 2436
# [182, 183, 184, 185, 186, 187, 379, 380, 381, 382, 383, 384]
# 182
# 183
